# %%
import urllib.request
import bs4

# %%
pagina = urllib.request.urlopen('http://www.itlalaguna.edu.mx')
html = pagina.read()
#BeautifulSoup es una biblioteca que ayuda a analizar datos en archivos html
sopa = bs4.BeautifulSoup(html, 'html5lib')

# %%
type(html)
# Out:
# bytes

# %%
type(sopa)
# Out:
# bs4.BeautifulSoup

# %%
sopa
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
# <!-- Global site tag (gtag.js) - Google Analytics urbilily =UA-54252992-1 solo www-->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-54252992-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-54252992-1');
# </script>
# <script crossorigin="anonymous" integrity="sha256-9/aliU8dGd2tb6OSsuzixeV4y/faTqgFtohetphbbj0=" src="https://code.jquery.com/jquery-3.5.1.min.js"></script>
# <!-- Global site tag (gtag.js) - Google Analytics itlsitioweb UA-180691430-1  dominio itlalaguna.edu.mx -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-180691430-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-180691430-1');
# </script>
# <!-- Global site tag (gtag.js) - Google Analytics G-JTN8QDY5L0 lalaguna.tecnm.mx -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-JTN8QDY5L0"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'G-JTN8QDY5L0');
# </script>
#
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="Licenciatura, Ingenierías, Maestrías, Doctorado en el Sistema de Institutos Tecnológicos, universidad, universidades torreon" name="description"/>
# <meta content="Licenciatura, Ingenierías, Maestrías, octorado, la laguna, torreon, posgrado, universidad, universidades torreon, gomez palacio, lerdo, tec torreon" name="keywords"/>
# <title>Instituto Tecnológico de La Laguna</title>
#
# <link href="img/logotipos/tecnmicono.ico" rel="shortcut icon"/>
#
# <link crossorigin="anonymous" href="https://stackpath.bootstrapcdn.com/bootstrap/4.1.1/css/bootstrap.min.css" integrity="sha384-WskhaSGFgHYWDcbwN70/dfYBj47jz9qbsMId/iRN3ewGhXQFZCSftd1LZCfmhktB" rel="stylesheet"/>
# <link href="css/carousel.css" rel="stylesheet"/>
#
# <link href="css/slick.css" rel="stylesheet" type="text/css"/>
# <link href="css/slick-theme.css" rel="stylesheet" type="text/css"/>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/5.14.0/css/all.min.css" rel="stylesheet" type="text/css"/>
#
# <!--Carrusel-->
# <style>
#     h1#carousel {
#         font-size: 80px;
#         color: #fff;
#     }
#
#     h2#carousel {
#         font-size: 50px;
#         color: white;
#     }
#
#     h5#carousel {
#         font-size: 30px;
#         font-family: century gothic;
#         color: white;
#         text-align: left;
#     }
#
#     h6#carousel {
#         font-size: 15px;
#         font-family: century gothic;
#         color: white;
#         text-align: left;
#     }
#
#     img#carousel {
#         max-width: 100%;
#     }
#
#     @media (max-width: 650px) {
#         .prevMod{
#         width: 50px;
#         height: 100%;
#     }
#
#
#     }
#
#     .prevMod {
#         width: 50px;
#
#     }
#
#     .prevMod:hover {
#         background-color: #19396a;
#     }
#
#     .carousel-control-next,
#     .carousel-control-prev {
#         opacity: 1;
#     }
#
#     /*VIÑETAS*/
#
#     @media (max-height: 736px){
#         .bolita{
#             height: 10px !important;
#             width: 10px !important;
#         }
#     }
#     .bolita {
#         cursor: pointer;
#         height: 15px;
#         width: 15px;
#         margin-top: 0 2px;
#         background-color: #bbb;
#         border-radius: 50%;
#         display: inline-block;
#         transition: background-color 1s ease;
#     }
#
#     #bolitas {
#         text-align: center;
#     }
#
#     .activo,
#     .bolita:hover {
#         background-color: #717171 !important;
#     }
# </style>
# <style>
#         .tecCar{
#             width: 60%;
#             height: 30%;
#             display: inline-block !important;
#         }
#
#         .next{
#             right: 0px;
#             position: absolute;
#             top: 50%;
#             display: block;
#             color: #333333 !important;
#         }
#
#         .prev{
#             left: 0px;
#             position: absolute;
#             top: 50%;
#             display: block;
#             color: #333333 !important;
#         }
#
#         .slick-next::before{
#             content: '';
#
#         }
#
#         .slick-prev::before{
#             content: '';
#         }
#
#         .slick-next .slick-prev{
#             opacity: 1;
#         }
#
#         .img-container{
#             text-align: center;
#         }
#
#         .center {
#             margin-left: auto;
#             margin-right: auto;
#             display: block;
#         }
#         .tecCar img{
#             width: auto;
#             max-width: 98%;
#             height: 110px;
#         }
#     </style>
#     </head>
# <body>
#     <!-- SCRIPT SUBMENUS -->
# <script>
# /*     $('.dropdown-menu a.dropdown-toggle').on('click', function(e) {
#         if (!$(this).next().hasClass('show')) {
#             $(this).parents('.dropdown-menu').first().find('.show').removeClass('show');
#         }
#         var $subMenu = $(this).next('.dropdown-menu');
#         $subMenu.toggleClass('show');
#
#
#         $(this).parents('li.nav-item.dropdown.show').on('hidden.bs.dropdown', function(e) {
#             $('.dropdown-submenu .show').removeClass('show');
#         });
#
#
#         return false;
#     }); */
# </script>
#
# <!--arreglos navbar verde-->
# <style>
#     a {
#         color: white !important;
#         font-size: large;
#     }
#
#     @media (min-width: 960px) {
#         .dropdown:hover>.dropdown-menu {
#             display: block;
#         }
#
#
#     }
#
#     .dropdown-submenu {
#         position: relative;
#     }
#
#     .dropdown-submenu a::after {
#         transform: rotate(-90deg);
#         position: absolute;
#         right: 6px;
#         top: .8em;
#     }
#
#     .dropdown-submenu {
#         position: relative;
#     }
#
#     .dropdown-submenu .dropdown-menu {
#         top: 0;
#         left: 100%;
#         margin-top: -1px;
#     }
#
#     .dropdown-submenu .dropdown-menu {
#         top: 0;
#         left: 100%;
#         margin-left: .1rem;
#         margin-right: .1rem;
#
#     }
#
#     #navbarDropdown {
#         cursor: pointer;
#     }
#
#     /*
#   nav>a:hover {
#     display:block;
#     cursor: pointer;
#     color: tomato;
#     background-color:white;
#     transition: background-color .5s;
#     opacity: 0.05;*/
#
#     div.dropdown-menu a:hover {
#         background-color: #363636;
#         align-content: center;
#     }
#
#     .navbar-nav li:hover>ul.dropdown-menu {
#         display: block;
#     }
#
#     .dropdown-submenu {
#         position: relative;
#     }
#
#     .dropdown-submenu>.dropdown-menu {
#         top: 0;
#         left: 100%;
#         margin-top: -6px;
#     }
#
#     /* rotate caret on hover */
#     .dropdown-menu>li>a:hover:after {
#         text-decoration: underline;
#         transform: rotate(-90deg);
#     }
#
#     div.dropdown-menu a:hover {
#       background-color: #363636;
#       align-content: center;
#     }
#
#     /*Fix imagen inicio del header*/
#     @media (max-width: 960px) {
#         .img-inicio-fix{
#             width: 30px !important;
#         }
#     }
#     .img-inicio-fix{
#         width: 50px;
#     }
# </style>
#
# <!--NavBar Menu Verde-->
#
# <nav class="navbar navbar-expand-md navbar-dark bg-dark" style="width: 100%; background-color: #0b231e  !important;">
#     <a class="navbar-brand" href="#">
#         <img alt="Página de inicio, Gobierno de México" height="33" src="https://framework-gb.cdn.gob.mx/landing/img/logoheader.svg" style=" margin-left: 80%;"/>
#     </a>
#
#     <button class="navbar-toggler" data-target="#navbarNav" data-toggle="collapse" type="button">
#         <span class="navbar-toggler-icon"></span>
#     </button>
#     <div class="collapse navbar-collapse" id="navbarNav">
#         <ul class="navbar-nav mr-auto">
#             <li class="nav-item active">
#                 <a class="nav-link" href="#"> <span class="sr-only">(current)</span></a>
#             </li>
#
#         </ul>
#         <ul class="navbar-nav" style="margin-right: 10%;">
#             <li class="nav-item">
#                 <a class="nav-link" href="https://www.gob.mx/gobierno" style="color: white;"> Gobierno</a>
#             </li>
#
#             <li class="nav-item">
#                 <a class="nav-link" href="https://www.gob.mx/participa" style="color: white;">Participa</a>
#             </li>
#
#             <li class="nav-item">
#                 <a class="nav-link" href="https://datos.gob.mx " style="color: white;">Datos</a>
#             </li>
#
#             <li class="nav-item">
#                 <a class="nav-item nav-link active" href="https://www.gob.mx/busqueda" style="color: white;">
#                     <span class="sr-only">Búsqueda</span>
#                     <svg aria-hidden="true" class="svg-inline--fa fa-search fa-w-16" data-fa-i2svg="" data-icon="search" data-prefix="fas" focusable="false" height="18" role="img" viewBox="0 0 512 512" width="18" xmlns="http://www.w3.org/2000/svg">
#                         <path d="M505 442.7L405.3 343c-4.5-4.5-10.6-7-17-7H372c27.6-35.3 44-79.7 44-128C416 93.1 322.9 0 208 0S0 93.1 0 208s93.1 208 208 208c48.3 0 92.7-16.4 128-44v16.3c0 6.4 2.5 12.5 7 17l99.7 99.7c9.4 9.4 24.6 9.4 33.9 0l28.3-28.3c9.4-9.4 9.4-24.6.1-34zM208 336c-70.7 0-128-57.2-128-128 0-70.7 57.2-128 128-128 70.7 0 128 57.2 128 128 0 70.7-57.2 128-128 128z" fill="currentColor"></path>
#                     </svg><!-- <i class="fas fa-search"></i> -->
#                 </a>
#             </li>
#
#         </ul>
#     </div>
# </nav>
# <!--Fin NavBar Menu Verde-->
#
#
#
# <!-- Menu logos instituciones -->
# <div style="background-color: fff; width: 90%;
#            margin-left: 5%; margin-right:5%; margin-top:2%; margin-bottom:2%;">
#
#     <a href="https://www.gob.mx/">
#         <img alt="Gobierno de México" src="img/logotipos/pleca-gob1.png" style="width:30%;height:auto"/>
#     </a>
#     <a href="https://www.gob.mx/sep">
#         <img alt="Educación" src="img/logotipos/pleca-gob2.png" style="width:30%;height:auto; min-width:auto;"/>
#     </a>
#     <a href="https://www.tecnm.mx/">
#         <img alt="TecNM" src="img/logotipos/pleca_tecnm.jpg" style="width:18%;height:auto; "/>
#     </a>
#     <a href="https:/www.itlalaguna.edu.mx/">
#         <img alt="ITL" src="img/logotipos/itl2.jpeg" style="width:7%; height:auto;"/>
#     </a>
# </div>
# <!--Fin Menu logos instituciones-->
#
#
# <!-- Menu Gris -->
# <nav class="navbar navbar-expand-lg navbar-dark bg-dark sticky-top" style="background:#363637 !important; z-index: 2;">
#
#     <!--  Collapse-->
#     <button aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-target="#navbarSupportedContent" data-toggle="collapse" type="button">
#         <span class="navbar-toggler-icon"></span>
#     </button>
#
#
#     <!-- Normal Menu-->
#     <div class="collapse navbar-collapse" id="navbarSupportedContent">
#         <ul class="navbar-nav mr-auto" style="margin: auto;">
#
#             <li class="nav-item img-inicio-fix" id="dmenu">
#                 <a aria-expanded="false" aria-haspopup="true" class="nav-link" href="index.php" role="button">
#                 <img class="img-fluid" src="img/icono-home.png"/>
#                 </a>
#             </li>
#             <li class="nav-item" id="dmenu">
#                 <a aria-expanded="false" aria-haspopup="true" class="nav-link" href="directorio.php" role="button">
#                     Directorio
#                 </a>
#             </li>
#             <!--   1-->
#             <li class="nav-item dropdown" id="dmenu">
#
#                 <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" id="navbarDropdown" role="button">
#                     ¿Quiénes Somos?
#                 </a>
#                 <div class="dropdown-menu" style="background:#454547;">
#
#                     <a class="text-black dropdown-item" href="historia.php">HISTORIA</a>
#                     <a class="text-black dropdown-item" href="mision.php">MISIÓN Y VISIÓN</a>
#                     <a class="text-black dropdown-item" href="infra.php">UBICACIÓN E INFRAESCTRUCTURA</a>
#                     <a class="text-black dropdown-item" href="cuidadoMa.php">CUIDADO DEL MEDIO AMBIENTE</a>
#                     <a class="text-black dropdown-item" href="logos.php">MASCOTA Y LOGOS</a>
#                     <!--<a class="text-black dropdown-item" href="contacto.php">CONTACTO</a>-->
#
#                     <!--<a class="text-black dropdown-item" href="https://docs.google.com/forms/d/e/1FAIpQLSeE8OPXE5YSXIcA0zLvfCnaHtY0NQrbtSEr9VVMn8ZavzT_iA/viewform#response=ACYDBNiyCA6p87VDbN4lu-wVyLdVOv5qkOKwqxQXMwKijoJdEsQXK53UB9bS5t4">BUZÓN DE QUEJAS Y SUGERENCIAS</a>-->
#                     <a class="text-black dropdown-item" href="https://docs.google.com/forms/d/e/1FAIpQLSddMvuMgSe8qJ63G7op3Pcr5-VEuV2_UPElM977PS9lm8faug/viewform">BUZÓN DE QUEJAS Y SUGERENCIAS</a>
#
#                     <a class="text-black dropdown-item" href="https://docs.google.com/forms/d/e/1FAIpQLSckSqRPLi4GVYVthg5wP034P8tiEgBhyLnNcd6JCc7ZkE1KGg/viewform?entry.1159593137=nombre&amp;entry.1809109965&amp;entry.1214002645&amp;entry.1344596603&amp;entry.1727722980&amp;entry.1573787809=nombre+completo&amp;entry.471819699=puesto&amp;entry.285911030=ITL&amp;entry.134294733=2018-03-03&amp;entry.1785309787=20:00&amp;entry.1084813065=ITL&amp;entry.1814560733=hechos&amp;entry.1641027819=Nombre+testigo&amp;entry.1484745992=Domicilio+testigo&amp;entry.769034671=S%C3%AD&amp;entry.1684521492=si1&amp;entry.1680632340=si2">
#                         FORMATO DE DENUNCIAS DEL SG DE
#                         <br/>IGUALDAD DE GÉNERO Y NO DISCRIMINACIÓN</a>
#
#                     <a class="text-black dropdown-item" href="http://www.itlalaguna.edu.mx/etica/codigoetica.pdf">CÓDIGO DE ÉTICA Y CONDUCTA</a>
#                     <a class="text-black dropdown-item" href="https://www.tecnm.mx/?vista=Normateca">NORMATECA  DEL TECNM</a>
#
#
#                 </div>
#             </li>
#             <!-- PRUEBA -->
#    <!--2-->
#                <!--2-->
#
#
#
#                <li class="nav-item dropdown" id="dmenu">
#                 <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" id="navbarDropdown" role="button">
#                     Oferta Educativa
#                 </a>
#
#                 <div class="dropdown-menu" style="background:#454547;">
#                     <ul class="navbar-nav nav-dropdown dropdown-item" data-app-modern-menu="true" style="background:#454547;">
#                         <li class="nav-item dropdown dropdown-submenu" style="background:#454547;">
#                             <a aria-expanded="false" class="dropdown-toggle dropdown-item dropdown-submenu" data-toggle="dropdown-submenu" href="#" style="background:#454547;">NIVEL LICENCIATURA</a>
#                             <div class="dropdown-menu" style="background:#454547;">
#                                 <a class="text-black dropdown-item" href="sistemas.php">ING. SISTEMAS
#                                     COMPUTACIONALES</a>
#                                 <a class="text-black dropdown-item" href="electrica.php">ING. ELÉCTRICA</a>
#                                 <a class="text-black dropdown-item" href="electronica.php">ING. ELECTRÓNICA</a>
#                                 <a class="text-black dropdown-item" href="er.php">ING. EN ENERGÍAS
#                                     RENOVABLES</a>
#                                 <a class="text-black dropdown-item" href="industrial.php">ING.
#                                     INDUSTRIAL</a>
#                                 <a class="text-black dropdown-item" href="mecanica.php">ING. MECÁNICA</a>
#                                 <a class="text-black dropdown-item" href="mecatronica.php">ING.
#                                     MECATRÓNICA</a>
#                                 <a class="text-black dropdown-item" href="quimica.php">ING. QUÍMICA</a>
#                                 <a class="text-black dropdown-item" href="admin.php">LIC.
#                                     ADMINISTRACION</a>
#                                 <a class="text-black dropdown-item" href="gestionEmp.php">ING. GESTIÓN
#                                     EMPRESARIAL</a>
#
#                             </div>
#                         </li>
#                     </ul>
#                        <!-- <a class="link text-black dropdown-item" style="background:#454547;" href="http://www.itlalaguna.edu.mx/posgrado/indexposgrado.html" data-toggle="dropdown-submenu" aria-expanded="false">NIVEL POSGRADO</a>-->
#
#
#
#
#                     <ul class="navbar-nav nav-dropdown dropdown-item" data-app-modern-menu="true" style="background:#454547;">
#                         <li class="nav-item dropdown dropdown-submenu" style="background:#454547;">
#                             <a aria-expanded="false" class="dropdown-toggle dropdown-item dropdown-submenu" data-toggle="dropdown-submenu" href="#" style="background:#454547;">NIVEL POSGRADO</a>
#                             <div class="dropdown-menu" style="background:#454547;">
#
#                                 <a class="text-black dropdown-item" href="MAESTRIAE.php">MAESTRÍA EN CIENCIAS EN INGENIERÍA ELÉCTRICA (PNPC)</a>
#
#                                 <a class="text-black dropdown-item" href="MAESTRIAI.php">MAESTRÍA EN INGENIERÍA INDUSTRIAL</a>
#                                 <a class="text-black dropdown-item" href="MAESTRIAS.php">MAESTRÍA EN SISTEMAS COMPUTACIONALES</a>
#                                 <a class="text-black dropdown-item" href="DOCTORADOE.php">DOCTORADO EN CIENCIAS EN INGENIERÍA ELÉCTRICA (PNPC)</a>
#
#                             </div>
#                         </li>
#                     </ul>
#
#
#                      <!-- <ul class="navbar-nav nav-dropdown dropdown-item " style="background:#454547;" data-app-modern-menu="true">
#                         <li class="nav-item dropdown dropdown-submenu" style="background:#454547;">
#                             <a class="dropdown-toggle dropdown-item dropdown-submenu" style="background:#454547;" href="#" data-toggle="dropdown-submenu" aria-expanded="false">NIVEL LICENCIATURA A DISTANCIA</a>
#                             <div class=" dropdown-menu" style="background:#454547;">
#
#                                 <a class="text-black dropdown-item" href="industrial.php">ING.
#                                     INDUSTRIAL</a>
#
#                                 <a class="text-black dropdown-item" href="gestionEmp.php">ING. GESTIÓN
#                                     EMPRESARIAL</a>
#
#                             </div>
#                         </li>
#                     </ul>-->
#                     </div>
#
#             </li>
#             <!-- NEW 4 -->
#
#
#
#
#
#
#
#  <!-- 3-->
#
#  <!-- ALUMNADO2   ERA 4
#  <li class="nav-item dropdown" id='dmenu'>
#                 <a class="nav-link dropdown-toggle" id="navbarDropdown" role="button" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
#                     Aspirantes
#                 </a>
#                 <div class="dropdown-menu" style="background:#454547;">
#                     <a class="text-black dropdown-item" href="nivelacion.php">SEMESTRE DE NIVELACIÓN</a>
#                     <a class="text-black dropdown-item" href="http://apps2.itlalaguna.edu.mx:8081/">INGRESO LICENCIATURA</a>
#                     <a class="text-black dropdown-item" href="posgrado/indexposgrado.html">INGRESO POSGRADO</a>
#
#                 </div>
#             </li>
#
#             <li class="nav-item dropdown" id='dmenu'>
#                 <a class="nav-link dropdown-toggle" id="navbarDropdown" role="button" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
#                     Alumnado2
#                 </a>
#                 <div class="dropdown-menu" style="background:#454547; ">
#                     <ul class="navbar-nav nav-dropdown dropdown-item" style="background:#454547;" data-app-modern-menu="true">
#                         <li class="nav-item dropdown dropdown-submenu" style="background:#454547;">
#                             <a class="dropdown-toggle dropdown-item dropdown-submenu" id="smn3" style="background:#454547;" href="#" data-toggle="dropdown-submenu" aria-expanded="false">DIV. DE ESTUDIOS PROFESIONALES</a>
#                             <div class="dropdown-menu" style="background:#454547;">
#                                 <a class="dropdown-item" href="#">COORDINACIÓN DE TITULACIÓN</a>
#                                 <a class="dropdown-item" href="#">HORARIO MATERIAS</a>
#                                 <a class="dropdown-item" href="#">REINGRESO LICENCIATURA</a>
#                                 <a class="dropdown-item" href="#">VERANOS LICENCIATURA</a>
#                                 <a class="dropdown-item" href="#">REINGRESO POSGRADO</a>
#                                 <a class="dropdown-item" href="#">REINGRESO A DISTANCIA</a>
#                             </div>
#                         </li>
#                     </ul>
#                     <ul class="navbar-nav nav-dropdown dropdown-item" style="background:#454547;" data-app-modern-menu="true">
#                         <li class="nav-item dropdown" style="background:#454547;">
#                             <a class=" dropdown-toggle dropdown-item dropdown-submenu" href="http://escolares.itlalaguna.edu.mx" id="smn4" style="background:#454547;" href="#" data-toggle="dropdown-submenu" aria-expanded="false">SERVICIOS ESCOLARES</a>
#
#                         </li>
#                     </ul>
#                 </div>
#             </li>
#
# -->
#
#
#    <!--2-->
#    <li class="nav-item dropdown" id="dmenu">
#                 <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" id="navbarDropdown" role="button">
#                     Alumnado
#                 </a>
#                 <div class="dropdown-menu" style="background:#454547;">
#                 <ul class="navbar-nav nav-dropdown dropdown-item" data-app-modern-menu="true" style="background:#454547;">
#                         <li class="nav-item dropdown dropdown-submenu" style="background:#454547;">
#                             <a aria-expanded="false" class="link text-black dropdown-toggle dropdown-item" data-toggle="dropdown-submenu" href="#" style="background:#454547;">DESARROLLO ACADÉMICO</a>
#                              <div class="dropdown-menu" style="background:#454547;">
#                             <a class="text-black dropdown-item" href="http://sed.itlalaguna.edu.mx/sed/">EVALUACIÓN AL PROFESORADO</a>
#
#                             <a class="dropdown-item" href="AVISOS/CALENDARIO.PDF">CALENDARIO ESCOLAR</a>
#                             </div>
#                         </li>
#                     </ul>
#                     <ul class="navbar-nav nav-dropdown dropdown-item" data-app-modern-menu="true" style="background:#454547;">
#                         <li class="nav-item dropdown dropdown-submenu" style="background:#454547;">
#                             <a aria-expanded="false" class="link text-black dropdown-toggle dropdown-item" data-toggle="dropdown-submenu" href="#" style="background:#454547;">DIVISIÓN DE ESTUDIOS PROFESIONALES</a>
#                              <div class="dropdown-menu" style="background:#454547;">
#
#                              <a class="dropdown-item" href="http://apps2.itlalaguna.edu.mx/inscripcion/login.aspx">CARGA DE MATERIAS</a>
#                              <!--<a class="dropdown-item" href="soporte@correo.itlalaguna.edu.mx">Si tienes algún problema escribe a <br>
#                              soporte@correo.itlalaguna.edu.mx <br> incluye número de control y <br>comprobante de pago
#                             </a>-->
#                              <a class="dropdown-item" href="http://apps.itlalaguna.edu.mx/servicios/academicos/horario_materias_2020/index.htm">HORARIO MATERIAS</a>
#                               <a class="text-black dropdown-item" href="titulacion.php">COORDINACIÓN DE TITULACIÓN</a>
#
#                             <a class="dropdown-item" href="http://apps2.itlalaguna.edu.mx:8082/">FICHAS DE PAGO REINGRESO</a>
#                             <a class="dropdown-item" href="COMITE/COMITE.PDF">COMITÉ ACADÉMICO</a>
#                             <a class="dropdown-item" href="ESPECIALES/ESPECIALES.PDF">EXÁMENES ESPECIALES</a>
#                             </div>
#                         </li>
#                     </ul>
#                     <a aria-expanded="false" class="link text-black dropdown-item" data-toggle="dropdown-submenu" href="REGLAMENTO/Manual_de_Lineamientos_TecNM.pdf" style="background:#454547;">MANUAL DE LINEAMIENTOS</a>
#                     <a aria-expanded="false" class="link text-black dropdown-item" data-toggle="dropdown-submenu" href="REGLAMENTO/REGLAMENTO2019.PDF" style="background:#454547;">REGLAMENTO ESTUDIANTIL</a>
#
#
#
#                     <a aria-expanded="false" class="link text-black dropdown-item" data-toggle="dropdown-submenu" href="http://escolares.itlalaguna.edu.mx" style="background:#454547;">SERVICIOS ESCOLARES</a>
#                     <a aria-expanded="false" class="link text-black dropdown-item" data-toggle="dropdown-submenu" href="extraescolares/extraescolares20.pdf" style="background:#454547;">ACTIVIDADES EXTRAESCOLARES</a>
#                 </div>
#             </li>
#
#
#
#
#             <!-- 3-->
#
#
#             <!-- 3-->
#             <li class="nav-item dropdown" id="dmenu">
#                 <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" id="navbarDropdown" role="button">
#                    Nuevo Ingreso
#                 </a>
#                 <div class="dropdown-menu" style="background:#454547;">
#
#                    <!-- <a class="text-black dropdown-item" href="http://apps2.itlalaguna.edu.mx:8081/">LICENCIATURA</a>-->
#                    <a class="text-black dropdown-item" href="ADMago.PHP">LICENCIATURA AGOSTO - DICIEMBRE</a>
#                    <a class="text-black dropdown-item" href="ADMcpago.PHP">POSGRADO AGOSTO - DICIEMBRE</a>
#                    <a class="text-black dropdown-item" href="nivelacion.php">NIVELACIÓN AGOSTO - DICIEMBRE</a>
#                    <a class="text-black dropdown-item" href="ADM.PHP">LICENCIATURA ENERO - JUNIO</a>
#                     <a class="text-black dropdown-item" href="ADMcp.PHP">POSGRADO ENERO - JUNIO</a>
#
#
#
#                     <!--<a class="text-black dropdown-item" href="ADMdis.PHP">LICENCIATURA MODALIDAD A DISTANCIA</a>-->
#
#                   <!--  <a class="text-black dropdown-item" href="distancia.php">INGRESO A DISTANCIA</a>-->
#                 </div>
#             </li>
#
#
#
#              <!-- 5-->
#              <li class="nav-item dropdown" id="dmenu">
#                 <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" id="navbarDropdown" role="button">
#                     Vinculación
#                 </a>
#                 <div class="dropdown-menu" style="background:#454547;">
#                     <a class="dropdown-item" href="http://www.itlalaguna.edu.mx/vinculacion/servsocial21.pdf">SERVICIO SOCIAL</a>
#                     <a class="dropdown-item" href="http://www.itlalaguna.edu.mx/vinculacion/bolsa_trabajo_2.pdf">BOLSA DE TRABAJO</a>
#                     <a class="dropdown-item" href="http://www.itlalaguna.edu.mx/vinculacion/servicios_externos.pdf">SERVICIO EXTERNOS</a>
#                     <a class="dropdown-item" href="http://www.itlalaguna.edu.mx/vinculacion/idiomas.pdf">IDIOMAS</a>
#                     <a class="dropdown-item" href="vinculacion/residencia/residencia-platica.pdf">SOLICITUD DE CARTA DE PRESENTACIÓN<br/> DE RESIDENCIA PROFESIONAL</a>
#
#                 </div>
#             </li>
#              <!-- 6-->
#              <li class="nav-item dropdown" id="dmenu">
#                 <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" id="navbarDropdown" role="button">
#                     Personal
#                 </a>
#                 <div class="dropdown-menu" style="background:#454547;">
#                     <a class="dropdown-item" href="http://apps.itlalaguna.edu.mx/servicios/personal/catedraticos/index18.html">DOCENTES CARGA DE TRABAJO</a>
#                     <!--<a class=" dropdown-item" href="http://apps2.itlalaguna.edu.mx/SGESCL/login.aspx">DOCENTES CALIFICACIONES</a>-->
#                     <a class="dropdown-item" href="becasint/becasint.html">CONVOCATORIAS</a>
#                     <a class="dropdown-item" href="REGLAMENTOS.PHP">REGLAMENTOS</a>
#                     <a class="dropdown-item" href="CONTRALORIA.PHP">PRODEP</a>
#                 </div>
#             </li>
#             <!-- 7-->
#             <!--  <li class="nav-item dropdown" id='dmenu'>
#                 <a class="nav-link dropdown-toggle" id="navbarDropdown" data-toggle="dropdown" role="button" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
#                     Mejora Continua
#                 </a>
#                 <div class="dropdown-menu" style="background:#454547;">
#                     <a class=" dropdown-item" href="#">CONTROL DE DOCUMENTOS</a>
#                     <a class=" dropdown-item" href="#">SISTEMA DE GESTIÓN INTEGRAL</a>
#                     <a class=" dropdown-item" href="#">SISTEMA DE G.DE IGUALDAD DE GÉNERO</a>
#                     <a class=" dropdown-item" href="#">BUZÓN DE QUEJAS Y SUGERENCIAS</a>
#                     <a class=" dropdown-item" href="#">INNOVACIÓN Y DESARROLLO (PIID ITLaguna)</a>
#
#                 </div>
#             </li>-->
#         </ul>
#     </div>
# </nav>
# <!-- Fin Menu Gris -->
#
# <!-- boostrap
# <script src="https://code.jquery.com/jquery-3.5.1.min.js" integrity="sha256-9/aliU8dGd2tb6OSsuzixeV4y/faTqgFtohetphbbj0=" crossorigin="anonymous"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.14.3/umd/popper.min.js" integrity="sha384-ZMP7rVo3mIykV+2+9J3UJ46jBk0WLaUAdn689aCwoqbBJiSnjAK/l8WvCWPIPm49" crossorigin="anonymous">
# </script>
# <script src="https://stackpath.bootstrapcdn.com/bootstrap/4.1.1/js/bootstrap.min.js" integrity="sha384-smHYKdLADwkXOn1EmN1qk/HfnUcbVRZyYmZ4qpPea6sjB/pTJ0euyQp0Mk8ck+5T" crossorigin="anonymous">
# </script>-->
#
#
#
#
#
#
#      <br/>
#
# <!-- Carousel Banners -->
#
# <div class="slideshow-container">
#
# <!--<div class="mySlides1">
#
#
#             <img src="slider/AVISovacuna.png" style="width:100%">
#     </div>
#     -->
#
#
#
#
#
#
# <div class="mySlides1">
#         <a href="avisos/registro-office.pdf">
#
#             <img src="slider/office.png" style="width:100%"/></a>
#     </div>
#     <div class="mySlides1">
#         <a href="https://www.tecnm.mx/menu/convocatorias_tecnm/01_InvCientifica_Academicos_Convocatoria_2021-2.pdf">
#
#             <img src="slider/convoinvest2.png" style="width:100%"/></a>
#     </div>
#
# <div class="mySlides1">
#         <a href="avisos/solicitud protocolos  titulación_mayo 2021.pdf">
#
#             <img src="slider/solicitud protocolos  titulación_mayo 2021.png" style="width:100%"/></a>
#     </div>
#
# <div class="mySlides1">
#         <a href="avisos/registro proyectos titulación_mayo 2021.pdf">
#
#             <img src="slider/registro proyectos titulación_mayo 2021.png" style="width:100%"/></a>
#     </div>
#
#
# <div class="mySlides1">
#         <a href="https://escolares.itlalaguna.edu.mx/web/index.php/entrega-de-certificados/">
#
#             <img src="slider/certificados2.png" style="width:100%"/></a>
#     </div>
#
#
# <div class="mySlides1">
#         <a href="ADMago.PHP">
#
#             <img src="slider/adm21ago2.png" style="width:100%"/></a>
#     </div>
#
#
#
#      <div class="mySlides1">
#
#        <img src="slider/puertas.jpg" style="width:100%"/>
#     </div>
#
#
#       <!-- <div class="mySlides1">
#         <a href="https://www.gob.mx/cms/uploads/attachment/file/617238/MANUTENCION_FEDERAL.pdf">
#
#             <img src="slider/becas.jpg" style="width:100%"></a>
#     </div>-->
#
# <div class="mySlides1">
#         <a href="http://mooc.tecnm.mx/">
#
#             <img src="slider/mooc.jpg" style="width:100%"/></a>
#     </div>
#
# <!--<div class="mySlides1">
#         <a href="https://docs.google.com/forms/d/e/1FAIpQLSeB0dMOHIapAMmylfW-sgKBPudl7-2krNWwB2Naud24UI0yaA/viewform?pli=1">
#
#             <img src="slider/ti2.jpg" style="width:100%"></a>
#     </div>
#
# <div class="mySlides1">
#         <a href="https://forms.gle/JqEd4btNsP73eRvJ8">
#
#             <img src="slider/protocolos.png" style="width:100%"></a>
#     </div>-->
# <div class="mySlides1">
#         <a href="avisos/convocatoria anfei.pdf">
#             <img src="slider/cienciasbasicas.png" style="width:100%"/></a>
#     </div>
#     <div class="mySlides1">
#         <a href="avisos/tripticoetica.pdf">
#             <img src="slider/tripticoetica.jpg" style="width:100%"/></a>
#     </div>
#
#
#
#
#
#
# <!--<div class="mySlides1">
#         <a href="AVISOS/CALENDARIOEJ21.PDF">
#             <img src="slider/CALENDARIOEJ212.png" style="width:100%"></a>
#     </div>-->
#
#
#     <div class="mySlides1">
#         <a href="https://docs.google.com/forms/d/e/1FAIpQLSeco-OxDhHp_81y0fcDNBKu0dPQakLceC1tHWM49gjPnJdurQ/viewform">
#             <img src="slider/bioetica.jpg" style="width:100%"/></a>
#     </div>
# <div class="mySlides1">
#         <a href="http://forms.gle/skuGWT2vabzxyDVp9">
#             <img src="slider/evalingles2.png" style="width:100%"/></a>
#     </div>
#
#
#
#     <div class="mySlides1">
#         <a href="avisos/ci2021.pdf">
#             <img src="slider/ci20212.png" style="width:100%"/></a>
#     </div>
#
#
#
#
#
#
#
#
# <div class="mySlides1">
#         <a href="AVISOS/anfei20.PDF">
#             <img src="slider/anfei202.png" style="width:100%"/></a>
#     </div>
#
#
#
#
#
# <div class="mySlides1">
#
#             <img src="slider/ingles203.jpg" style="width:100%"/>
#     </div>
#     <div class="mySlides1">
#         <a href="calidad/mejoracontinua.pdf">
#             <img src="slider/cero tolerancia2.jpg" style="width:100%"/></a>
#     </div>
#
#
#
#
#
#
# <div class="mySlides1">
#         <a href="../avisos/elibro.pdf">
#             <img src="slider/elibro2.png" style="width:100%"/></a>
#     </div>
#
#
#
#
#
#     <div class="mySlides1">
#         <a href="directorio.php">
#             <img src="slider/directorio212.png" style="width:100%"/></a>
#     </div>
#
#
#
#
#
#     <div class="mySlides1">
#
#         <img src="slider/redesof.png" style="width:100%"/>
#     </div>
#
#
#
#
#     <div class="mySlides1">
#         <a href="https://www.tecnm.mx/?vista=TecNM_Virtual"><img src="slider/tecnmvirtual2.jpg" style="width:100%"/></a>
#     </div>
#
#
#     <div class="mySlides1">
#         <a href="avisos/gradua202.pdf">
#
#             <img src="slider/gradua204.jpg" style="width:100%"/></a>
#     </div>
#
#     <div class="mySlides1">
#         <a href="https://bit.ly/2VGuGuK">
#             <img src="slider/protocolo202.jpg" style="width:100%"/></a>
#     </div>
#
#     <div class="mySlides1">
#         <a href="https://bit.ly/2Toczbt">
#             <img src="slider/cerotolerancia202.jpg" style="width:100%"/></a>
#     </div>
#
#
#
#
#
#
#     </div>
#
#
#
#
#
#     <a class="prev" onclick="plusSlides(-1, 0)">❮</a>
#     <a class="next" onclick="plusSlides(1, 0)">❯</a>
#
#         <div id="bolitas">
#             <span class="bolita" onclick="foto(1)"></span>
#             <span class="bolita" onclick="foto(2)"></span>
#             <span class="bolita" onclick="foto(3)"></span>
#             <span class="bolita" onclick="foto(4)"></span>
#             <span class="bolita" onclick="foto(5)"></span>
#             <span class="bolita" onclick="foto(6)"></span>
#             <span class="bolita" onclick="foto(7)"></span>
#             <span class="bolita" onclick="foto(8)"></span>
#             <span class="bolita" onclick="foto(9)"></span>
#             <span class="bolita" onclick="foto(10)"></span>
#             <span class="bolita" onclick="foto(11)"></span>
#             <span class="bolita" onclick="foto(12)"></span>
#             <span class="bolita" onclick="foto(13)"></span>
#             <span class="bolita" onclick="foto(14)"></span>
#             <span class="bolita" onclick="foto(15)"></span>
#             <span class="bolita" onclick="foto(16)"></span>
#             <span class="bolita" onclick="foto(17)"></span>
#             <span class="bolita" onclick="foto(18)"></span>
#             <!-- <span class="bolita" onclick="foto(19)">
#             </span>
#            <span class="bolita" onclick="foto(20)"></span>-->
#
#
#
#
#
#
#
#
#         </div>
#
#
#
#
#
#
#
#
#     <br/>
#     <br/>
#
#
#
#
#
# 	<!-- Dinamic Carousel  -->
#
#
# 		<div class="top-content" style="background:#19396a;">
# 			<div class="text-center text-white">
# 			<a href="new.php/?id=1326"><h1 class="align-center display-4">NOTICIAS</h1>	</a>
# 			</div>
# 			<div class="container-fluid">
# 				<div class="carousel slide" data-ride="carousel" id="carousel-example">
# 					<div class="carousel-inner row w-100 mx-auto" role="listbox">
# 						<div class="text-white carousel-item col-12 col-sm-6 col-md-4 col-lg-3 active">
# 							<h2> Noticias Recientes ITL </h2>
#   						</div>
# 			<div class="carousel-item col-12 col-sm-6 col-md-4 col-lg-3">
#
#
# 			<a href="new.php/?id=1345" id="carousel">
# 			<img alt="img" class="img-fluid mx-auto d-block" src="../../tec_noticias/imagenes_noticias/8778.jpg"/>
# 			</a>
#
# 				<a href="new.php/?id=1345" id="carousel">
# 				<h5>NUEVA JEFA DEL DEPARTAMENTO DE ING. QUÍMICA BIOQUÍMICA</h5>
# 				</a>
# 				<h6></h6>
#
#
# 				<a href="new.php/?id=1345" id="carousel" style="color: #dark blue !important;">
# 						LEER MAS
# 				</a>
#
#
# 			</div>
#
# 			<div class="carousel-item col-12 col-sm-6 col-md-4 col-lg-3">
#
#
# 			<a href="new.php/?id=1343" id="carousel">
# 			<img alt="img" class="img-fluid mx-auto d-block" src="../../tec_noticias/imagenes_noticias/8760.jpg"/>
# 			</a>
#
# 				<a href="new.php/?id=1343" id="carousel">
# 				<h5>PRIMERA SESIÓN DEL CONSEJO DE VINCULACIÓN 2021 DEL TECNM CAMPUS LA LAGUNA</h5>
# 				</a>
# 				<h6></h6>
#
#
# 				<a href="new.php/?id=1343" id="carousel" style="color: #dark blue !important;">
# 						LEER MAS
# 				</a>
#
#
# 			</div>
#
# 			<div class="carousel-item col-12 col-sm-6 col-md-4 col-lg-3">
#
#
# 			<a href="new.php/?id=1344" id="carousel">
# 			<img alt="img" class="img-fluid mx-auto d-block" src="../../tec_noticias/imagenes_noticias/8768.jpg"/>
# 			</a>
#
# 				<a href="new.php/?id=1344" id="carousel">
# 				<h5>RECONOCEN TRAYECTORIA LABORAL</h5>
# 				</a>
# 				<h6></h6>
#
#
# 				<a href="new.php/?id=1344" id="carousel" style="color: #dark blue !important;">
# 						LEER MAS
# 				</a>
#
#
# 			</div>
#
# 			<div class="carousel-item col-12 col-sm-6 col-md-4 col-lg-3">
#
#
# 			<a href="new.php/?id=1342" id="carousel">
# 			<img alt="img" class="img-fluid mx-auto d-block" src="../../tec_noticias/imagenes_noticias/8753.jpg"/>
# 			</a>
#
# 				<a href="new.php/?id=1342" id="carousel">
# 				<h5>   TECNM CAMPUS LA LAGUNA, EN LA LUCHA CONTRA EL CÁNCER DE MAMA.   </h5>
# 				</a>
# 				<h6></h6>
#
#
# 				<a href="new.php/?id=1342" id="carousel" style="color: #dark blue !important;">
# 						LEER MAS
# 				</a>
#
#
# 			</div>
#
# 			<div class="carousel-item col-12 col-sm-6 col-md-4 col-lg-3">
#
#
# 			<a href="new.php/?id=1341" id="carousel">
# 			<img alt="img" class="img-fluid mx-auto d-block" src="../../tec_noticias/imagenes_noticias/8746.jpg"/>
# 			</a>
#
# 				<a href="new.php/?id=1341" id="carousel">
# 				<h5>TOMA DE PROTESTA DEL CAPÍTULO ESTUDIANTIL DE ING. MECATRÓNICA</h5>
# 				</a>
# 				<h6></h6>
#
#
# 				<a href="new.php/?id=1341" id="carousel" style="color: #dark blue !important;">
# 						LEER MAS
# 				</a>
#
#
# 			</div>
#
# 			<div class="carousel-item col-12 col-sm-6 col-md-4 col-lg-3">
#
#
# 			<a href="new.php/?id=1340" id="carousel">
# 			<img alt="img" class="img-fluid mx-auto d-block" src="../../tec_noticias/imagenes_noticias/8740.jpg"/>
# 			</a>
#
# 				<a href="new.php/?id=1340" id="carousel">
# 				<h5>SE CERTIFICAN EN ESTANDAR DE COMPETENCIA LABORAL EC0264 -SEIS SIGMA- A ESTUDIANTES DEL TECNM </h5>
# 				</a>
# 				<h6></h6>
#
#
# 				<a href="new.php/?id=1340" id="carousel" style="color: #dark blue !important;">
# 						LEER MAS
# 				</a>
#
#
# 			</div>
#
# 			<div class="carousel-item col-12 col-sm-6 col-md-4 col-lg-3">
#
#
# 			<a href="new.php/?id=1339" id="carousel">
# 			<img alt="img" class="img-fluid mx-auto d-block" src="../../tec_noticias/imagenes_noticias/8736.jpg"/>
# 			</a>
#
# 				<a href="new.php/?id=1339" id="carousel">
# 				<h5>CAMPUS LA  LAGUNA Y CAMPUS TORREÓN DEL TECNM PACTAN CONVENIO DE COLABORACIÓN</h5>
# 				</a>
# 				<h6></h6>
#
#
# 				<a href="new.php/?id=1339" id="carousel" style="color: #dark blue !important;">
# 						LEER MAS
# 				</a>
#
#
# 			</div>
#
# 			<div class="carousel-item col-12 col-sm-6 col-md-4 col-lg-3">
#
#
# 			<a href="new.php/?id=1338" id="carousel">
# 			<img alt="img" class="img-fluid mx-auto d-block" src="../../tec_noticias/imagenes_noticias/8722.jpg"/>
# 			</a>
#
# 				<a href="new.php/?id=1338" id="carousel">
# 				<h5>CEREMONIA DE INVESTIDURA MESA DIRECTIVA FUNDADORA IISE MÉXICO</h5>
# 				</a>
# 				<h6></h6>
#
#
# 				<a href="new.php/?id=1338" id="carousel" style="color: #dark blue !important;">
# 						LEER MAS
# 				</a>
#
#
# 			</div>
#
# 			<div class="carousel-item col-12 col-sm-6 col-md-4 col-lg-3">
#
#
# 			<a href="new.php/?id=1336" id="carousel">
# 			<img alt="img" class="img-fluid mx-auto d-block" src="../../tec_noticias/imagenes_noticias/8705.jpg"/>
# 			</a>
#
# 				<a href="new.php/?id=1336" id="carousel">
# 				<h5>MILWAUKEE TOOLS COMPANY: EN VISIÓN DE COLABORACIÓN CON EL TECNM CAMPUS LA LAGUNA</h5>
# 				</a>
# 				<h6></h6>
#
#
# 				<a href="new.php/?id=1336" id="carousel" style="color: #dark blue !important;">
# 						LEER MAS
# 				</a>
#
#
# 			</div>
#
# 			<div class="carousel-item col-12 col-sm-6 col-md-4 col-lg-3">
#
#
# 			<a href="new.php/?id=1337" id="carousel">
# 			<img alt="img" class="img-fluid mx-auto d-block" src="../../tec_noticias/imagenes_noticias/8714.jpg"/>
# 			</a>
#
# 				<a href="new.php/?id=1337" id="carousel">
# 				<h5>CAPITULO ESTUDIANTIL SALSS.DEL TECNM CAMPUS LA LAGUNA RENUEVA SU MESA DIRECTIVA</h5>
# 				</a>
# 				<h6></h6>
#
#
# 				<a href="new.php/?id=1337" id="carousel" style="color: #dark blue !important;">
# 						LEER MAS
# 				</a>
#
#
# 			</div>
#
#
# 		</div>
# 			<a class="carousel-control-prev" data-slide="prev" href="#carousel-example" role="button">
# 				<span aria-hidden="true" class="carousel-control-prev-icon"></span>
# 				<span class="sr-only">Previous</span>
# 			</a>
#
# 			<a class="carousel-control-next" data-slide="next" href="#carousel-example" role="button">
# 				<span aria-hidden="true" class="carousel-control-next-icon"></span>
# 				<span class="sr-only">Next</span>
# 			</a>
#
#
# 			</div>
# 		</div>
# 		<br/><br/>
# 	</div>
# 	<br/><br/><br/>
#
#
#
#         <!-- Javascript -->
# 		<!--<script src="js/jquery-3.3.1.min.js"></script>
# 		<script src="js/jquery-migrate-3.0.0.min.js"></script>
# 		<script src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.14.6/umd/popper.min.js" integrity="sha384-wHAiFfRlMFy6i5SRaxvfOCifBUQy1xHdJ/yoi7FRNXMRBu5WHdZYu1hA6ZOblgut" crossorigin="anonymous"></script>
# 		<script src="https://stackpath.bootstrapcdn.com/bootstrap/4.2.1/js/bootstrap.min.js" integrity="sha384-B0UglyR+jN6CkvvICOB2joaf5I4l3gm9GU6Hc1og6Ls7i6U/mkkaduKaBhlAXv9k" crossorigin="anonymous"></script>
#         <script src="js/jquery.backstretch.min.js"></script>
#         <script src="js/wow.min.js"></script>
#         <script src="js/scripts.js"></script>-->
#
#
#
#
#
#
#
#
#
#
#     <section id="Section1" style="background-color: #efefef; width:85%; margin:auto; padding-bottom:15px;">
#
#         <center>
#             <h2 class="mbr-section-title pb-3 align-center mbr-fonts-style display-4" style="margin-bottom: 15px; margin: auto;">
#                 Síguenos
#             </h2>
#         </center>
#
#         <div class="media-container-row" style="text-align:center">
#
#             <!--Twitter-->
#             <span style="margin-top:15px;">
#                 <a class="twitter-timeline" data-dnt="true" data-height="525" data-lang="es" data-theme="light" data-width="330" href="https://twitter.com/itlalaguna?ref_src=twsrc%5Etfw">Tweets by
#                     itlalaguna</a>
#                 <script async="" charset="utf-8" src="https://platform.twitter.com/widgets.js"></script>
#             </span>
#
#             <!--Youtube-->
#             <iframe allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" frameborder="0" height="525" src="https://www.youtube.com/embed/swACDm94S5g" style="margin-top:15px;" width="280"></iframe>
#
#             <!--Facebook-->
#             <iframe allow="encrypted-media" allowtransparency="true" frameborder="0" height="525" scrolling="no" src="https://www.facebook.com/plugins/page.php?href=https%3A%2F%2Fwww.facebook.com%2FtecLaguna%2F&amp;tabs=timeline&amp;width=340&amp;height=500&amp;small_header=false&amp;adapt_container_width=true&amp;hide_cover=false&amp;show_facepile=false&amp;appId" style="margin-top:15px;" width="280"></iframe>
#
#
#                 <div style="width: 100%; align-items:center;">
#                         <div class="tecCar">
#
#                         <div><a href="CALIDAD.PHP"><img alt="" class="center" src="img/anexos/SG.png"/></a></div>
#                         <div><a href="https://www.tecnm.mx/?vista=Protocolo_Actuacion"><img alt="" class="center" src="img/anexos/Boton_Actuacion.png"/></a></div>
#                         <div><a href="https://www.tecnm.mx/archivos/anexos/M00-CC-01_Codigo_de_Conducta_del_TecNM.pdf"><img alt="" class="center" src="img/anexos/codigo conducta btn.png"/></a></div>
#                         <div><a href="https://www.tecnm.mx/archivos/anexos/SFP-CE-2019_C%C3%B3digo_de_%C3%89tica.pdf"><img alt="" class="center" src="img/anexos/codigo etica btn.png"/></a></div>
#                         <div><a href="https://www.tecnm.mx/?vista=Comite_Etica_CEPCI"><img alt="" class="center" src="img/anexos/logoetica.png"/></a></div>
#                         <!--<div><a href=""><img class="center" src="img/anexos/convocatoria_seguro_btn.png" alt=""></a></div>-->
#                         <div><a href="piid.php"><img alt="" class="center" src="img/anexos/logopiid.png"/></a></div>
#                         <div><a href="https://www.tecnm.mx/archivos/anexos/PRONTUARIO%20-%20Difusion%20Digital.pdf"><img alt="" class="center" src="img/anexos/prontuario.png"/></a></div>
#                         <div><a href="https://www.tecnm.mx/archivos/anexos/Pronunciamiento%20Cero%20Tolerancia%20al%20Hostigamiento%20y%20Acoso%20Sexual%20en%20el%20TecNM.pdf"><img alt="" class="center" src="img/anexos/pronunciamiento.png"/></a></div>
#                         <div><a href="https://www.tecnm.mx/archivos/anexos/ANEXO%201%20Protocolo%20HSyAS.pdf"><img alt="" class="center" src="img/anexos/protocolo prevencion btn.png"/></a></div>
#
#                         <div><a href="transp.php"><img alt="" class="center" src="img/anexos/transparencia.png"/></a></div>
#                         <div><a href="proveedores.php"><img alt="" class="center" src="img/anexos/proveedoresgris.png"/></a></div>
#                         <div><a href="historial.php"><img alt="" class="center" src="img/anexos/historialgris.png"/></a></div>
#                         </div>
#                 </div>
#
#         </div>
#     </section>
#
#     <!------------------------------------------BOT-------------------------------------------------------- -->
# <div class="tecbot-container" id="contenedorBot">
# ...
#                         scrollTop: $('#chatContainer').prop("scrollHeight")
#                     }, 500);
#                 } catch (error) {
#                     var botHtml =
#                         '<div class="tecbot-msgBot" style="display: inline-block;"><p class=" tecbot-msgBotText">' +
#                         data + '</p></div>';
#                     chat.append(botHtml);
#                     var menuReturn =
#                         '<div class="tecbot-msgBot" style="display: inline-block;"><p class=" tecbot-msgBotText"><button class="menu-option" onclick="menuInicial()">Volver a menú</button></p></div>';
#                     chat.append(menuReturn);
#                     $("#chatContainer").animate({
#                         scrollTop: $('#chatContainer').prop("scrollHeight")
#                     }, 500);
#                 }
#             });
#         }
#
#     </script>
#     <!------------------------------------------BOT--------------------------------------------------------->
#
#
#     <!-- Otras Páginas -->
#
# <section class="" id="features3-2" style="width:100%; margin: auto; margin-bottom: 2%; margin-top:2%; background-color: #efefef;">
#     <center>
#         <h2 class="mbr-section-title pb-3 align-center mbr-fonts-style display-2">
#             Sitios de Interés
#         </h2>
#     </center>
#
#     <div align="center">
#
# <a href="https://www.conacyt.gob.mx/" target="_blank">
#     <img alt="concyt" src="img/interes/CONACYT.png" style="width:16%;" title="CONACYT"/>
# </a>
#
# <a href="https://www.conricyt.mx/" target="_blank">
#      <img alt="conricyt" src="img/interes/CONRICYT.png" style="width:16%;" title="CONRICYT"/>
# </a>
#
# <a href="http://www.ifai.org.mx/" target="_blank">
#     <img alt="inai" src="img/interes/INAI.png" style="width:16%;" title="INAI"/>
# </a>
#
# <a href="prodep/docu.htmL" target="_blank">
#     <img alt="contraloria" src="img/interes/CONtraloria.png" style="width:16%;" title="CONACYT"/></a>
#
# <a href="http://consultapublicamx.inai.org.mx:8080/vut-web/?idSujetoObigadoParametro=10009&amp;idEntidadParametro=33&amp;idSectorParametro=21" target="_blank">
#     <img alt="pnt" src="img/interes/PNT.png" style="width:16%;" title=""/>
# </a>
#
#
#
#     <br/>
#     <a href="becasint/becasint.html" target="_blank">
#     <img alt="convocatorias" src="img/interes/convocatorias.png" style="width:11%;" title=""/></a>
#
# <a href="pulsotec/pulsotecdigital.html" target="_blank"><img alt="pulsotec" src="img/interes/revista.png" style="width:11%;" title=""/></a><a href="bolsadetrabajo.html" target="_blank"><img alt="bolsa" src="img/interes/bolsa.png" style="width:11%;" title=""/></a>
#     <a href="seguimientoegresados.html" target="_blank"><img alt="egresados" src="img/interes/egresados.png" style="width:11%;" title=""/></a>
#
#     <a href="AVISOS/CALENDARIO.PDF" target="_blank"><img alt="egresados" src="img/interes/calendario.png" style="width:11%;" title=""/></a>
#
#     <a href="recbiblio.php"><img alt="egresados" src="img/interes/recursosbiblio.png" style="width:11%;" title=""/></a>
#     <a href="https://docs.google.com/forms/d/e/1FAIpQLSckSqRPLi4GVYVthg5wP034P8tiEgBhyLnNcd6JCc7ZkE1KGg/viewform?entry.1159593137=nombre&amp;entry.1809109965&amp;entry.1214002645&amp;entry.1344596603&amp;entry.1727722980&amp;entry.1573787809=nombre+completo&amp;entry.471819699=puesto&amp;entry.285911030=ITL&amp;entry.134294733=2018-03-03&amp;entry.1785309787=20:00&amp;entry.1084813065=ITL&amp;entry.1814560733=hechos&amp;entry.1641027819=Nombre+testigo&amp;entry.1484745992=Domicilio+testigo&amp;entry.769034671=S%C3%AD&amp;entry.1684521492=si1&amp;entry.1680632340=si2"><img alt="egresados" src="img/interes/buzond.png" style="width:11%;" title=""/></a>
#     <a href="https://docs.google.com/forms/d/e/1FAIpQLSddMvuMgSe8qJ63G7op3Pcr5-VEuV2_UPElM977PS9lm8faug/viewform"><img alt="egresados" src="img/interes/buzonq.png" style="width:11%;" title=""/></a>
#     </div>
#
# </section>
#
# <!--footer gris-->
#
# <!--ajustes fooder-->
# <style>
#     p#pie {
#         color: white;
#         font-family: century gothic;
#     }
#
#     h3#pie {
#         color: yellow;
#         margin-top: 10%;
#         font-family: century gothic;
#     }
#
#     h4#pie {
#         color: white;
#         margin-top: 10%;
#         font-family: century gothic;
#     }
#
#     a#pie {
#         font-family: century gothic;
#     }
#
#     div#sep {
#         height: 5%;
#         background: #0b231e;
#         width: 100%;
#     }
# </style>
#
# <!-- fooder gris-->
# <footer>
#     <div class="bg-secondary" style="background: #454547 !important;">
#         <div class="container">
#             <div class="row">
#
#                 <div class="col-lg-3">
#                     <h3 id="pie"> Dirección</h3>
#                     <p id="pie">Blvd. Revolución y Av. Instituto Tecnológico de La Laguna, Torreón, Coahuila, C.P. 27000
#                        <br/>  <a href="https://www.netacad.com/es">  <img alt="cisco" src="cisco.png" width="103"/></a>
#                         <br/><br/><a href="CALIDAD.PHP">  <img alt="iso" src="isogde.png" width="203"/></a>
#
#
#
#                    </p>
#
#                 </div>
#
#                 <div class="col-lg-3">
#                     <h3 id="pie"> Contacto</h3>
#                     <p id="pie" style="color: white;">Email: webmaster@correo.itlalaguna.edu.mx
#                         Teléfono: 52 (871) 705-13-13 </p>
#                 </div>
#
#                 <div class="col-lg-3">
#                     <h3 id="pie"> Enlaces </h3>
#                     <ul class="list-unsyled">
#                         <li><a href="http://portaltransparencia.gob.mx/buscador/search/search.do?method=begin" id="pie" style="color:#fff">Portal
#                                 de Obligaciones de Transparencia</a></li>
#                         <li><a href="http://inicio.ifai.org.mx/SitePages/ifai.aspx" id="pie" style="color:#fff">INAI</a>
#                         </li>
#                         <li><a data-target="#modalQuejas" data-toggle="modal" href="#" id="pie" style="color:#fff">Buzón
#                                 de Sugerencias</a></li>
#                         <li><span data-target="#modalQuejas" data-toggle="modal" href="#" id="pie" style="color:#fff">Visitas</span>
#
#
#
# <!-- Histats.com  START  (standard)-->
# <script type="text/javascript">document.write(unescape("%3Cscript src=%27http://s10.histats.com/js15.js%27 type=%27text/javascript%27%3E%3C/script%3E"));</script>
# <a href="http://www.histats.com" target="_blank" title="contadores web free"><script type="text/javascript">
# try {Histats.start(1,1838853,4,4003,112,61,"00011011");
# Histats.track_hits();} catch(err){};
# </script></a>
# <noscript></noscript>
# <!-- Histats.com  END  -->
#
#
#
# <!-- Start of StatCounter Code -->
#
# <script type="text/javascript">
# var sc_project=7949821;
# var sc_invisible=1;
# var sc_partition=59;
# var sc_click_stat=1;
# var sc_security="8c4af0fe";
# </script>
#
# <script src="http://www.statcounter.com/counter/counter.js" type="text/javascript"></script>
# <!-- End of StatCounter Code --><br/>
# <a href="http://my.statcounter.com/project/standard/stats.php?project_id=7949821&amp;guest=1" onclick="_gaq.push(['_trackEvent','links menu', 'abandono', 'estadisticas']);" target="_blank">Estadísticas</a>
#
#
#    <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-54252992-1', 'auto');
#   ga('send', 'pageview');
#
# </script>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                             </li>
#
#
#
#
#
#
#
#
#                     </ul>
#                 </div>
#
#                 <div class="col-lg-3">
#                     <h3 id="pie"> Ubicación </h3>
#                     <img height="70%" src="img/ubicacionITL.jpeg" width="100%"/>
#                     <a href="infra.php" id="pie"> Ver Ubicación </a>
#                 </div>
#
#             </div>
#         </div>
#         <br/>
#     </div>
#     <!--Fin fooder gris-->
#
#     <div id="sep">
#         <br/>
#     </div>
#     <!-- fooder verde-->
#     <footer class="main-footer" style="background: url(img/banners/fondofooter.jpg)">
#         <div class="list-info">
#             <div class="container">
#                 <div class="row">
#                     <div class="col-md-3" style="margin-top: 15%;">
#                         <img alt="logo gobierno de méxico" class="logo_footer" data-v-9e928f9a="" href="/" src="https://framework-gb.cdn.gob.mx/landing/img/logoheader.svg" style="margin-top: 5%;"/>
#                     </div>
#
#                     <div class="col-sm-3">
#                         <h4 id="pie">Enlaces</h4>
#                         <ul>
#                             <li><a href="https://participa.gob.mx" rel="noopener" target="_blank" title="Enlace abre en ventana nueva">Participa</a></li>
#                             <li><a href="https://www.gob.mx/publicaciones" rel="noopener" target="_blank" title="Enlace abre en ventana nueva">Publicaciones Oficiales</a></li>
#                             <li><a href="http://www.ordenjuridico.gob.mx" rel="noopener" target="_blank" title="Enlace abre en ventana nueva">Marco Jurídico</a></li>
#                             <li><a href="https://consultapublicamx.inai.org.mx/vut-web/" rel="noopener" target="_blank" title="Enlace abre en ventana nueva">Plataforma Nacional de Transparencia</a></li>
#                         </ul>
#                     </div>
#
#                     <div class="col-sm-3">
#                         <h4 id="pie">¿Qué es gob.mx?</h4>
#                         <p id="pie">Es el portal único de trámites, información y participación ciudadana. <a href="https://www.gob.mx/que-es-gobmx">Leer más</a></p>
#                         <ul>
#                             <li><a href="https://datos.gob.mx">Portal de datos abiertos</a></li>
#                             <li><a href="https://www.gob.mx/accesibilidad">Declaración de accesibilidad</a></li>
#                             <li><a href="https://www.gob.mx/privacidadintegral">Aviso de privacidad integral</a></li>
#                             <li><a href="https://www.gob.mx/privacidadsimplificado">Aviso de privacidad simplificado</a>
#                             </li>
#                             <li><a href="https://www.gob.mx/terminos">Términos y Condiciones</a></li>
#                             <li><a href="https://www.gob.mx/terminos#medidas-seguridad-informacion">Política de
#                                     seguridad</a></li>
#                             <li><a href="https://www.gob.mx/sitemap">Mapa de sitio</a></li>
#                         </ul>
#                     </div>
#
#                      <div class="col-sm-3">
#                         <h4 id="pie"><a href="https://www.gob.mx/tramites/ficha/presentacion-de-quejas-y-denuncias-en-la-sfp/SFP54">Denuncia
#                                 contra servidores públicos</a></h4> <br/><br/>
#                         <h4 id="pie">Síguenos en</h4>
#                         <h4><a aria-label="Facebook de presidencia" class="social-icon facebook" href="https://www.facebook.com/gobmexico" rel="noopener" target="_blank" title="Enlace abre en ventana nueva"><img alt="facebook" src="img/redes_sociales/faceb.png" width="10%"/></a><a aria-label="Twitter de presidencia" class="social-icon twitter" href="https://twitter.com/GobiernoMX" rel="noopener" target="_blank" title="Enlace abre en ventana nueva"><img alt="facebook" src="img/redes_sociales/twitt.png" width="10%"/></a></h4>
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </footer>
#     <!-- fin fooder verde-->
#
#     <div id="sep">
#         <br/>
#     </div>
#
#     <!-- boostrap -->
#     <script crossorigin="anonymous" integrity="sha256-9/aliU8dGd2tb6OSsuzixeV4y/faTqgFtohetphbbj0=" src="https://code.jquery.com/jquery-3.5.1.min.js"></script>
#     <script crossorigin="anonymous" integrity="sha384-ZMP7rVo3mIykV+2+9J3UJ46jBk0WLaUAdn689aCwoqbBJiSnjAK/l8WvCWPIPm49" src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.14.3/umd/popper.min.js">
#     </script>
#     <script crossorigin="anonymous" integrity="sha384-smHYKdLADwkXOn1EmN1qk/HfnUcbVRZyYmZ4qpPea6sjB/pTJ0euyQp0Mk8ck+5T" src="https://stackpath.bootstrapcdn.com/bootstrap/4.1.1/js/bootstrap.min.js">
#     </script>
#     <script src="js/jquery.backstretch.min.js"></script>
#     <script src="js/wow.min.js"></script>
#     <script src="js/scripts.js"></script>
#     <script src="js/slick.min.js" type="text/javascript"></script>
#
#     <script>
#     console.log("Footer cargado");
#         //Navbar
#         $('.dropdown-menu a.dropdown-toggle').on('click', function (e) {
#             if (!$(this).next().hasClass('show')) {
#                 $(this).parents('.dropdown-menu').first().find('.show').removeClass('show');
#             }
#             var $subMenu = $(this).next('.dropdown-menu');
#             $subMenu.toggleClass('show');
#
#
#             $(this).parents('li.nav-item.dropdown.show').on('hidden.bs.dropdown', function (e) {
#                 $('.dropdown-submenu .show').removeClass('show');
#             });
#
#
#             return false;
#         });
#
#         //Si existe el elemento con id tecCar, quiere decir que es el index y a continuacion se ejecuta el codigo del index
#         if ($('.tecCar').length) {
#
#             //Script works to Carousel
#             var slideIndex = [1, 1];
#             var slideId = ["mySlides1", "mySlides2"];
#             var bolitas = document.getElementsByClassName("bolita");
#             var i = 1;
#
#             showSlides(1, 0);
#             //showSlides(1, 1);
#
#             function plusSlides(n, no) {
#                 showSlides(slideIndex[no] += n, no);
#             }
#
#             function foto(n, interval = true) {
#                 if (interval)
#                     i = n;
#                 showSlides(slideIndex[0] = n, 0);
#             }
#
#             function showSlides(n = 1, no = 0) {
#                 var i;
#                 var x = document.getElementsByClassName(slideId[no]);
#                 if (n > x.length) {
#                     slideIndex[no] = 1
#                 }
#                 if (n < 1) {
#                     slideIndex[no] = x.length
#                 }
#                 for (i = 0; i < x.length; i++) {
#                     x[i].style.display = "none";
#                 }
#                 for (var i = 0; i < bolitas.length; i++) {
#                     bolitas[i].className = bolitas[i].className.replace("activo", "");
#                 }
#                 x[slideIndex[no] - 1].style.display = "block";
#                 bolitas[slideIndex[no] - 1].className += " activo";
#             }
#
#             //Transcición automatica para el banner
#             $(document).ready(function () {
#                 setInterval(function () {
#                     if (i == 36) {
#                         i = 1;
#                     }
#                     foto(i++, false);
#                 }, 3000);
#             });
#
#
#             //Carusel gris
#             if (screen.width < 1024) {
#                 $('.tecCar').slick({
#                     infinite: true,
#                     slidesToShow: 2,
#                     slidesToScroll: 1,
#                     nextArrow: '<button type="button" class="slick-next"><i class="next fas fa-arrow-circle-right"></i></button>',
#                     prevArrow: '<button type="button" class="slick-prev"><i class="prev fas fa-arrow-circle-left"></i></button>'
#                 });
#             } else {
#                 $('.tecCar').slick({
#                     infinite: true,
#                     slidesToShow: 4,
#                     slidesToScroll: 1,
#                     nextArrow: '<button type="button" class="slick-next"><i class="next fas fa-arrow-circle-right"></i></button>',
#                     prevArrow: '<button type="button" class="slick-prev"><i class="prev fas fa-arrow-circle-left"></i></button>'
#                 });
#             }
#         }
#     </script>
#
#
#
#     </footer></body></html><!-- Redes Sociales Vista -->

# %%
sopa.title
# Out:
# <title>Instituto Tecnológico de La Laguna</title>

# %%
type(sopa.title)
# Out:
# bs4.element.Tag

# %%
sopa.title.text
# Out:
# 'Instituto Tecnológico de La Laguna'

# %%
sopa.body.text
# Out:
# '\n    \n\n/*     $(\'.dropdown-menu a.dropdown-toggle\').on(\'click\', function(e) {\n        if (!$(this).next().hasClass(\'show\')) {\n            $(this).parents(\'.dropdown-menu\').first().find(\'.show\').removeClass(\'show\');\n        }\n        var $subMenu = $(this).next(\'.dropdown-menu\');\n        $subMenu.toggleClass(\'show\');\n\n\n        $(this).parents(\'li.nav-item.dropdown.show\').on(\'hidden.bs.dropdown\', function(e) {\n            $(\'.dropdown-submenu .show\').removeClass(\'show\');\n        });\n\n \n        return false;\n    }); */\n\n\n\n\n    a {\n        color: white !important;\n        font-size: large;\n    }\n\n    @media (min-width: 960px) {\n        .dropdown:hover>.dropdown-menu {\n            display: block;\n        }\n\n        \n    }\n\n    .dropdown-submenu {\n        position: relative;\n    }\n\n    .dropdown-submenu a::after {\n        transform: rotate(-90deg);\n        position: absolute;\n        right: 6px;\n        top: .8em;\n    }\n\n    .dropdown-submenu {\n        position: relative;\n    }\n\n    .dropdown-submenu .dropdown-menu {\n        top: 0;\n        left: 100%;\n        margin-top: -1px;\n    }\n\n    .dropdown-submenu .dropdown-menu {\n        top: 0;\n        left: 100%;\n        margin-left: .1rem;\n        margin-right: .1rem;\n\n    }\n\n    #navbarDropdown {\n        cursor: pointer;\n    }\n\n    /*\n  nav>a:hover {\n    display:block;\n    cursor: pointer;\n    color: tomato;\n    background-color:white;\n    transition: background-color .5s;\n    opacity: 0.05;*/\n\n    div.dropdown-menu a:hover {\n        background-color: #363636;\n        align-content: center;\n    }\n\n    .navbar-nav li:hover>ul.dropdown-menu {\n        display: block;\n    }\n\n    .dropdown-submenu {\n        position: relative;\n    }\n\n    .dropdown-submenu>.dropdown-menu {\n        top: 0;\n        left: 100%;\n        margin-top: -6px;\n    }\n\n    /* rotate caret on hover */\n    .dropdown-menu>li>a:hover:after {\n        text-decoration: underline;\n        transform: rotate(-90deg);\n    }\n\n    div.dropdown-menu a:hover {\n      background-color: #363636;\n      align-content: center;\n    }\n\n    /*Fix imagen inicio del header*/\n    @media (max-width: 960px) {\n        .img-inicio-fix{\n            width: 30px !important;\n        }\n    }\n    .img-inicio-fix{\n        width: 50px;\n    }\n\n\n\n\n\n    \n        \n    \n\n    \n        \n    \n    \n        \n            \n                 (current)\n            \n\n        \n        \n            \n                 Gobierno\n            \n\n            \n                Participa\n            \n\n            \n                Datos\n            \n\n            \n                \n                    Búsqueda\n                    \n                        \n                    \n                \n            \n\n        \n    \n\n\n\n\n\n\n\n\n    \n        \n    \n    \n        \n    \n    \n        \n    \n    \n        \n    \n\n\n\n\n\n\n\n    \n    \n        \n    \n\n\n    \n    \n        \n\n            \n                \n                \n                \n            \n            \n                \n                    Directorio\n                \n            \n            \n            \n\n                \n                    ¿Quiénes Somos?\n                \n                \n\n                    HISTORIA\n                    MISIÓN Y VISIÓN\n                    UBICACIÓN E INFRAESCTRUCTURA\n                    CUIDADO DEL MEDIO AMBIENTE\n                    MASCOTA Y LOGOS\n                    \n                    \n                    \n                    BUZÓN DE QUEJAS Y SUGERENCIAS\n                    \n                    \n                        FORMATO DE DENUNCIAS DEL SG DE\n                        IGUALDAD DE GÉNERO Y NO DISCRIMINACIÓN\n\n                    CÓDIGO DE ÉTICA Y CONDUCTA\n                    NORMATECA  DEL TECNM\n                    \n\n                \n            \n     ...

# %%
lista = sopa.body.select('div')

# %%
lista[10]
# Out:
# <div class="dropdown-menu" style="background:#454547;">
#
#                    <!-- <a class="text-black dropdown-item" href="http://apps2.itlalaguna.edu.mx:8081/">LICENCIATURA</a>-->
#                    <a class="text-black dropdown-item" href="ADMago.PHP">LICENCIATURA AGOSTO - DICIEMBRE</a>
#                    <a class="text-black dropdown-item" href="ADMcpago.PHP">POSGRADO AGOSTO - DICIEMBRE</a>
#                    <a class="text-black dropdown-item" href="nivelacion.php">NIVELACIÓN AGOSTO - DICIEMBRE</a>
#                    <a class="text-black dropdown-item" href="ADM.PHP">LICENCIATURA ENERO - JUNIO</a>
#                     <a class="text-black dropdown-item" href="ADMcp.PHP">POSGRADO ENERO - JUNIO</a>
#
#
#
#                     <!--<a class="text-black dropdown-item" href="ADMdis.PHP">LICENCIATURA MODALIDAD A DISTANCIA</a>-->
#
#                   <!--  <a class="text-black dropdown-item" href="distancia.php">INGRESO A DISTANCIA</a>-->
#                 </div>

# %%
[e for e in lista]
# Out:
# [<div class="collapse navbar-collapse" id="navbarNav">
#          <ul class="navbar-nav mr-auto">
#              <li class="nav-item active">
#                  <a class="nav-link" href="#"> <span class="sr-only">(current)</span></a>
#              </li>
#
#          </ul>
#          <ul class="navbar-nav" style="margin-right: 10%;">
#              <li class="nav-item">
#                  <a class="nav-link" href="https://www.gob.mx/gobierno" style="color: white;"> Gobierno</a>
#              </li>
#
#              <li class="nav-item">
#                  <a class="nav-link" href="https://www.gob.mx/participa" style="color: white;">Participa</a>
#              </li>
#
#              <li class="nav-item">
#                  <a class="nav-link" href="https://datos.gob.mx " style="color: white;">Datos</a>
#              </li>
#
#              <li class="nav-item">
#                  <a class="nav-item nav-link active" href="https://www.gob.mx/busqueda" style="color: white;">
#                      <span class="sr-only">Búsqueda</span>
#                      <svg aria-hidden="true" class="svg-inline--fa fa-search fa-w-16" data-fa-i2svg="" data-icon="search" data-prefix="fas" focusable="false" height="18" role="img" viewBox="0 0 512 512" width="18" xmlns="http://www.w3.org/2000/svg">
#                          <path d="M505 442.7L405.3 343c-4.5-4.5-10.6-7-17-7H372c27.6-35.3 44-79.7 44-128C416 93.1 322.9 0 208 0S0 93.1 0 208s93.1 208 208 208c48.3 0 92.7-16.4 128-44v16.3c0 6.4 2.5 12.5 7 17l99.7 99.7c9.4 9.4 24.6 9.4 33.9 0l28.3-28.3c9.4-9.4 9.4-24.6.1-34zM208 336c-70.7 0-128-57.2-128-128 0-70.7 57.2-128 128-128 70.7 0 128 57.2 128 128 0 70.7-57.2 128-128 128z" fill="currentColor"></path>
#                      </svg><!-- <i class="fas fa-search"></i> -->
#                  </a>
#              </li>
#
#          </ul>
#      </div>,
#  <div style="background-color: fff; width: 90%;
#             margin-left: 5%; margin-right:5%; margin-top:2%; margin-bottom:2%;">
#
#      <a href="https://www.gob.mx/">
#          <img alt="Gobierno de México" src="img/logotipos/pleca-gob1.png" style="width:30%;height:auto"/>
#      </a>
#      <a href="https://www.gob.mx/sep">
#          <img alt="Educación" src="img/logotipos/pleca-gob2.png" style="width:30%;height:auto; min-width:auto;"/>
#      </a>
#      <a href="https://www.tecnm.mx/">
#          <img alt="TecNM" src="img/logotipos/pleca_tecnm.jpg" style="width:18%;height:auto; "/>
#      </a>
#      <a href="https:/www.itlalaguna.edu.mx/">
#          <img alt="ITL" src="img/logotipos/itl2.jpeg" style="width:7%; height:auto;"/>
#      </a>
#  </div>,
#  <div class="collapse navbar-collapse" id="navbarSupportedContent">
#          <ul class="navbar-nav mr-auto" style="margin: auto;">
#
#              <li class="nav-item img-inicio-fix" id="dmenu">
#                  <a aria-expanded="false" aria-haspopup="true" class="nav-link" href="index.php" role="button">
#                  <img class="img-fluid" src="img/icono-home.png"/>
#                  </a>
#              </li>
#              <li class="nav-item" id="dmenu">
#                  <a aria-expanded="false" aria-haspopup="true" class="nav-link" href="directorio.php" role="button">
#                      Directorio
#                  </a>
#              </li>
#              <!--   1-->
#              <li class="nav-item dropdown" id="dmenu">
#
#                  <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" id="navbarDropdown" role="button">
#                      ¿Quiénes Somos?
#                  </a>
#                  <div class="dropdown-menu" style="background:#454547;">
#
#                      <a class="text-black dropdown-item" href="historia.php">HISTORIA</a>
#                      <a class="text-black dropdown-item" href="mision.php">MISIÓN Y VISIÓN</a>
#                      <a class="text-black dropdown-item" href="infra.php">UBICACIÓN E INFRAESCTRUCTURA</a>
#                      <a class="text-black dropdown-item" href="cuidadoMa.php">CUIDADO DEL MEDIO AMBIENTE</a>
#                      <a class="text-black dropdown-item" href="logos.php">MASCOTA Y LOGOS</a>
#                      <!--<a class="text-black dropdown-item" href="contacto.php">CONTACTO</a>-->
#
#                      <!--<a class="text-black dropdown-item" href="https://docs.google.com/forms/d/e/1FAIpQLSeE8OPXE5YSXIcA0zLvfCnaHtY0NQrbtSEr9VVMn8ZavzT_iA/viewform#response=ACYDBNiyCA6p87VDbN4lu-wVyLdVOv5qkOKwqxQXMwKijoJdEsQXK53UB9bS5t4">BUZÓN DE QUEJAS Y SUGERENCIAS</a>-->
#                      <a class="text-black dropdown-item" href="https://docs.google.com/forms/d/e/1FAIpQLSddMvuMgSe8qJ63G7op3Pcr5-VEuV2_UPElM977PS9lm8faug/viewform">BUZÓN DE QUEJAS Y SUGERENCIAS</a>
#
#                      <a class="text-black dropdown-item" href="https://docs.google.com/forms/d/e/1FAIpQLSckSqRPLi4GVYVthg5wP034P8tiEgBhyLnNcd6JCc7ZkE1KGg/viewform?entry.1159593137=nombre&amp;entry.1809109965&amp;entry.1214002645&amp;entry.1344596603&amp;entry.1727722980&amp;entry.1573787809=nombre+completo&amp;entry.471819699=puesto&amp;entry.285911030=ITL&amp;entry.134294733=2018-03-03&amp;entry.1785309787=20:00&amp;entry.1084813065=ITL&amp;entry.1814560733=hechos&amp;entry.1641027819=Nombre+testigo&amp;entry.1484745992=Domicilio+testigo&amp;entry.769034671=S%C3%AD&amp;entry.1684521492=si1&amp;entry.1680632340=si2">
#                          FORMATO DE DENUNCIAS DEL SG DE
#                          <br/>IGUALDAD DE GÉNERO Y NO DISCRIMINACIÓN</a>
#
#                      <a class="text-black dropdown-item" href="http://www.itlalaguna.edu.mx/etica/codigoetica.pdf">CÓDIGO DE ÉTICA Y CONDUCTA</a>
#                      <a class="text-black dropdown-item" href="https://www.tecnm.mx/?vista=Normateca">NORMATECA  DEL TECNM</a>
#
#
#                  </div>
#              </li>
#              <!-- PRUEBA -->
#     <!--2-->
#                 <!--2-->
#
#
#
#                 <li class="nav-item dropdown" id="dmenu">
#                  <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" id="navbarDropdown" role="button">
#                      Oferta Educativa
#                  </a>
#
#                  <div class="dropdown-menu" style="background:#454547;">
#                      <ul class="navbar-nav nav-dropdown dropdown-item" data-app-modern-menu="true" style="background:#454547;">
#                          <li class="nav-item dropdown dropdown-submenu" style="background:#454547;">
#                              <a aria-expanded="false" class="dropdown-toggle dropdown-item dropdown-submenu" data-toggle="dropdown-submenu" href="#" style="background:#454547;">NIVEL LICENCIATURA</a>
#                              <div class="dropdown-menu" style="background:#454547;">
#                                  <a class="text-black dropdown-item" href="sistemas.php">ING. SISTEMAS
#                                      COMPUTACIONALES</a>
#                                  <a class="text-black dropdown-item" href="electrica.php">ING. ELÉCTRICA</a>
#                                  <a class="text-black dropdown-item" href="electronica.php">ING. ELECTRÓNICA</a>
#                                  <a class="text-black dropdown-item" href="er.php">ING. EN ENERGÍAS
#                                      RENOVABLES</a>
#                                  <a class="text-black dropdown-item" href="industrial.php">ING.
#                                      INDUSTRIAL</a>
#                                  <a class="text-black dropdown-item" href="mecanica.php">ING. MECÁNICA</a>
#                                  <a class="text-black dropdown-item" href="mecatronica.php">ING.
#                                      MECATRÓNICA</a>
#                                  <a class="text-black dropdown-item" href="quimica.php">ING. QUÍMICA</a>
#                                  <a class="text-black dropdown-item" href="admin.php">LIC.
#                                      ADMINISTRACION</a>
#                                  <a class="text-black dropdown-item" href="gestionEmp.php">ING. GESTIÓN
#                                      EMPRESARIAL</a>
#
#                              </div>
#                          </li>
#                      </ul>
#                         <!-- <a class="link text-black dropdown-item" style="background:#454547;" href="http://www.itlalaguna.edu.mx/posgrado/indexposgrado.html" data-toggle="dropdown-submenu" aria-expanded="false">NIVEL POSGRADO</a>-->
#
#
#
#
#                      <ul class="navbar-nav nav-dropdown dropdown-item" data-app-modern-menu="true" style="background:#454547;">
#                          <li class="nav-item dropdown dropdown-submenu" style="background:#454547;">
#                              <a aria-expanded="false" class="dropdown-toggle dropdown-item dropdown-submenu" data-toggle="dropdown-submenu" href="#" style="background:#454547;">NIVEL POSGRADO</a>
#                              <div class="dropdown-menu" style="background:#454547;">
#
#                                  <a class="text-black dropdown-item" href="MAESTRIAE.php">MAESTRÍA EN CIENCIAS EN INGENIERÍA ELÉCTRICA (PNPC)</a>
#
#                                  <a class="text-black dropdown-item" href="MAESTRIAI.php">MAESTRÍA EN INGENIERÍA INDUSTRIAL</a>
#                                  <a class="text-black dropdown-item" href="MAESTRIAS.php">MAESTRÍA EN SISTEMAS COMPUTACIONALES</a>
#                                  <a class="text-black dropdown-item" href="DOCTORADOE.php">DOCTORADO EN CIENCIAS EN INGENIERÍA ELÉCTRICA (PNPC)</a>
#
#                              </div>
#                          </li>
#                      </ul>
#
#
#                       <!-- <ul class="navbar-nav nav-dropdown dropdown-item " style="background:#454547;" data-app-modern-menu="true">
#                          <li class="nav-item dropdown dropdown-submenu" style="background:#454547;">
#                              <a class="dropdown-toggle dropdown-item dropdown-submenu" style="background:#454547;" href="#" data-toggle="dropdown-submenu" aria-expanded="false">NIVEL LICENCIATURA A DISTANCIA</a>
#                              <div class=" dropdown-menu" style="background:#454547;">
#
#                                  <a class="text-black dropdown-item" href="industrial.php">ING.
#                                      INDUSTRIAL</a>
#
#                                  <a class="text-black dropdown-item" href="gestionEmp.php">ING. GESTIÓN
#                                      EMPRESARIAL</a>
#
#                              </div>
#                          </li>
#                      </ul>-->
#                      </div>
#
#              </li>
#              <!-- NEW 4 -->
#
#
#
#
#
#
#
#   <!-- 3-->
#
#   <!-- ALUMNADO2   ERA 4
#   <li class="nav-item dropdown" id='dmenu'>
#                  <a class="nav-link dropdown-toggle" id="navbarDropdown" role="button" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
#                      Aspirantes
#                  </a>
#                  <div class="dropdown-menu" style="background:#454547;">
#                      <a class="text-black dropdown-item" href="nivelacion.php">SEMESTRE DE NIVELACIÓN</a>
#                      <a class="text-black dropdown-item" href="http://apps2.itlalaguna.edu.mx:8081/">INGRESO LICENCIATURA</a>
#                      <a class="text-black dropdown-item" href="posgrado/indexposgrado.html">INGRESO POSGRADO</a>
#
#                  </div>
#              </li>
#
#              <li class="nav-item dropdown" id='dmenu'>
#                  <a class="nav-link dropdown-toggle" id="navbarDropdown" role="button" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
#                      Alumnado2
#                  </a>
#                  <div class="dropdown-menu" style="background:#454547; ">
#                      <ul class="navbar-nav nav-dropdown dropdown-item" style="background:#454547;" data-app-modern-menu="true">
#                          <li class="nav-item dropdown dropdown-submenu" style="background:#454547;">
#                              <a class="dropdown-toggle dropdown-item dropdown-submenu" id="smn3" style="background:#454547;" href="#" data-toggle="dropdown-submenu" aria-expanded="false">DIV. DE ESTUDIOS PROFESIONALES</a>
#                              <div class="dropdown-menu" style="background:#454547;">
#                                  <a class="dropdown-item" href="#">COORDINACIÓN DE TITULACIÓN</a>
#                                  <a class="dropdown-item" href="#">HORARIO MATERIAS</a>
#                                  <a class="dropdown-item" href="#">REINGRESO LICENCIATURA</a>
#                                  <a class="dropdown-item" href="#">VERANOS LICENCIATURA</a>
#                                  <a class="dropdown-item" href="#">REINGRESO POSGRADO</a>
#                                  <a class="dropdown-item" href="#">REINGRESO A DISTANCIA</a>
#                              </div>
#                          </li>
#                      </ul>
#                      <ul class="navbar-nav nav-dropdown dropdown-item" style="background:#454547;" data-app-modern-menu="true">
#                          <li class="nav-item dropdown" style="background:#454547;">
#                              <a class=" dropdown-toggle dropdown-item dropdown-submenu" href="http://escolares.itlalaguna.edu.mx" id="smn4" style="background:#454547;" href="#" data-toggle="dropdown-submenu" aria-expanded="false">SERVICIOS ESCOLARES</a>
#
#                          </li>
#                      </ul>
#                  </div>
#              </li>
#
#  -->
#
#
#     <!--2-->
#     <li class="nav-item dropdown" id="dmenu">
#                  <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" id="navbarDropdown" role="button">
#                      Alumnado
#                  </a>
#                  <div class="dropdown-menu" style="background:#454547;">
#                  <ul class="navbar-nav nav-dropdown dropdown-item" data-app-modern-menu="true" style="background:#454547;">
#                          <li class="nav-item dropdown dropdown-submenu" style="background:#454547;">
#                              <a aria-expanded="false" class="link text-black dropdown-toggle dropdown-item" data-toggle="dropdown-submenu" href="#" style="background:#454547;">DESARROLLO ACADÉMICO</a>
#                               <div class="dropdown-menu" style="background:#454547;">
#                              <a class="text-black dropdown-item" href="http://sed.itlalaguna.edu.mx/sed/">EVALUACIÓN AL PROFESORADO</a>
#
#                              <a class="dropdown-item" href="AVISOS/CALENDARIO.PDF">CALENDARIO ESCOLAR</a>
#                              </div>
#                          </li>
#                      </ul>
#                      <ul class="navbar-nav nav-dropdown dropdown-item" data-app-modern-menu="true" style="background:#454547;">
#                          <li class="nav-item dropdown dropdown-submenu" style="background:#454547;">
#                              <a aria-expanded="false" class="link text-black dropdown-toggle dropdown-item" data-toggle="dropdown-submenu" href="#" style="background:#454547;">DIVISIÓN DE ESTUDIOS PROFESIONALES</a>
#                               <div class="dropdown-menu" style="background:#454547;">
#
#                               <a class="dropdown-item" href="http://apps2.itlalaguna.edu.mx/inscripcion/login.aspx">CARGA DE MATERIAS</a>
#                               <!--<a class="dropdown-item" href="soporte@correo.itlalaguna.edu.mx">Si tienes algún problema escribe a <br>
#                               soporte@correo.itlalaguna.edu.mx <br> incluye número de control y <br>comprobante de pago
#                              </a>-->
#                               <a class="dropdown-item" href="http://apps.itlalaguna.edu.mx/servicios/academicos/horario_materias_2020/index.htm">HORARIO MATERIAS</a>
#                                <a class="text-black dropdown-item" href="titulacion.php">COORDINACIÓN DE TITULACIÓN</a>
#
#                              <a class="dropdown-item" href="http://apps2.itlalaguna.edu.mx:8082/">FICHAS DE PAGO REINGRESO</a>
#                              <a class="dropdown-item" href="COMITE/COMITE.PDF">COMITÉ ACADÉMICO</a>
#                              <a class="dropdown-item" href="ESPECIALES/ESPECIALES.PDF">EXÁMENES ESPECIALES</a>
#                              </div>
#                          </li>
#                      </ul>
#                      <a aria-expanded="false" class="link text-black dropdown-item" data-toggle="dropdown-submenu" href="REGLAMENTO/Manual_de_Lineamientos_TecNM.pdf" style="background:#454547;">MANUAL DE LINEAMIENTOS</a>
#                      <a aria-expanded="false" class="link text-black dropdown-item" data-toggle="dropdown-submenu" href="REGLAMENTO/REGLAMENTO2019.PDF" style="background:#454547;">REGLAMENTO ESTUDIANTIL</a>
#
#
#
#                      <a aria-expanded="false" class="link text-black dropdown-item" data-toggle="dropdown-submenu" href="http://escolares.itlalaguna.edu.mx" style="background:#454547;">SERVICIOS ESCOLARES</a>
#                      <a aria-expanded="false" class="link text-black dropdown-item" data-toggle="dropdown-submenu" href="extraescolares/extraescolares20.pdf" style="background:#454547;">ACTIVIDADES EXTRAESCOLARES</a>
#                  </div>
#              </li>
#
#
#
#
#              <!-- 3-->
#
#
#              <!-- 3-->
#              <li class="nav-item dropdown" id="dmenu">
#                  <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" id="navbarDropdown" role="button">
#                     Nuevo Ingreso
#                  </a>
#                  <div class="dropdown-menu" style="background:#454547;">
#
#                     <!-- <a class="text-black dropdown-item" href="http://apps2.itlalaguna.edu.mx:8081/">LICENCIATURA</a>-->
#                     <a class="text-black dropdown-item" href="ADMago.PHP">LICENCIATURA AGOSTO - DICIEMBRE</a>
#                     <a class="text-black dropdown-item" href="ADMcpago.PHP">POSGRADO AGOSTO - DICIEMBRE</a>
#                     <a class="text-black dropdown-item" href="nivelacion.php">NIVELACIÓN AGOSTO - DICIEMBRE</a>
#                     <a class="text-black dropdown-item" href="ADM.PHP">LICENCIATURA ENERO - JUNIO</a>
#                      <a class="text-black dropdown-item" href="ADMcp.PHP">POSGRADO ENERO - JUNIO</a>
#
#
#
#                      <!--<a class="text-black dropdown-item" href="ADMdis.PHP">LICENCIATURA MODALIDAD A DISTANCIA</a>-->
#
#                    <!--  <a class="text-black dropdown-item" href="distancia.php">INGRESO A DISTANCIA</a>-->
#                  </div>
#              </li>
#
#
#
#               <!-- 5-->
#               <li class="nav-item dropdown" id="dmenu">
#                  <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" id="navbarDropdown" role="button">
#                      Vinculación
#                  </a>
#                  <div class="dropdown-menu" style="background:#454547;">
#                      <a class="dropdown-item" href="http://www.itlalaguna.edu.mx/vinculacion/servsocial21.pdf">SERVICIO SOCIAL</a>
#                      <a class="dropdown-item" href="http://www.itlalaguna.edu.mx/vinculacion/bolsa_trabajo_2.pdf">BOLSA DE TRABAJO</a>
#                      <a class="dropdown-item" href="http://www.itlalaguna.edu.mx/vinculacion/servicios_externos.pdf">SERVICIO EXTERNOS</a>
#                      <a class="dropdown-item" href="http://www.itlalaguna.edu.mx/vinculacion/idiomas.pdf">IDIOMAS</a>
#                      <a class="dropdown-item" href="vinculacion/residencia/residencia-platica.pdf">SOLICITUD DE CARTA DE PRESENTACIÓN<br/> DE RESIDENCIA PROFESIONAL</a>
#
#                  </div>
#              </li>
#               <!-- 6-->
#               <li class="nav-item dropdown" id="dmenu">
#                  <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" id="navbarDropdown" role="button">
#                      Personal
#                  </a>
#                  <div class="dropdown-menu" style="background:#454547;">
#                      <a class="dropdown-item" href="http://apps.itlalaguna.edu.mx/servicios/personal/catedraticos/index18.html">DOCENTES CARGA DE TRABAJO</a>
#                      <!--<a class=" dropdown-item" href="http://apps2.itlalaguna.edu.mx/SGESCL/login.aspx">DOCENTES CALIFICACIONES</a>-->
#                      <a class="dropdown-item" href="becasint/becasint.html">CONVOCATORIAS</a>
#                      <a class="dropdown-item" href="REGLAMENTOS.PHP">REGLAMENTOS</a>
#                      <a class="dropdown-item" href="CONTRALORIA.PHP">PRODEP</a>
#                  </div>
#              </li>
#              <!-- 7-->
#              <!--  <li class="nav-item dropdown" id='dmenu'>
#                  <a class="nav-link dropdown-toggle" id="navbarDropdown" data-toggle="dropdown" role="button" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
#                      Mejora Continua
#                  </a>
#                  <div class="dropdown-menu" style="background:#454547;">
#                      <a class=" dropdown-item" href="#">CONTROL DE DOCUMENTOS</a>
#                      <a class=" dropdown-item" href="#">SISTEMA DE GESTIÓN INTEGRAL</a>
#                      <a class=" dropdown-item" href="#">SISTEMA DE G.DE IGUALDAD DE GÉNERO</a>
#                      <a class=" dropdown-item" href="#">BUZÓN DE QUEJAS Y SUGERENCIAS</a>
#                      <a class=" dropdown-item" href="#">INNOVACIÓN Y DESARROLLO (PIID ITLaguna)</a>
#
#                  </div>
#              </li>-->
#          </ul>
#      </div>,
#  <div class="dropdown-menu" style="background:#454547;">
#
#                      <a class="text-black dropdown-item" href="historia.php">HISTORIA</a>
#                      <a class="text-black dropdown-item" href="mision.php">MISIÓN Y VISIÓN</a>
#                      <a class="text-black dropdown-item" href="infra.php">UBICACIÓN E INFRAESCTRUCTURA</a>
#                      <a class="text-black dropdown-item" href="cuidadoMa.php">CUIDADO DEL MEDIO AMBIENTE</a>
#                      <a class="text-black dropdown-item" href="logos.php">MASCOTA Y LOGOS</a>
#                      <!--<a class="text-black dropdown-item" href="contacto.php">CONTACTO</a>-->
#
#                      <!--<a class="text-black dropdown-item" href="https://docs.google.com/forms/d/e/1FAIpQLSeE8OPXE5YSXIcA0zLvfCnaHtY0NQrbtSEr9VVMn8ZavzT_iA/viewform#response=ACYDBNiyCA6p87VDbN4lu-wVyLdVOv5qkOKwqxQXMwKijoJdEsQXK53UB9bS5t4">BUZÓN DE QUEJAS Y SUGERENCIAS</a>-->
#                      <a class="text-black dropdown-item" href="https://docs.google.com/forms/d/e/1FAIpQLSddMvuMgSe8qJ63G7op3Pcr5-VEuV2_UPElM977PS9lm8faug/viewform">BUZÓN DE QUEJAS Y SUGERENCIAS</a>
#
#                      <a class="text-black dropdown-item" href="https://docs.google.com/forms/d/e/1FAIpQLSckSqRPLi4GVYVthg5wP034P8tiEgBhyLnNcd6JCc7ZkE1KGg/viewform?entry.1159593137=nombre&amp;entry.1809109965&amp;entry.1214002645&amp;entry.1344596603&amp;entry.1727722980&amp;entry.1573787809=nombre+completo&amp;entry.471819699=puesto&amp;entry.285911030=ITL&amp;entry.134294733=2018-03-03&amp;entry.1785309787=20:00&amp;entry.1084813065=ITL&amp;entry.1814560733=hechos&amp;entry.1641027819=Nombre+testigo&amp;entry.1484745992=Domicilio+testigo&amp;entry.769034671=S%C3%AD&amp;entry.1684521492=si1&amp;entry.1680632340=si2">
#                          FORMATO DE DENUNCIAS DEL SG DE
#                          <br/>IGUALDAD DE GÉNERO Y NO DISCRIMINACIÓN</a>
#
#                      <a class="text-black dropdown-item" href="http://www.itlalaguna.edu.mx/etica/codigoetica.pdf">CÓDIGO DE ÉTICA Y CONDUCTA</a>
#                      <a class="text-black dropdown-item" href="https://www.tecnm.mx/?vista=Normateca">NORMATECA  DEL TECNM</a>
#
#
#                  </div>,
#  <div class="dropdown-menu" style="background:#454547;">
#                      <ul class="navbar-nav nav-dropdown dropdown-item" data-app-modern-menu="true" style="background:#454547;">
#                          <li class="nav-item dropdown dropdown-submenu" style="background:#454547;">
#                              <a aria-expanded="false" class="dropdown-toggle dropdown-item dropdown-submenu" data-toggle="dropdown-submenu" href="#" style="background:#454547;">NIVEL LICENCIATURA</a>
#                              <div class="dropdown-menu" style="background:#454547;">
#                                  <a class="text-black dropdown-item" href="sistemas.php">ING. SISTEMAS
#                                      COMPUTACIONALES</a>
#                                  <a class="text-black dropdown-item" href="electrica.php">ING. ELÉCTRICA</a>
#                                  <a class="text-black dropdown-item" href="electronica.php">ING. ELECTRÓNICA</a>
#                                  <a class="text-black dropdown-item" href="er.php">ING. EN ENERGÍAS
#                                      RENOVABLES</a>
#                                  <a class="text-black dropdown-item" href="industrial.php">ING.
#                                      INDUSTRIAL</a>
#                                  <a class="text-black dropdown-item" href="mecanica.php">ING. MECÁNICA</a>
#                                  <a class="text-black dropdown-item" href="mecatronica.php">ING.
#                                      MECATRÓNICA</a>
#                                  <a class="text-black dropdown-item" href="quimica.php">ING. QUÍMICA</a>
#                                  <a class="text-black dropdown-item" href="admin.php">LIC.
#                                      ADMINISTRACION</a>
#                                  <a class="text-black dropdown-item" href="gestionEmp.php">ING. GESTIÓN
#                                      EMPRESARIAL</a>
#
#                              </div>
#                          </li>
#                      </ul>
#                         <!-- <a class="link text-black dropdown-item" style="background:#454547;" href="http://www.itlalaguna.edu.mx/posgrado/indexposgrado.html" data-toggle="dropdown-submenu" aria-expanded="false">NIVEL POSGRADO</a>-->
#
#
#
#
#                      <ul class="navbar-nav nav-dropdown dropdown-item" data-app-modern-menu="true" style="background:#454547;">
#                          <li class="nav-item dropdown dropdown-submenu" style="background:#454547;">
#                              <a aria-expanded="false" class="dropdown-toggle dropdown-item dropdown-submenu" data-toggle="dropdown-submenu" href="#" style="background:#454547;">NIVEL POSGRADO</a>
#                              <div class="dropdown-menu" style="background:#454547;">
#
#                                  <a class="text-black dropdown-item" href="MAESTRIAE.php">MAESTRÍA EN CIENCIAS EN INGENIERÍA ELÉCTRICA (PNPC)</a>
#
#                                  <a class="text-black dropdown-item" href="MAESTRIAI.php">MAESTRÍA EN INGENIERÍA INDUSTRIAL</a>
#                                  <a class="text-black dropdown-item" href="MAESTRIAS.php">MAESTRÍA EN SISTEMAS COMPUTACIONALES</a>
#                                  <a class="text-black dropdown-item" href="DOCTORADOE.php">DOCTORADO EN CIENCIAS EN INGENIERÍA ELÉCTRICA (PNPC)</a>
#
#                              </div>
#                          </li>
#                      </ul>
#
#
#                       <!-- <ul class="navbar-nav nav-dropdown dropdown-item " style="background:#454547;" data-app-modern-menu="true">
#                          <li class="nav-item dropdown dropdown-submenu" style="background:#454547;">
#                              <a class="dropdown-toggle dropdown-item dropdown-submenu" style="background:#454547;" href="#" data-toggle="dropdown-submenu" aria-expanded="false">NIVEL LICENCIATURA A DISTANCIA</a>
#                              <div class=" dropdown-menu" style="background:#454547;">
#
#                                  <a class="text-black dropdown-item" href="industrial.php">ING.
#                                      INDUSTRIAL</a>
#
#                                  <a class="text-black dropdown-item" href="gestionEmp.php">ING. GESTIÓN
#                                      EMPRESARIAL</a>
#
#                              </div>
#                          </li>
#                      </ul>-->
#                      </div>,
#  <div class="dropdown-menu" style="background:#454547;">
#                                  <a class="text-black dropdown-item" href="sistemas.php">ING. SISTEMAS
#                                      COMPUTACIONALES</a>
#                                  <a class="text-black dropdown-item" href="electrica.php">ING. ELÉCTRICA</a>
#                                  <a class="text-black dropdown-item" href="electronica.php">ING. ELECTRÓNICA</a>
#                                  <a class="text-black dropdown-item" href="er.php">ING. EN ENERGÍAS
#                                      RENOVABLES</a>
#                                  <a class="text-black dropdown-item" href="industrial.php">ING.
#                                      INDUSTRIAL</a>
#                                  <a class="text-black dropdown-item" href="mecanica.php">ING. MECÁNICA</a>
#                                  <a class="text-black dropdown-item" href="mecatronica.php">ING.
#                                      MECATRÓNICA</a>
#                                  <a class="text-black dropdown-item" href="quimica.php">ING. QUÍMICA</a>
#                                  <a class="text-black dropdown-item" href="admin.php">LIC.
#                                      ADMINISTRACION</a>
#                                  <a class="text-black dropdown-item" href="gestionEmp.php">ING. GESTIÓN
#                                      EMPRESARIAL</a>
#
#                              </div>,
#  <div class="dropdown-menu" style="background:#454547;">
#
#                                  <a class="text-black dropdown-item" href="MAESTRIAE.php">MAESTRÍA EN CIENCIAS EN INGENIERÍA ELÉCTRICA (PNPC)</a>
#
#                                  <a class="text-black dropdown-item" href="MAESTRIAI.php">MAESTRÍA EN INGENIERÍA INDUSTRIAL</a>
#                                  <a class="text-black dropdown-item" href="MAESTRIAS.php">MAESTRÍA EN SISTEMAS COMPUTACIONALES</a>
#                                  <a class="text-black dropdown-item" href="DOCTORADOE.php">DOCTORADO EN CIENCIAS EN INGENIERÍA ELÉCTRICA (PNPC)</a>
#
#                              </div>,
#  <div class="dropdown-menu" style="background:#454547;">
#                  <ul class="navbar-nav nav-dropdown dropdown-item" data-app-modern-menu="true" style="background:#454547;">
#                          <li class="nav-item dropdown dropdown-submenu" style="background:#454547;">
#                              <a aria-expanded="false" class="link text-black dropdown-toggle dropdown-item" data-toggle="dropdown-submenu" href="#" style="background:#454547;">DESARROLLO ACADÉMICO</a>
#                               <div class="dropdown-menu" style="background:#454547;">
#                              <a class="text-black dropdown-item" href="http://sed.itlalaguna.edu.mx/sed/">EVALUACIÓN AL PROFESORADO</a>
#
#                              <a class="dropdown-item" href="AVISOS/CALENDARIO.PDF">CALENDARIO ESCOLAR</a>
#                              </div>
#                          </li>
#                      </ul>
#                      <ul class="navbar-nav nav-dropdown dropdown-item" data-app-modern-menu="true" style="background:#454547;">
#                          <li class="nav-item dropdown dropdown-submenu" style="background:#454547;">
#                              <a aria-expanded="false" class="link text-black dropdown-toggle dropdown-item" data-toggle="dropdown-submenu" href="#" style="background:#454547;">DIVISIÓN DE ESTUDIOS PROFESIONALES</a>
#                               <div class="dropdown-menu" style="background:#454547;">
#
#                               <a class="dropdown-item" href="http://apps2.itlalaguna.edu.mx/inscripcion/login.aspx">CARGA DE MATERIAS</a>
#                               <!--<a class="dropdown-item" href="soporte@correo.itlalaguna.edu.mx">Si tienes algún problema escribe a <br>
#                               soporte@correo.itlalaguna.edu.mx <br> incluye número de control y <br>comprobante de pago
#                              </a>-->
#                               <a class="dropdown-item" href="http://apps.itlalaguna.edu.mx/servicios/academicos/horario_materias_2020/index.htm">HORARIO MATERIAS</a>
#                                <a class="text-black dropdown-item" href="titulacion.php">COORDINACIÓN DE TITULACIÓN</a>
#
#                              <a class="dropdown-item" href="http://apps2.itlalaguna.edu.mx:8082/">FICHAS DE PAGO REINGRESO</a>
#                              <a class="dropdown-item" href="COMITE/COMITE.PDF">COMITÉ ACADÉMICO</a>
#                              <a class="dropdown-item" href="ESPECIALES/ESPECIALES.PDF">EXÁMENES ESPECIALES</a>
#                              </div>
#                          </li>
#                      </ul>
#                      <a aria-expanded="false" class="link text-black dropdown-item" data-toggle="dropdown-submenu" href="REGLAMENTO/Manual_de_Lineamientos_TecNM.pdf" style="background:#454547;">MANUAL DE LINEAMIENTOS</a>
#                      <a aria-expanded="false" class="link text-black dropdown-item" data-toggle="dropdown-submenu" href="REGLAMENTO/REGLAMENTO2019.PDF" style="background:#454547;">REGLAMENTO ESTUDIANTIL</a>
#
#
#
#                      <a aria-expanded="false" class="link text-black dropdown-item" data-toggle="dropdown-submenu" href="http://escolares.itlalaguna.edu.mx" style="background:#454547;">SERVICIOS ESCOLARES</a>
#                      <a aria-expanded="false" class="link text-black dropdown-item" data-toggle="dropdown-submenu" href="extraescolares/extraescolares20.pdf" style="background:#454547;">ACTIVIDADES EXTRAESCOLARES</a>
#                  </div>,
#  <div class="dropdown-menu" style="background:#454547;">
#                              <a class="text-black dropdown-item" href="http://sed.itlalaguna.edu.mx/sed/">EVALUACIÓN AL PROFESORADO</a>
#
#                              <a class="dropdown-item" href="AVISOS/CALENDARIO.PDF">CALENDARIO ESCOLAR</a>
#                              </div>,
#  <div class="dropdown-menu" style="background:#454547;">
#
#                               <a class="dropdown-item" href="http://apps2.itlalaguna.edu.mx/inscripcion/login.aspx">CARGA DE MATERIAS</a>
#                               <!--<a class="dropdown-item" href="soporte@correo.itlalaguna.edu.mx">Si tienes algún problema escribe a <br>
#                               soporte@correo.itlalaguna.edu.mx <br> incluye número de control y <br>comprobante de pago
#                              </a>-->
#                               <a class="dropdown-item" href="http://apps.itlalaguna.edu.mx/servicios/academicos/horario_materias_2020/index.htm">HORARIO MATERIAS</a>
#                                <a class="text-black dropdown-item" href="titulacion.php">COORDINACIÓN DE TITULACIÓN</a>
#
#                              <a class="dropdown-item" href="http://apps2.itlalaguna.edu.mx:8082/">FICHAS DE PAGO REINGRESO</a>
#                              <a class="dropdown-item" href="COMITE/COMITE.PDF">COMITÉ ACADÉMICO</a>
#                              <a class="dropdown-item" href="ESPECIALES/ESPECIALES.PDF">EXÁMENES ESPECIALES</a>
#                              </div>,
#  <div class="dropdown-menu" style="background:#454547;">
#
#                     <!-- <a class="text-black dropdown-item" href="http://apps2.itlalaguna.edu.mx:8081/">LICENCIATURA</a>-->
#                     <a class="text-black dropdown-item" href="ADMago.PHP">LICENCIATURA AGOSTO - DICIEMBRE</a>
#                     <a class="text-black dropdown-item" href="ADMcpago.PHP">POSGRADO AGOSTO - DICIEMBRE</a>
#                     <a class="text-black dropdown-item" href="nivelacion.php">NIVELACIÓN AGOSTO - DICIEMBRE</a>
#                     <a class="text-black dropdown-item" href="ADM.PHP">LICENCIATURA ENERO - JUNIO</a>
#                      <a class="text-black dropdown-item" href="ADMcp.PHP">POSGRADO ENERO - JUNIO</a>
#
#
#
#                      <!--<a class="text-black dropdown-item" href="ADMdis.PHP">LICENCIATURA MODALIDAD A DISTANCIA</a>-->
#
#                    <!--  <a class="text-black dropdown-item" href="distancia.php">INGRESO A DISTANCIA</a>-->
#                  </div>,
#  <div class="dropdown-menu" style="background:#454547;">
#                      <a class="dropdown-item" href="http://www.itlalaguna.edu.mx/vinculacion/servsocial21.pdf">SERVICIO SOCIAL</a>
#                      <a class="dropdown-item" href="http://www.itlalaguna.edu.mx/vinculacion/bolsa_trabajo_2.pdf">BOLSA DE TRABAJO</a>
#                      <a class="dropdown-item" href="http://www.itlalaguna.edu.mx/vinculacion/servicios_externos.pdf">SERVICIO EXTERNOS</a>
#                      <a class="dropdown-item" href="http://www.itlalaguna.edu.mx/vinculacion/idiomas.pdf">IDIOMAS</a>
#                      <a class="dropdown-item" href="vinculacion/residencia/residencia-platica.pdf">SOLICITUD DE CARTA DE PRESENTACIÓN<br/> DE RESIDENCIA PROFESIONAL</a>
#
#                  </div>,
#  <div class="dropdown-menu" style="background:#454547;">
#                      <a class="dropdown-item" href="http://apps.itlalaguna.edu.mx/servicios/personal/catedraticos/index18.html">DOCENTES CARGA DE TRABAJO</a>
#                      <!--<a class=" dropdown-item" href="http://apps2.itlalaguna.edu.mx/SGESCL/login.aspx">DOCENTES CALIFICACIONES</a>-->
#                      <a class="dropdown-item" href="becasint/becasint.html">CONVOCATORIAS</a>
#                      <a class="dropdown-item" href="REGLAMENTOS.PHP">REGLAMENTOS</a>
#                      <a class="dropdown-item" href="CONTRALORIA.PHP">PRODEP</a>
#                  </div>,
#  <div class="slideshow-container">
#
#  <!--<div class="mySlides1">
#
#
#              <img src="slider/AVISovacuna.png" style="width:100%">
#      </div>
#      -->
#
#
#
#
#
#
#  <div class="mySlides1">
#          <a href="avisos/registro-office.pdf">
#
#              <img src="slider/office.png" style="width:100%"/></a>
#      </div>
#      <div class="mySlides1">
#          <a href="https://www.tecnm.mx/menu/convocatorias_tecnm/01_InvCientifica_Academicos_Convocatoria_2021-2.pdf">
#
#              <img src="slider/convoinvest2.png" style="width:100%"/></a>
#      </div>
#
#  <div class="mySlides1">
#          <a href="avisos/solicitud protocolos  titulación_mayo 2021.pdf">
#
#              <img src="slider/solicitud protocolos  titulación_mayo 2021.png" style="width:100%"/></a>
#      </div>
#
#  <div class="mySlides1">
#          <a href="avisos/registro proyectos titulación_mayo 2021.pdf">
#
#              <img src="slider/registro proyectos titulación_mayo 2021.png" style="width:100%"/></a>
#      </div>
#
#
#  <div class="mySlides1">
#          <a href="https://escolares.itlalaguna.edu.mx/web/index.php/entrega-de-certificados/">
#
#              <img src="slider/certificados2.png" style="width:100%"/></a>
#      </div>
#
#
#  <div class="mySlides1">
#          <a href="ADMago.PHP">
#
#              <img src="slider/adm21ago2.png" style="width:100%"/></a>
#      </div>
#
#
#
#       <div class="mySlides1">
#
#         <img src="slider/puertas.jpg" style="width:100%"/>
#      </div>
#
#
#        <!-- <div class="mySlides1">
#          <a href="https://www.gob.mx/cms/uploads/attachment/file/617238/MANUTENCION_FEDERAL.pdf">
#
#              <img src="slider/becas.jpg" style="width:100%"></a>
#      </div>-->
#
#  <div class="mySlides1">
#          <a href="http://mooc.tecnm.mx/">
#
#              <img src="slider/mooc.jpg" style="width:100%"/></a>
#      </div>
#
#  <!--<div class="mySlides1">
#          <a href="https://docs.google.com/forms/d/e/1FAIpQLSeB0dMOHIapAMmylfW-sgKBPudl7-2krNWwB2Naud24UI0yaA/viewform?pli=1">
#
#              <img src="slider/ti2.jpg" style="width:100%"></a>
#      </div>
#
#  <div class="mySlides1">
#          <a href="https://forms.gle/JqEd4btNsP73eRvJ8">
#
#              <img src="slider/protocolos.png" style="width:100%"></a>
#      </div>-->
#  <div class="mySlides1">
#          <a href="avisos/convocatoria anfei.pdf">
#              <img src="slider/cienciasbasicas.png" style="width:100%"/></a>
#      </div>
#      <div class="mySlides1">
#          <a href="avisos/tripticoetica.pdf">
#              <img src="slider/tripticoetica.jpg" style="width:100%"/></a>
#      </div>
#
#
#
#
#
#
#  <!--<div class="mySlides1">
#          <a href="AVISOS/CALENDARIOEJ21.PDF">
#              <img src="slider/CALENDARIOEJ212.png" style="width:100%"></a>
#      </div>-->
#
#
#      <div class="mySlides1">
#          <a href="https://docs.google.com/forms/d/e/1FAIpQLSeco-OxDhHp_81y0fcDNBKu0dPQakLceC1tHWM49gjPnJdurQ/viewform">
#              <img src="slider/bioetica.jpg" style="width:100%"/></a>
#      </div>
#  <div class="mySlides1">
#          <a href="http://forms.gle/skuGWT2vabzxyDVp9">
#              <img src="slider/evalingles2.png" style="width:100%"/></a>
#      </div>
#
#
#
#      <div class="mySlides1">
#          <a href="avisos/ci2021.pdf">
#              <img src="slider/ci20212.png" style="width:100%"/></a>
#      </div>
#
#
#
#
#
#
#
#
#  <div class="mySlides1">
#          <a href="AVISOS/anfei20.PDF">
#              <img src="slider/anfei202.png" style="width:100%"/></a>
#      </div>
#
#
#
#
#
#  <div class="mySlides1">
#
#              <img src="slider/ingles203.jpg" style="width:100%"/>
#      </div>
#      <div class="mySlides1">
#          <a href="calidad/mejoracontinua.pdf">
#              <img src="slider/cero tolerancia2.jpg" style="width:100%"/></a>
#      </div>
#
#
#
#
#
#
#  <div class="mySlides1">
#          <a href="../avisos/elibro.pdf">
#              <img src="slider/elibro2.png" style="width:100%"/></a>
#      </div>
#
#
#
#
#
#      <div class="mySlides1">
#          <a href="directorio.php">
#              <img src="slider/directorio212.png" style="width:100%"/></a>
#      </div>
#
#
#
#
#
#      <div class="mySlides1">
#
#          <img src="slider/redesof.png" style="width:100%"/>
#      </div>
#
#
#
#
#      <div class="mySlides1">
#          <a href="https://www.tecnm.mx/?vista=TecNM_Virtual"><img src="slider/tecnmvirtual2.jpg" style="width:100%"/></a>
#      </div>
#
#
#      <div class="mySlides1">
#          <a href="avisos/gradua202.pdf">
#
#              <img src="slider/gradua204.jpg" style="width:100%"/></a>
#      </div>
#
#      <div class="mySlides1">
#          <a href="https://bit.ly/2VGuGuK">
#              <img src="slider/protocolo202.jpg" style="width:100%"/></a>
#      </div>
#
#      <div class="mySlides1">
#          <a href="https://bit.ly/2Toczbt">
#              <img src="slider/cerotolerancia202.jpg" style="width:100%"/></a>
#      </div>
#
#
#
#
#
#
#      </div>,
#  <div class="mySlides1">
#          <a href="avisos/registro-office.pdf">
#
#              <img src="slider/office.png" style="width:100%"/></a>
#      </div>,
#  <div class="mySlides1">
#          <a href="https://www.tecnm.mx/menu/convocatorias_tecnm/01_InvCientifica_Academicos_Convocatoria_2021-2.pdf">
#
#              <img src="slider/convoinvest2.png" style="width:100%"/></a>
#      </div>,
#  <div class="mySlides1">
#          <a href="avisos/solicitud protocolos  titulación_mayo 2021.pdf">
#
#              <img src="slider/solicitud protocolos  titulación_mayo 2021.png" style="width:100%"/></a>
#      </div>,
#  <div class="mySlides1">
#          <a href="avisos/registro proyectos titulación_mayo 2021.pdf">
#
#              <img src="slider/registro proyectos titulación_mayo 2021.png" style="width:100%"/></a>
#      </div>,
#  <div class="mySlides1">
#          <a href="https://escolares.itlalaguna.edu.mx/web/index.php/entrega-de-certificados/">
#
#              <img src="slider/certificados2.png" style="width:100%"/></a>
#      </div>,
#  <div class="mySlides1">
#          <a href="ADMago.PHP">
#
#              <img src="slider/adm21ago2.png" style="width:100%"/></a>
#      </div>,
#  <div class="mySlides1">
#
#         <img src="slider/puertas.jpg" style="width:100%"/>
#      </div>,
#  <div class="mySlides1">
#          <a href="http://mooc.tecnm.mx/">
#
#              <img src="slider/mooc.jpg" style="width:100%"/></a>
#      </div>,
#  <div class="mySlides1">
#          <a href="avisos/convocatoria anfei.pdf">
#              <img src="slider/cienciasbasicas.png" style="width:100%"/></a>
#      </div>,
#  <div class="mySlides1">
#          <a href="avisos/tripticoetica.pdf">
#              <img src="slider/tripticoetica.jpg" style="width:100%"/></a>
#      </div>,
#  <div class="mySlides1">
#          <a href="https://docs.google.com/forms/d/e/1FAIpQLSeco-OxDhHp_81y0fcDNBKu0dPQakLceC1tHWM49gjPnJdurQ/viewform">
#              <img src="slider/bioetica.jpg" style="width:100%"/></a>
#      </div>,
#  <div class="mySlides1">
#          <a href="http://forms.gle/skuGWT2vabzxyDVp9">
#              <img src="slider/evalingles2.png" style="width:100%"/></a>
#      </div>,
#  <div class="mySlides1">
#          <a href="avisos/ci2021.pdf">
#              <img src="slider/ci20212.png" style="width:100%"/></a>
#      </div>,
#  <div class="mySlides1">
#          <a href="AVISOS/anfei20.PDF">
#              <img src="slider/anfei202.png" style="width:100%"/></a>
#      </div>,
#  <div class="mySlides1">
#
#              <img src="slider/ingles203.jpg" style="width:100%"/>
#      </div>,
#  <div class="mySlides1">
#          <a href="calidad/mejoracontinua.pdf">
#              <img src="slider/cero tolerancia2.jpg" style="width:100%"/></a>
#      </div>,
#  <div class="mySlides1">
#          <a href="../avisos/elibro.pdf">
#              <img src="slider/elibro2.png" style="width:100%"/></a>
#      </div>,
#  <div class="mySlides1">
#          <a href="directorio.php">
#              <img src="slider/directorio212.png" style="width:100%"/></a>
#      </div>,
#  <div class="mySlides1">
#
#          <img src="slider/redesof.png" style="width:100%"/>
#      </div>,
#  <div class="mySlides1">
#          <a href="https://www.tecnm.mx/?vista=TecNM_Virtual"><img src="slider/tecnmvirtual2.jpg" style="width:100%"/></a>
#      </div>,
#  <div class="mySlides1">
#          <a href="avisos/gradua202.pdf">
#
#              <img src="slider/gradua204.jpg" style="width:100%"/></a>
#      </div>,
#  <div class="mySlides1">
#          <a href="https://bit.ly/2VGuGuK">
#              <img src="slider/protocolo202.jpg" style="width:100%"/></a>
#      </div>,
#  <div class="mySlides1">
#          <a href="https://bit.ly/2Toczbt">
#              <img src="slider/cerotolerancia202.jpg" style="width:100%"/></a>
#      </div>,
#  <div id="bolitas">
#              <span class="bolita" onclick="foto(1)"></span>
#              <span class="bolita" onclick="foto(2)"></span>
#              <span class="bolita" onclick="foto(3)"></span>
#              <span class="bolita" onclick="foto(4)"></span>
#              <span class="bolita" onclick="foto(5)"></span>
#              <span class="bolita" onclick="foto(6)"></span>
#              <span class="bolita" onclick="foto(7)"></span>
# ...
#                                  de Obligaciones de Transparencia</a></li>
#                          <li><a href="http://inicio.ifai.org.mx/SitePages/ifai.aspx" id="pie" style="color:#fff">INAI</a>
#                          </li>
#                          <li><a data-target="#modalQuejas" data-toggle="modal" href="#" id="pie" style="color:#fff">Buzón
#                                  de Sugerencias</a></li>
#                          <li><span data-target="#modalQuejas" data-toggle="modal" href="#" id="pie" style="color:#fff">Visitas</span>
#
#
#
#  <!-- Histats.com  START  (standard)-->
#  <script type="text/javascript">document.write(unescape("%3Cscript src=%27http://s10.histats.com/js15.js%27 type=%27text/javascript%27%3E%3C/script%3E"));</script>
#  <a href="http://www.histats.com" target="_blank" title="contadores web free"><script type="text/javascript">
#  try {Histats.start(1,1838853,4,4003,112,61,"00011011");
#  Histats.track_hits();} catch(err){};
#  </script></a>
#  <noscript></noscript>
#  <!-- Histats.com  END  -->
#
#
#
#  <!-- Start of StatCounter Code -->
#
#  <script type="text/javascript">
#  var sc_project=7949821;
#  var sc_invisible=1;
#  var sc_partition=59;
#  var sc_click_stat=1;
#  var sc_security="8c4af0fe";
#  </script>
#
#  <script src="http://www.statcounter.com/counter/counter.js" type="text/javascript"></script>
#  <!-- End of StatCounter Code --><br/>
#  <a href="http://my.statcounter.com/project/standard/stats.php?project_id=7949821&amp;guest=1" onclick="_gaq.push(['_trackEvent','links menu', 'abandono', 'estadisticas']);" target="_blank">Estadísticas</a>
#
#
#     <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#    (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#    m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#    })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#    ga('create', 'UA-54252992-1', 'auto');
#    ga('send', 'pageview');
#
#  </script>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                              </li>
#
#
#
#
#
#
#
#
#                      </ul>
#                  </div>,
#  <div class="col-lg-3">
#                      <h3 id="pie"> Ubicación </h3>
#                      <img height="70%" src="img/ubicacionITL.jpeg" width="100%"/>
#                      <a href="infra.php" id="pie"> Ver Ubicación </a>
#                  </div>,
#  <div id="sep">
#          <br/>
#      </div>,
#  <div class="list-info">
#              <div class="container">
#                  <div class="row">
#                      <div class="col-md-3" style="margin-top: 15%;">
#                          <img alt="logo gobierno de méxico" class="logo_footer" data-v-9e928f9a="" href="/" src="https://framework-gb.cdn.gob.mx/landing/img/logoheader.svg" style="margin-top: 5%;"/>
#                      </div>
#
#                      <div class="col-sm-3">
#                          <h4 id="pie">Enlaces</h4>
#                          <ul>
#                              <li><a href="https://participa.gob.mx" rel="noopener" target="_blank" title="Enlace abre en ventana nueva">Participa</a></li>
#                              <li><a href="https://www.gob.mx/publicaciones" rel="noopener" target="_blank" title="Enlace abre en ventana nueva">Publicaciones Oficiales</a></li>
#                              <li><a href="http://www.ordenjuridico.gob.mx" rel="noopener" target="_blank" title="Enlace abre en ventana nueva">Marco Jurídico</a></li>
#                              <li><a href="https://consultapublicamx.inai.org.mx/vut-web/" rel="noopener" target="_blank" title="Enlace abre en ventana nueva">Plataforma Nacional de Transparencia</a></li>
#                          </ul>
#                      </div>
#
#                      <div class="col-sm-3">
#                          <h4 id="pie">¿Qué es gob.mx?</h4>
#                          <p id="pie">Es el portal único de trámites, información y participación ciudadana. <a href="https://www.gob.mx/que-es-gobmx">Leer más</a></p>
#                          <ul>
#                              <li><a href="https://datos.gob.mx">Portal de datos abiertos</a></li>
#                              <li><a href="https://www.gob.mx/accesibilidad">Declaración de accesibilidad</a></li>
#                              <li><a href="https://www.gob.mx/privacidadintegral">Aviso de privacidad integral</a></li>
#                              <li><a href="https://www.gob.mx/privacidadsimplificado">Aviso de privacidad simplificado</a>
#                              </li>
#                              <li><a href="https://www.gob.mx/terminos">Términos y Condiciones</a></li>
#                              <li><a href="https://www.gob.mx/terminos#medidas-seguridad-informacion">Política de
#                                      seguridad</a></li>
#                              <li><a href="https://www.gob.mx/sitemap">Mapa de sitio</a></li>
#                          </ul>
#                      </div>
#
#                       <div class="col-sm-3">
#                          <h4 id="pie"><a href="https://www.gob.mx/tramites/ficha/presentacion-de-quejas-y-denuncias-en-la-sfp/SFP54">Denuncia
#                                  contra servidores públicos</a></h4> <br/><br/>
#                          <h4 id="pie">Síguenos en</h4>
#                          <h4><a aria-label="Facebook de presidencia" class="social-icon facebook" href="https://www.facebook.com/gobmexico" rel="noopener" target="_blank" title="Enlace abre en ventana nueva"><img alt="facebook" src="img/redes_sociales/faceb.png" width="10%"/></a><a aria-label="Twitter de presidencia" class="social-icon twitter" href="https://twitter.com/GobiernoMX" rel="noopener" target="_blank" title="Enlace abre en ventana nueva"><img alt="facebook" src="img/redes_sociales/twitt.png" width="10%"/></a></h4>
#                      </div>
#                  </div>
#              </div>
#          </div>,
#  <div class="container">
#                  <div class="row">
#                      <div class="col-md-3" style="margin-top: 15%;">
#                          <img alt="logo gobierno de méxico" class="logo_footer" data-v-9e928f9a="" href="/" src="https://framework-gb.cdn.gob.mx/landing/img/logoheader.svg" style="margin-top: 5%;"/>
#                      </div>
#
#                      <div class="col-sm-3">
#                          <h4 id="pie">Enlaces</h4>
#                          <ul>
#                              <li><a href="https://participa.gob.mx" rel="noopener" target="_blank" title="Enlace abre en ventana nueva">Participa</a></li>
#                              <li><a href="https://www.gob.mx/publicaciones" rel="noopener" target="_blank" title="Enlace abre en ventana nueva">Publicaciones Oficiales</a></li>
#                              <li><a href="http://www.ordenjuridico.gob.mx" rel="noopener" target="_blank" title="Enlace abre en ventana nueva">Marco Jurídico</a></li>
#                              <li><a href="https://consultapublicamx.inai.org.mx/vut-web/" rel="noopener" target="_blank" title="Enlace abre en ventana nueva">Plataforma Nacional de Transparencia</a></li>
#                          </ul>
#                      </div>
#
#                      <div class="col-sm-3">
#                          <h4 id="pie">¿Qué es gob.mx?</h4>
#                          <p id="pie">Es el portal único de trámites, información y participación ciudadana. <a href="https://www.gob.mx/que-es-gobmx">Leer más</a></p>
#                          <ul>
#                              <li><a href="https://datos.gob.mx">Portal de datos abiertos</a></li>
#                              <li><a href="https://www.gob.mx/accesibilidad">Declaración de accesibilidad</a></li>
#                              <li><a href="https://www.gob.mx/privacidadintegral">Aviso de privacidad integral</a></li>
#                              <li><a href="https://www.gob.mx/privacidadsimplificado">Aviso de privacidad simplificado</a>
#                              </li>
#                              <li><a href="https://www.gob.mx/terminos">Términos y Condiciones</a></li>
#                              <li><a href="https://www.gob.mx/terminos#medidas-seguridad-informacion">Política de
#                                      seguridad</a></li>
#                              <li><a href="https://www.gob.mx/sitemap">Mapa de sitio</a></li>
#                          </ul>
#                      </div>
#
#                       <div class="col-sm-3">
#                          <h4 id="pie"><a href="https://www.gob.mx/tramites/ficha/presentacion-de-quejas-y-denuncias-en-la-sfp/SFP54">Denuncia
#                                  contra servidores públicos</a></h4> <br/><br/>
#                          <h4 id="pie">Síguenos en</h4>
#                          <h4><a aria-label="Facebook de presidencia" class="social-icon facebook" href="https://www.facebook.com/gobmexico" rel="noopener" target="_blank" title="Enlace abre en ventana nueva"><img alt="facebook" src="img/redes_sociales/faceb.png" width="10%"/></a><a aria-label="Twitter de presidencia" class="social-icon twitter" href="https://twitter.com/GobiernoMX" rel="noopener" target="_blank" title="Enlace abre en ventana nueva"><img alt="facebook" src="img/redes_sociales/twitt.png" width="10%"/></a></h4>
#                      </div>
#                  </div>
#              </div>,
#  <div class="row">
#                      <div class="col-md-3" style="margin-top: 15%;">
#                          <img alt="logo gobierno de méxico" class="logo_footer" data-v-9e928f9a="" href="/" src="https://framework-gb.cdn.gob.mx/landing/img/logoheader.svg" style="margin-top: 5%;"/>
#                      </div>
#
#                      <div class="col-sm-3">
#                          <h4 id="pie">Enlaces</h4>
#                          <ul>
#                              <li><a href="https://participa.gob.mx" rel="noopener" target="_blank" title="Enlace abre en ventana nueva">Participa</a></li>
#                              <li><a href="https://www.gob.mx/publicaciones" rel="noopener" target="_blank" title="Enlace abre en ventana nueva">Publicaciones Oficiales</a></li>
#                              <li><a href="http://www.ordenjuridico.gob.mx" rel="noopener" target="_blank" title="Enlace abre en ventana nueva">Marco Jurídico</a></li>
#                              <li><a href="https://consultapublicamx.inai.org.mx/vut-web/" rel="noopener" target="_blank" title="Enlace abre en ventana nueva">Plataforma Nacional de Transparencia</a></li>
#                          </ul>
#                      </div>
#
#                      <div class="col-sm-3">
#                          <h4 id="pie">¿Qué es gob.mx?</h4>
#                          <p id="pie">Es el portal único de trámites, información y participación ciudadana. <a href="https://www.gob.mx/que-es-gobmx">Leer más</a></p>
#                          <ul>
#                              <li><a href="https://datos.gob.mx">Portal de datos abiertos</a></li>
#                              <li><a href="https://www.gob.mx/accesibilidad">Declaración de accesibilidad</a></li>
#                              <li><a href="https://www.gob.mx/privacidadintegral">Aviso de privacidad integral</a></li>
#                              <li><a href="https://www.gob.mx/privacidadsimplificado">Aviso de privacidad simplificado</a>
#                              </li>
#                              <li><a href="https://www.gob.mx/terminos">Términos y Condiciones</a></li>
#                              <li><a href="https://www.gob.mx/terminos#medidas-seguridad-informacion">Política de
#                                      seguridad</a></li>
#                              <li><a href="https://www.gob.mx/sitemap">Mapa de sitio</a></li>
#                          </ul>
#                      </div>
#
#                       <div class="col-sm-3">
#                          <h4 id="pie"><a href="https://www.gob.mx/tramites/ficha/presentacion-de-quejas-y-denuncias-en-la-sfp/SFP54">Denuncia
#                                  contra servidores públicos</a></h4> <br/><br/>
#                          <h4 id="pie">Síguenos en</h4>
#                          <h4><a aria-label="Facebook de presidencia" class="social-icon facebook" href="https://www.facebook.com/gobmexico" rel="noopener" target="_blank" title="Enlace abre en ventana nueva"><img alt="facebook" src="img/redes_sociales/faceb.png" width="10%"/></a><a aria-label="Twitter de presidencia" class="social-icon twitter" href="https://twitter.com/GobiernoMX" rel="noopener" target="_blank" title="Enlace abre en ventana nueva"><img alt="facebook" src="img/redes_sociales/twitt.png" width="10%"/></a></h4>
#                      </div>
#                  </div>,
#  <div class="col-md-3" style="margin-top: 15%;">
#                          <img alt="logo gobierno de méxico" class="logo_footer" data-v-9e928f9a="" href="/" src="https://framework-gb.cdn.gob.mx/landing/img/logoheader.svg" style="margin-top: 5%;"/>
#                      </div>,
#  <div class="col-sm-3">
#                          <h4 id="pie">Enlaces</h4>
#                          <ul>
#                              <li><a href="https://participa.gob.mx" rel="noopener" target="_blank" title="Enlace abre en ventana nueva">Participa</a></li>
#                              <li><a href="https://www.gob.mx/publicaciones" rel="noopener" target="_blank" title="Enlace abre en ventana nueva">Publicaciones Oficiales</a></li>
#                              <li><a href="http://www.ordenjuridico.gob.mx" rel="noopener" target="_blank" title="Enlace abre en ventana nueva">Marco Jurídico</a></li>
#                              <li><a href="https://consultapublicamx.inai.org.mx/vut-web/" rel="noopener" target="_blank" title="Enlace abre en ventana nueva">Plataforma Nacional de Transparencia</a></li>
#                          </ul>
#                      </div>,
#  <div class="col-sm-3">
#                          <h4 id="pie">¿Qué es gob.mx?</h4>
#                          <p id="pie">Es el portal único de trámites, información y participación ciudadana. <a href="https://www.gob.mx/que-es-gobmx">Leer más</a></p>
#                          <ul>
#                              <li><a href="https://datos.gob.mx">Portal de datos abiertos</a></li>
#                              <li><a href="https://www.gob.mx/accesibilidad">Declaración de accesibilidad</a></li>
#                              <li><a href="https://www.gob.mx/privacidadintegral">Aviso de privacidad integral</a></li>
#                              <li><a href="https://www.gob.mx/privacidadsimplificado">Aviso de privacidad simplificado</a>
#                              </li>
#                              <li><a href="https://www.gob.mx/terminos">Términos y Condiciones</a></li>
#                              <li><a href="https://www.gob.mx/terminos#medidas-seguridad-informacion">Política de
#                                      seguridad</a></li>
#                              <li><a href="https://www.gob.mx/sitemap">Mapa de sitio</a></li>
#                          </ul>
#                      </div>,
#  <div class="col-sm-3">
#                          <h4 id="pie"><a href="https://www.gob.mx/tramites/ficha/presentacion-de-quejas-y-denuncias-en-la-sfp/SFP54">Denuncia
#                                  contra servidores públicos</a></h4> <br/><br/>
#                          <h4 id="pie">Síguenos en</h4>
#                          <h4><a aria-label="Facebook de presidencia" class="social-icon facebook" href="https://www.facebook.com/gobmexico" rel="noopener" target="_blank" title="Enlace abre en ventana nueva"><img alt="facebook" src="img/redes_sociales/faceb.png" width="10%"/></a><a aria-label="Twitter de presidencia" class="social-icon twitter" href="https://twitter.com/GobiernoMX" rel="noopener" target="_blank" title="Enlace abre en ventana nueva"><img alt="facebook" src="img/redes_sociales/twitt.png" width="10%"/></a></h4>
#                      </div>,
#  <div id="sep">
#          <br/>
#      </div>]

# %%
sopa.find_all("div")
# Out:
# [<div class="collapse navbar-collapse" id="navbarNav">
#          <ul class="navbar-nav mr-auto">
#              <li class="nav-item active">
#                  <a class="nav-link" href="#"> <span class="sr-only">(current)</span></a>
#              </li>
#
#          </ul>
#          <ul class="navbar-nav" style="margin-right: 10%;">
#              <li class="nav-item">
#                  <a class="nav-link" href="https://www.gob.mx/gobierno" style="color: white;"> Gobierno</a>
#              </li>
#
#              <li class="nav-item">
#                  <a class="nav-link" href="https://www.gob.mx/participa" style="color: white;">Participa</a>
#              </li>
#
#              <li class="nav-item">
#                  <a class="nav-link" href="https://datos.gob.mx " style="color: white;">Datos</a>
#              </li>
#
#              <li class="nav-item">
#                  <a class="nav-item nav-link active" href="https://www.gob.mx/busqueda" style="color: white;">
#                      <span class="sr-only">Búsqueda</span>
#                      <svg aria-hidden="true" class="svg-inline--fa fa-search fa-w-16" data-fa-i2svg="" data-icon="search" data-prefix="fas" focusable="false" height="18" role="img" viewBox="0 0 512 512" width="18" xmlns="http://www.w3.org/2000/svg">
#                          <path d="M505 442.7L405.3 343c-4.5-4.5-10.6-7-17-7H372c27.6-35.3 44-79.7 44-128C416 93.1 322.9 0 208 0S0 93.1 0 208s93.1 208 208 208c48.3 0 92.7-16.4 128-44v16.3c0 6.4 2.5 12.5 7 17l99.7 99.7c9.4 9.4 24.6 9.4 33.9 0l28.3-28.3c9.4-9.4 9.4-24.6.1-34zM208 336c-70.7 0-128-57.2-128-128 0-70.7 57.2-128 128-128 70.7 0 128 57.2 128 128 0 70.7-57.2 128-128 128z" fill="currentColor"></path>
#                      </svg><!-- <i class="fas fa-search"></i> -->
#                  </a>
#              </li>
#
#          </ul>
#      </div>,
#  <div style="background-color: fff; width: 90%;
#             margin-left: 5%; margin-right:5%; margin-top:2%; margin-bottom:2%;">
#
#      <a href="https://www.gob.mx/">
#          <img alt="Gobierno de México" src="img/logotipos/pleca-gob1.png" style="width:30%;height:auto"/>
#      </a>
#      <a href="https://www.gob.mx/sep">
#          <img alt="Educación" src="img/logotipos/pleca-gob2.png" style="width:30%;height:auto; min-width:auto;"/>
#      </a>
#      <a href="https://www.tecnm.mx/">
#          <img alt="TecNM" src="img/logotipos/pleca_tecnm.jpg" style="width:18%;height:auto; "/>
#      </a>
#      <a href="https:/www.itlalaguna.edu.mx/">
#          <img alt="ITL" src="img/logotipos/itl2.jpeg" style="width:7%; height:auto;"/>
#      </a>
#  </div>,
#  <div class="collapse navbar-collapse" id="navbarSupportedContent">
#          <ul class="navbar-nav mr-auto" style="margin: auto;">
#
#              <li class="nav-item img-inicio-fix" id="dmenu">
#                  <a aria-expanded="false" aria-haspopup="true" class="nav-link" href="index.php" role="button">
#                  <img class="img-fluid" src="img/icono-home.png"/>
#                  </a>
#              </li>
#              <li class="nav-item" id="dmenu">
#                  <a aria-expanded="false" aria-haspopup="true" class="nav-link" href="directorio.php" role="button">
#                      Directorio
#                  </a>
#              </li>
#              <!--   1-->
#              <li class="nav-item dropdown" id="dmenu">
#
#                  <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" id="navbarDropdown" role="button">
#                      ¿Quiénes Somos?
#                  </a>
#                  <div class="dropdown-menu" style="background:#454547;">
#
#                      <a class="text-black dropdown-item" href="historia.php">HISTORIA</a>
#                      <a class="text-black dropdown-item" href="mision.php">MISIÓN Y VISIÓN</a>
#                      <a class="text-black dropdown-item" href="infra.php">UBICACIÓN E INFRAESCTRUCTURA</a>
#                      <a class="text-black dropdown-item" href="cuidadoMa.php">CUIDADO DEL MEDIO AMBIENTE</a>
#                      <a class="text-black dropdown-item" href="logos.php">MASCOTA Y LOGOS</a>
#                      <!--<a class="text-black dropdown-item" href="contacto.php">CONTACTO</a>-->
#
#                      <!--<a class="text-black dropdown-item" href="https://docs.google.com/forms/d/e/1FAIpQLSeE8OPXE5YSXIcA0zLvfCnaHtY0NQrbtSEr9VVMn8ZavzT_iA/viewform#response=ACYDBNiyCA6p87VDbN4lu-wVyLdVOv5qkOKwqxQXMwKijoJdEsQXK53UB9bS5t4">BUZÓN DE QUEJAS Y SUGERENCIAS</a>-->
#                      <a class="text-black dropdown-item" href="https://docs.google.com/forms/d/e/1FAIpQLSddMvuMgSe8qJ63G7op3Pcr5-VEuV2_UPElM977PS9lm8faug/viewform">BUZÓN DE QUEJAS Y SUGERENCIAS</a>
#
#                      <a class="text-black dropdown-item" href="https://docs.google.com/forms/d/e/1FAIpQLSckSqRPLi4GVYVthg5wP034P8tiEgBhyLnNcd6JCc7ZkE1KGg/viewform?entry.1159593137=nombre&amp;entry.1809109965&amp;entry.1214002645&amp;entry.1344596603&amp;entry.1727722980&amp;entry.1573787809=nombre+completo&amp;entry.471819699=puesto&amp;entry.285911030=ITL&amp;entry.134294733=2018-03-03&amp;entry.1785309787=20:00&amp;entry.1084813065=ITL&amp;entry.1814560733=hechos&amp;entry.1641027819=Nombre+testigo&amp;entry.1484745992=Domicilio+testigo&amp;entry.769034671=S%C3%AD&amp;entry.1684521492=si1&amp;entry.1680632340=si2">
#                          FORMATO DE DENUNCIAS DEL SG DE
#                          <br/>IGUALDAD DE GÉNERO Y NO DISCRIMINACIÓN</a>
#
#                      <a class="text-black dropdown-item" href="http://www.itlalaguna.edu.mx/etica/codigoetica.pdf">CÓDIGO DE ÉTICA Y CONDUCTA</a>
#                      <a class="text-black dropdown-item" href="https://www.tecnm.mx/?vista=Normateca">NORMATECA  DEL TECNM</a>
#
#
#                  </div>
#              </li>
#              <!-- PRUEBA -->
#     <!--2-->
#                 <!--2-->
#
#
#
#                 <li class="nav-item dropdown" id="dmenu">
#                  <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" id="navbarDropdown" role="button">
#                      Oferta Educativa
#                  </a>
#
#                  <div class="dropdown-menu" style="background:#454547;">
#                      <ul class="navbar-nav nav-dropdown dropdown-item" data-app-modern-menu="true" style="background:#454547;">
#                          <li class="nav-item dropdown dropdown-submenu" style="background:#454547;">
#                              <a aria-expanded="false" class="dropdown-toggle dropdown-item dropdown-submenu" data-toggle="dropdown-submenu" href="#" style="background:#454547;">NIVEL LICENCIATURA</a>
#                              <div class="dropdown-menu" style="background:#454547;">
#                                  <a class="text-black dropdown-item" href="sistemas.php">ING. SISTEMAS
#                                      COMPUTACIONALES</a>
#                                  <a class="text-black dropdown-item" href="electrica.php">ING. ELÉCTRICA</a>
#                                  <a class="text-black dropdown-item" href="electronica.php">ING. ELECTRÓNICA</a>
#                                  <a class="text-black dropdown-item" href="er.php">ING. EN ENERGÍAS
#                                      RENOVABLES</a>
#                                  <a class="text-black dropdown-item" href="industrial.php">ING.
#                                      INDUSTRIAL</a>
#                                  <a class="text-black dropdown-item" href="mecanica.php">ING. MECÁNICA</a>
#                                  <a class="text-black dropdown-item" href="mecatronica.php">ING.
#                                      MECATRÓNICA</a>
#                                  <a class="text-black dropdown-item" href="quimica.php">ING. QUÍMICA</a>
#                                  <a class="text-black dropdown-item" href="admin.php">LIC.
#                                      ADMINISTRACION</a>
#                                  <a class="text-black dropdown-item" href="gestionEmp.php">ING. GESTIÓN
#                                      EMPRESARIAL</a>
#
#                              </div>
#                          </li>
#                      </ul>
#                         <!-- <a class="link text-black dropdown-item" style="background:#454547;" href="http://www.itlalaguna.edu.mx/posgrado/indexposgrado.html" data-toggle="dropdown-submenu" aria-expanded="false">NIVEL POSGRADO</a>-->
#
#
#
#
#                      <ul class="navbar-nav nav-dropdown dropdown-item" data-app-modern-menu="true" style="background:#454547;">
#                          <li class="nav-item dropdown dropdown-submenu" style="background:#454547;">
#                              <a aria-expanded="false" class="dropdown-toggle dropdown-item dropdown-submenu" data-toggle="dropdown-submenu" href="#" style="background:#454547;">NIVEL POSGRADO</a>
#                              <div class="dropdown-menu" style="background:#454547;">
#
#                                  <a class="text-black dropdown-item" href="MAESTRIAE.php">MAESTRÍA EN CIENCIAS EN INGENIERÍA ELÉCTRICA (PNPC)</a>
#
#                                  <a class="text-black dropdown-item" href="MAESTRIAI.php">MAESTRÍA EN INGENIERÍA INDUSTRIAL</a>
#                                  <a class="text-black dropdown-item" href="MAESTRIAS.php">MAESTRÍA EN SISTEMAS COMPUTACIONALES</a>
#                                  <a class="text-black dropdown-item" href="DOCTORADOE.php">DOCTORADO EN CIENCIAS EN INGENIERÍA ELÉCTRICA (PNPC)</a>
#
#                              </div>
#                          </li>
#                      </ul>
#
#
#                       <!-- <ul class="navbar-nav nav-dropdown dropdown-item " style="background:#454547;" data-app-modern-menu="true">
#                          <li class="nav-item dropdown dropdown-submenu" style="background:#454547;">
#                              <a class="dropdown-toggle dropdown-item dropdown-submenu" style="background:#454547;" href="#" data-toggle="dropdown-submenu" aria-expanded="false">NIVEL LICENCIATURA A DISTANCIA</a>
#                              <div class=" dropdown-menu" style="background:#454547;">
#
#                                  <a class="text-black dropdown-item" href="industrial.php">ING.
#                                      INDUSTRIAL</a>
#
#                                  <a class="text-black dropdown-item" href="gestionEmp.php">ING. GESTIÓN
#                                      EMPRESARIAL</a>
#
#                              </div>
#                          </li>
#                      </ul>-->
#                      </div>
#
#              </li>
#              <!-- NEW 4 -->
#
#
#
#
#
#
#
#   <!-- 3-->
#
#   <!-- ALUMNADO2   ERA 4
#   <li class="nav-item dropdown" id='dmenu'>
#                  <a class="nav-link dropdown-toggle" id="navbarDropdown" role="button" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
#                      Aspirantes
#                  </a>
#                  <div class="dropdown-menu" style="background:#454547;">
#                      <a class="text-black dropdown-item" href="nivelacion.php">SEMESTRE DE NIVELACIÓN</a>
#                      <a class="text-black dropdown-item" href="http://apps2.itlalaguna.edu.mx:8081/">INGRESO LICENCIATURA</a>
#                      <a class="text-black dropdown-item" href="posgrado/indexposgrado.html">INGRESO POSGRADO</a>
#
#                  </div>
#              </li>
#
#              <li class="nav-item dropdown" id='dmenu'>
#                  <a class="nav-link dropdown-toggle" id="navbarDropdown" role="button" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
#                      Alumnado2
#                  </a>
#                  <div class="dropdown-menu" style="background:#454547; ">
#                      <ul class="navbar-nav nav-dropdown dropdown-item" style="background:#454547;" data-app-modern-menu="true">
#                          <li class="nav-item dropdown dropdown-submenu" style="background:#454547;">
#                              <a class="dropdown-toggle dropdown-item dropdown-submenu" id="smn3" style="background:#454547;" href="#" data-toggle="dropdown-submenu" aria-expanded="false">DIV. DE ESTUDIOS PROFESIONALES</a>
#                              <div class="dropdown-menu" style="background:#454547;">
#                                  <a class="dropdown-item" href="#">COORDINACIÓN DE TITULACIÓN</a>
#                                  <a class="dropdown-item" href="#">HORARIO MATERIAS</a>
#                                  <a class="dropdown-item" href="#">REINGRESO LICENCIATURA</a>
#                                  <a class="dropdown-item" href="#">VERANOS LICENCIATURA</a>
#                                  <a class="dropdown-item" href="#">REINGRESO POSGRADO</a>
#                                  <a class="dropdown-item" href="#">REINGRESO A DISTANCIA</a>
#                              </div>
#                          </li>
#                      </ul>
#                      <ul class="navbar-nav nav-dropdown dropdown-item" style="background:#454547;" data-app-modern-menu="true">
#                          <li class="nav-item dropdown" style="background:#454547;">
#                              <a class=" dropdown-toggle dropdown-item dropdown-submenu" href="http://escolares.itlalaguna.edu.mx" id="smn4" style="background:#454547;" href="#" data-toggle="dropdown-submenu" aria-expanded="false">SERVICIOS ESCOLARES</a>
#
#                          </li>
#                      </ul>
#                  </div>
#              </li>
#
#  -->
#
#
#     <!--2-->
#     <li class="nav-item dropdown" id="dmenu">
#                  <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" id="navbarDropdown" role="button">
#                      Alumnado
#                  </a>
#                  <div class="dropdown-menu" style="background:#454547;">
#                  <ul class="navbar-nav nav-dropdown dropdown-item" data-app-modern-menu="true" style="background:#454547;">
#                          <li class="nav-item dropdown dropdown-submenu" style="background:#454547;">
#                              <a aria-expanded="false" class="link text-black dropdown-toggle dropdown-item" data-toggle="dropdown-submenu" href="#" style="background:#454547;">DESARROLLO ACADÉMICO</a>
#                               <div class="dropdown-menu" style="background:#454547;">
#                              <a class="text-black dropdown-item" href="http://sed.itlalaguna.edu.mx/sed/">EVALUACIÓN AL PROFESORADO</a>
#
#                              <a class="dropdown-item" href="AVISOS/CALENDARIO.PDF">CALENDARIO ESCOLAR</a>
#                              </div>
#                          </li>
#                      </ul>
#                      <ul class="navbar-nav nav-dropdown dropdown-item" data-app-modern-menu="true" style="background:#454547;">
#                          <li class="nav-item dropdown dropdown-submenu" style="background:#454547;">
#                              <a aria-expanded="false" class="link text-black dropdown-toggle dropdown-item" data-toggle="dropdown-submenu" href="#" style="background:#454547;">DIVISIÓN DE ESTUDIOS PROFESIONALES</a>
#                               <div class="dropdown-menu" style="background:#454547;">
#
#                               <a class="dropdown-item" href="http://apps2.itlalaguna.edu.mx/inscripcion/login.aspx">CARGA DE MATERIAS</a>
#                               <!--<a class="dropdown-item" href="soporte@correo.itlalaguna.edu.mx">Si tienes algún problema escribe a <br>
#                               soporte@correo.itlalaguna.edu.mx <br> incluye número de control y <br>comprobante de pago
#                              </a>-->
#                               <a class="dropdown-item" href="http://apps.itlalaguna.edu.mx/servicios/academicos/horario_materias_2020/index.htm">HORARIO MATERIAS</a>
#                                <a class="text-black dropdown-item" href="titulacion.php">COORDINACIÓN DE TITULACIÓN</a>
#
#                              <a class="dropdown-item" href="http://apps2.itlalaguna.edu.mx:8082/">FICHAS DE PAGO REINGRESO</a>
#                              <a class="dropdown-item" href="COMITE/COMITE.PDF">COMITÉ ACADÉMICO</a>
#                              <a class="dropdown-item" href="ESPECIALES/ESPECIALES.PDF">EXÁMENES ESPECIALES</a>
#                              </div>
#                          </li>
#                      </ul>
#                      <a aria-expanded="false" class="link text-black dropdown-item" data-toggle="dropdown-submenu" href="REGLAMENTO/Manual_de_Lineamientos_TecNM.pdf" style="background:#454547;">MANUAL DE LINEAMIENTOS</a>
#                      <a aria-expanded="false" class="link text-black dropdown-item" data-toggle="dropdown-submenu" href="REGLAMENTO/REGLAMENTO2019.PDF" style="background:#454547;">REGLAMENTO ESTUDIANTIL</a>
#
#
#
#                      <a aria-expanded="false" class="link text-black dropdown-item" data-toggle="dropdown-submenu" href="http://escolares.itlalaguna.edu.mx" style="background:#454547;">SERVICIOS ESCOLARES</a>
#                      <a aria-expanded="false" class="link text-black dropdown-item" data-toggle="dropdown-submenu" href="extraescolares/extraescolares20.pdf" style="background:#454547;">ACTIVIDADES EXTRAESCOLARES</a>
#                  </div>
#              </li>
#
#
#
#
#              <!-- 3-->
#
#
#              <!-- 3-->
#              <li class="nav-item dropdown" id="dmenu">
#                  <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" id="navbarDropdown" role="button">
#                     Nuevo Ingreso
#                  </a>
#                  <div class="dropdown-menu" style="background:#454547;">
#
#                     <!-- <a class="text-black dropdown-item" href="http://apps2.itlalaguna.edu.mx:8081/">LICENCIATURA</a>-->
#                     <a class="text-black dropdown-item" href="ADMago.PHP">LICENCIATURA AGOSTO - DICIEMBRE</a>
#                     <a class="text-black dropdown-item" href="ADMcpago.PHP">POSGRADO AGOSTO - DICIEMBRE</a>
#                     <a class="text-black dropdown-item" href="nivelacion.php">NIVELACIÓN AGOSTO - DICIEMBRE</a>
#                     <a class="text-black dropdown-item" href="ADM.PHP">LICENCIATURA ENERO - JUNIO</a>
#                      <a class="text-black dropdown-item" href="ADMcp.PHP">POSGRADO ENERO - JUNIO</a>
#
#
#
#                      <!--<a class="text-black dropdown-item" href="ADMdis.PHP">LICENCIATURA MODALIDAD A DISTANCIA</a>-->
#
#                    <!--  <a class="text-black dropdown-item" href="distancia.php">INGRESO A DISTANCIA</a>-->
#                  </div>
#              </li>
#
#
#
#               <!-- 5-->
#               <li class="nav-item dropdown" id="dmenu">
#                  <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" id="navbarDropdown" role="button">
#                      Vinculación
#                  </a>
#                  <div class="dropdown-menu" style="background:#454547;">
#                      <a class="dropdown-item" href="http://www.itlalaguna.edu.mx/vinculacion/servsocial21.pdf">SERVICIO SOCIAL</a>
#                      <a class="dropdown-item" href="http://www.itlalaguna.edu.mx/vinculacion/bolsa_trabajo_2.pdf">BOLSA DE TRABAJO</a>
#                      <a class="dropdown-item" href="http://www.itlalaguna.edu.mx/vinculacion/servicios_externos.pdf">SERVICIO EXTERNOS</a>
#                      <a class="dropdown-item" href="http://www.itlalaguna.edu.mx/vinculacion/idiomas.pdf">IDIOMAS</a>
#                      <a class="dropdown-item" href="vinculacion/residencia/residencia-platica.pdf">SOLICITUD DE CARTA DE PRESENTACIÓN<br/> DE RESIDENCIA PROFESIONAL</a>
#
#                  </div>
#              </li>
#               <!-- 6-->
#               <li class="nav-item dropdown" id="dmenu">
#                  <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" id="navbarDropdown" role="button">
#                      Personal
#                  </a>
#                  <div class="dropdown-menu" style="background:#454547;">
#                      <a class="dropdown-item" href="http://apps.itlalaguna.edu.mx/servicios/personal/catedraticos/index18.html">DOCENTES CARGA DE TRABAJO</a>
#                      <!--<a class=" dropdown-item" href="http://apps2.itlalaguna.edu.mx/SGESCL/login.aspx">DOCENTES CALIFICACIONES</a>-->
#                      <a class="dropdown-item" href="becasint/becasint.html">CONVOCATORIAS</a>
#                      <a class="dropdown-item" href="REGLAMENTOS.PHP">REGLAMENTOS</a>
#                      <a class="dropdown-item" href="CONTRALORIA.PHP">PRODEP</a>
#                  </div>
#              </li>
#              <!-- 7-->
#              <!--  <li class="nav-item dropdown" id='dmenu'>
#                  <a class="nav-link dropdown-toggle" id="navbarDropdown" data-toggle="dropdown" role="button" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
#                      Mejora Continua
#                  </a>
#                  <div class="dropdown-menu" style="background:#454547;">
#                      <a class=" dropdown-item" href="#">CONTROL DE DOCUMENTOS</a>
#                      <a class=" dropdown-item" href="#">SISTEMA DE GESTIÓN INTEGRAL</a>
#                      <a class=" dropdown-item" href="#">SISTEMA DE G.DE IGUALDAD DE GÉNERO</a>
#                      <a class=" dropdown-item" href="#">BUZÓN DE QUEJAS Y SUGERENCIAS</a>
#                      <a class=" dropdown-item" href="#">INNOVACIÓN Y DESARROLLO (PIID ITLaguna)</a>
#
#                  </div>
#              </li>-->
#          </ul>
#      </div>,
#  <div class="dropdown-menu" style="background:#454547;">
#
#                      <a class="text-black dropdown-item" href="historia.php">HISTORIA</a>
#                      <a class="text-black dropdown-item" href="mision.php">MISIÓN Y VISIÓN</a>
#                      <a class="text-black dropdown-item" href="infra.php">UBICACIÓN E INFRAESCTRUCTURA</a>
#                      <a class="text-black dropdown-item" href="cuidadoMa.php">CUIDADO DEL MEDIO AMBIENTE</a>
#                      <a class="text-black dropdown-item" href="logos.php">MASCOTA Y LOGOS</a>
#                      <!--<a class="text-black dropdown-item" href="contacto.php">CONTACTO</a>-->
#
#                      <!--<a class="text-black dropdown-item" href="https://docs.google.com/forms/d/e/1FAIpQLSeE8OPXE5YSXIcA0zLvfCnaHtY0NQrbtSEr9VVMn8ZavzT_iA/viewform#response=ACYDBNiyCA6p87VDbN4lu-wVyLdVOv5qkOKwqxQXMwKijoJdEsQXK53UB9bS5t4">BUZÓN DE QUEJAS Y SUGERENCIAS</a>-->
#                      <a class="text-black dropdown-item" href="https://docs.google.com/forms/d/e/1FAIpQLSddMvuMgSe8qJ63G7op3Pcr5-VEuV2_UPElM977PS9lm8faug/viewform">BUZÓN DE QUEJAS Y SUGERENCIAS</a>
#
#                      <a class="text-black dropdown-item" href="https://docs.google.com/forms/d/e/1FAIpQLSckSqRPLi4GVYVthg5wP034P8tiEgBhyLnNcd6JCc7ZkE1KGg/viewform?entry.1159593137=nombre&amp;entry.1809109965&amp;entry.1214002645&amp;entry.1344596603&amp;entry.1727722980&amp;entry.1573787809=nombre+completo&amp;entry.471819699=puesto&amp;entry.285911030=ITL&amp;entry.134294733=2018-03-03&amp;entry.1785309787=20:00&amp;entry.1084813065=ITL&amp;entry.1814560733=hechos&amp;entry.1641027819=Nombre+testigo&amp;entry.1484745992=Domicilio+testigo&amp;entry.769034671=S%C3%AD&amp;entry.1684521492=si1&amp;entry.1680632340=si2">
#                          FORMATO DE DENUNCIAS DEL SG DE
#                          <br/>IGUALDAD DE GÉNERO Y NO DISCRIMINACIÓN</a>
#
#                      <a class="text-black dropdown-item" href="http://www.itlalaguna.edu.mx/etica/codigoetica.pdf">CÓDIGO DE ÉTICA Y CONDUCTA</a>
#                      <a class="text-black dropdown-item" href="https://www.tecnm.mx/?vista=Normateca">NORMATECA  DEL TECNM</a>
#
#
#                  </div>,
#  <div class="dropdown-menu" style="background:#454547;">
#                      <ul class="navbar-nav nav-dropdown dropdown-item" data-app-modern-menu="true" style="background:#454547;">
#                          <li class="nav-item dropdown dropdown-submenu" style="background:#454547;">
#                              <a aria-expanded="false" class="dropdown-toggle dropdown-item dropdown-submenu" data-toggle="dropdown-submenu" href="#" style="background:#454547;">NIVEL LICENCIATURA</a>
#                              <div class="dropdown-menu" style="background:#454547;">
#                                  <a class="text-black dropdown-item" href="sistemas.php">ING. SISTEMAS
#                                      COMPUTACIONALES</a>
#                                  <a class="text-black dropdown-item" href="electrica.php">ING. ELÉCTRICA</a>
#                                  <a class="text-black dropdown-item" href="electronica.php">ING. ELECTRÓNICA</a>
#                                  <a class="text-black dropdown-item" href="er.php">ING. EN ENERGÍAS
#                                      RENOVABLES</a>
#                                  <a class="text-black dropdown-item" href="industrial.php">ING.
#                                      INDUSTRIAL</a>
#                                  <a class="text-black dropdown-item" href="mecanica.php">ING. MECÁNICA</a>
#                                  <a class="text-black dropdown-item" href="mecatronica.php">ING.
#                                      MECATRÓNICA</a>
#                                  <a class="text-black dropdown-item" href="quimica.php">ING. QUÍMICA</a>
#                                  <a class="text-black dropdown-item" href="admin.php">LIC.
#                                      ADMINISTRACION</a>
#                                  <a class="text-black dropdown-item" href="gestionEmp.php">ING. GESTIÓN
#                                      EMPRESARIAL</a>
#
#                              </div>
#                          </li>
#                      </ul>
#                         <!-- <a class="link text-black dropdown-item" style="background:#454547;" href="http://www.itlalaguna.edu.mx/posgrado/indexposgrado.html" data-toggle="dropdown-submenu" aria-expanded="false">NIVEL POSGRADO</a>-->
#
#
#
#
#                      <ul class="navbar-nav nav-dropdown dropdown-item" data-app-modern-menu="true" style="background:#454547;">
#                          <li class="nav-item dropdown dropdown-submenu" style="background:#454547;">
#                              <a aria-expanded="false" class="dropdown-toggle dropdown-item dropdown-submenu" data-toggle="dropdown-submenu" href="#" style="background:#454547;">NIVEL POSGRADO</a>
#                              <div class="dropdown-menu" style="background:#454547;">
#
#                                  <a class="text-black dropdown-item" href="MAESTRIAE.php">MAESTRÍA EN CIENCIAS EN INGENIERÍA ELÉCTRICA (PNPC)</a>
#
#                                  <a class="text-black dropdown-item" href="MAESTRIAI.php">MAESTRÍA EN INGENIERÍA INDUSTRIAL</a>
#                                  <a class="text-black dropdown-item" href="MAESTRIAS.php">MAESTRÍA EN SISTEMAS COMPUTACIONALES</a>
#                                  <a class="text-black dropdown-item" href="DOCTORADOE.php">DOCTORADO EN CIENCIAS EN INGENIERÍA ELÉCTRICA (PNPC)</a>
#
#                              </div>
#                          </li>
#                      </ul>
#
#
#                       <!-- <ul class="navbar-nav nav-dropdown dropdown-item " style="background:#454547;" data-app-modern-menu="true">
#                          <li class="nav-item dropdown dropdown-submenu" style="background:#454547;">
#                              <a class="dropdown-toggle dropdown-item dropdown-submenu" style="background:#454547;" href="#" data-toggle="dropdown-submenu" aria-expanded="false">NIVEL LICENCIATURA A DISTANCIA</a>
#                              <div class=" dropdown-menu" style="background:#454547;">
#
#                                  <a class="text-black dropdown-item" href="industrial.php">ING.
#                                      INDUSTRIAL</a>
#
#                                  <a class="text-black dropdown-item" href="gestionEmp.php">ING. GESTIÓN
#                                      EMPRESARIAL</a>
#
#                              </div>
#                          </li>
#                      </ul>-->
#                      </div>,
#  <div class="dropdown-menu" style="background:#454547;">
#                                  <a class="text-black dropdown-item" href="sistemas.php">ING. SISTEMAS
#                                      COMPUTACIONALES</a>
#                                  <a class="text-black dropdown-item" href="electrica.php">ING. ELÉCTRICA</a>
#                                  <a class="text-black dropdown-item" href="electronica.php">ING. ELECTRÓNICA</a>
#                                  <a class="text-black dropdown-item" href="er.php">ING. EN ENERGÍAS
#                                      RENOVABLES</a>
#                                  <a class="text-black dropdown-item" href="industrial.php">ING.
#                                      INDUSTRIAL</a>
#                                  <a class="text-black dropdown-item" href="mecanica.php">ING. MECÁNICA</a>
#                                  <a class="text-black dropdown-item" href="mecatronica.php">ING.
#                                      MECATRÓNICA</a>
#                                  <a class="text-black dropdown-item" href="quimica.php">ING. QUÍMICA</a>
#                                  <a class="text-black dropdown-item" href="admin.php">LIC.
#                                      ADMINISTRACION</a>
#                                  <a class="text-black dropdown-item" href="gestionEmp.php">ING. GESTIÓN
#                                      EMPRESARIAL</a>
#
#                              </div>,
#  <div class="dropdown-menu" style="background:#454547;">
#
#                                  <a class="text-black dropdown-item" href="MAESTRIAE.php">MAESTRÍA EN CIENCIAS EN INGENIERÍA ELÉCTRICA (PNPC)</a>
#
#                                  <a class="text-black dropdown-item" href="MAESTRIAI.php">MAESTRÍA EN INGENIERÍA INDUSTRIAL</a>
#                                  <a class="text-black dropdown-item" href="MAESTRIAS.php">MAESTRÍA EN SISTEMAS COMPUTACIONALES</a>
#                                  <a class="text-black dropdown-item" href="DOCTORADOE.php">DOCTORADO EN CIENCIAS EN INGENIERÍA ELÉCTRICA (PNPC)</a>
#
#                              </div>,
#  <div class="dropdown-menu" style="background:#454547;">
#                  <ul class="navbar-nav nav-dropdown dropdown-item" data-app-modern-menu="true" style="background:#454547;">
#                          <li class="nav-item dropdown dropdown-submenu" style="background:#454547;">
#                              <a aria-expanded="false" class="link text-black dropdown-toggle dropdown-item" data-toggle="dropdown-submenu" href="#" style="background:#454547;">DESARROLLO ACADÉMICO</a>
#                               <div class="dropdown-menu" style="background:#454547;">
#                              <a class="text-black dropdown-item" href="http://sed.itlalaguna.edu.mx/sed/">EVALUACIÓN AL PROFESORADO</a>
#
#                              <a class="dropdown-item" href="AVISOS/CALENDARIO.PDF">CALENDARIO ESCOLAR</a>
#                              </div>
#                          </li>
#                      </ul>
#                      <ul class="navbar-nav nav-dropdown dropdown-item" data-app-modern-menu="true" style="background:#454547;">
#                          <li class="nav-item dropdown dropdown-submenu" style="background:#454547;">
#                              <a aria-expanded="false" class="link text-black dropdown-toggle dropdown-item" data-toggle="dropdown-submenu" href="#" style="background:#454547;">DIVISIÓN DE ESTUDIOS PROFESIONALES</a>
#                               <div class="dropdown-menu" style="background:#454547;">
#
#                               <a class="dropdown-item" href="http://apps2.itlalaguna.edu.mx/inscripcion/login.aspx">CARGA DE MATERIAS</a>
#                               <!--<a class="dropdown-item" href="soporte@correo.itlalaguna.edu.mx">Si tienes algún problema escribe a <br>
#                               soporte@correo.itlalaguna.edu.mx <br> incluye número de control y <br>comprobante de pago
#                              </a>-->
#                               <a class="dropdown-item" href="http://apps.itlalaguna.edu.mx/servicios/academicos/horario_materias_2020/index.htm">HORARIO MATERIAS</a>
#                                <a class="text-black dropdown-item" href="titulacion.php">COORDINACIÓN DE TITULACIÓN</a>
#
#                              <a class="dropdown-item" href="http://apps2.itlalaguna.edu.mx:8082/">FICHAS DE PAGO REINGRESO</a>
#                              <a class="dropdown-item" href="COMITE/COMITE.PDF">COMITÉ ACADÉMICO</a>
#                              <a class="dropdown-item" href="ESPECIALES/ESPECIALES.PDF">EXÁMENES ESPECIALES</a>
#                              </div>
#                          </li>
#                      </ul>
#                      <a aria-expanded="false" class="link text-black dropdown-item" data-toggle="dropdown-submenu" href="REGLAMENTO/Manual_de_Lineamientos_TecNM.pdf" style="background:#454547;">MANUAL DE LINEAMIENTOS</a>
#                      <a aria-expanded="false" class="link text-black dropdown-item" data-toggle="dropdown-submenu" href="REGLAMENTO/REGLAMENTO2019.PDF" style="background:#454547;">REGLAMENTO ESTUDIANTIL</a>
#
#
#
#                      <a aria-expanded="false" class="link text-black dropdown-item" data-toggle="dropdown-submenu" href="http://escolares.itlalaguna.edu.mx" style="background:#454547;">SERVICIOS ESCOLARES</a>
#                      <a aria-expanded="false" class="link text-black dropdown-item" data-toggle="dropdown-submenu" href="extraescolares/extraescolares20.pdf" style="background:#454547;">ACTIVIDADES EXTRAESCOLARES</a>
#                  </div>,
#  <div class="dropdown-menu" style="background:#454547;">
#                              <a class="text-black dropdown-item" href="http://sed.itlalaguna.edu.mx/sed/">EVALUACIÓN AL PROFESORADO</a>
#
#                              <a class="dropdown-item" href="AVISOS/CALENDARIO.PDF">CALENDARIO ESCOLAR</a>
#                              </div>,
#  <div class="dropdown-menu" style="background:#454547;">
#
#                               <a class="dropdown-item" href="http://apps2.itlalaguna.edu.mx/inscripcion/login.aspx">CARGA DE MATERIAS</a>
#                               <!--<a class="dropdown-item" href="soporte@correo.itlalaguna.edu.mx">Si tienes algún problema escribe a <br>
#                               soporte@correo.itlalaguna.edu.mx <br> incluye número de control y <br>comprobante de pago
#                              </a>-->
#                               <a class="dropdown-item" href="http://apps.itlalaguna.edu.mx/servicios/academicos/horario_materias_2020/index.htm">HORARIO MATERIAS</a>
#                                <a class="text-black dropdown-item" href="titulacion.php">COORDINACIÓN DE TITULACIÓN</a>
#
#                              <a class="dropdown-item" href="http://apps2.itlalaguna.edu.mx:8082/">FICHAS DE PAGO REINGRESO</a>
#                              <a class="dropdown-item" href="COMITE/COMITE.PDF">COMITÉ ACADÉMICO</a>
#                              <a class="dropdown-item" href="ESPECIALES/ESPECIALES.PDF">EXÁMENES ESPECIALES</a>
#                              </div>,
#  <div class="dropdown-menu" style="background:#454547;">
#
#                     <!-- <a class="text-black dropdown-item" href="http://apps2.itlalaguna.edu.mx:8081/">LICENCIATURA</a>-->
#                     <a class="text-black dropdown-item" href="ADMago.PHP">LICENCIATURA AGOSTO - DICIEMBRE</a>
#                     <a class="text-black dropdown-item" href="ADMcpago.PHP">POSGRADO AGOSTO - DICIEMBRE</a>
#                     <a class="text-black dropdown-item" href="nivelacion.php">NIVELACIÓN AGOSTO - DICIEMBRE</a>
#                     <a class="text-black dropdown-item" href="ADM.PHP">LICENCIATURA ENERO - JUNIO</a>
#                      <a class="text-black dropdown-item" href="ADMcp.PHP">POSGRADO ENERO - JUNIO</a>
#
#
#
#                      <!--<a class="text-black dropdown-item" href="ADMdis.PHP">LICENCIATURA MODALIDAD A DISTANCIA</a>-->
#
#                    <!--  <a class="text-black dropdown-item" href="distancia.php">INGRESO A DISTANCIA</a>-->
#                  </div>,
#  <div class="dropdown-menu" style="background:#454547;">
#                      <a class="dropdown-item" href="http://www.itlalaguna.edu.mx/vinculacion/servsocial21.pdf">SERVICIO SOCIAL</a>
#                      <a class="dropdown-item" href="http://www.itlalaguna.edu.mx/vinculacion/bolsa_trabajo_2.pdf">BOLSA DE TRABAJO</a>
#                      <a class="dropdown-item" href="http://www.itlalaguna.edu.mx/vinculacion/servicios_externos.pdf">SERVICIO EXTERNOS</a>
#                      <a class="dropdown-item" href="http://www.itlalaguna.edu.mx/vinculacion/idiomas.pdf">IDIOMAS</a>
#                      <a class="dropdown-item" href="vinculacion/residencia/residencia-platica.pdf">SOLICITUD DE CARTA DE PRESENTACIÓN<br/> DE RESIDENCIA PROFESIONAL</a>
#
#                  </div>,
#  <div class="dropdown-menu" style="background:#454547;">
#                      <a class="dropdown-item" href="http://apps.itlalaguna.edu.mx/servicios/personal/catedraticos/index18.html">DOCENTES CARGA DE TRABAJO</a>
#                      <!--<a class=" dropdown-item" href="http://apps2.itlalaguna.edu.mx/SGESCL/login.aspx">DOCENTES CALIFICACIONES</a>-->
#                      <a class="dropdown-item" href="becasint/becasint.html">CONVOCATORIAS</a>
#                      <a class="dropdown-item" href="REGLAMENTOS.PHP">REGLAMENTOS</a>
#                      <a class="dropdown-item" href="CONTRALORIA.PHP">PRODEP</a>
#                  </div>,
#  <div class="slideshow-container">
#
#  <!--<div class="mySlides1">
#
#
#              <img src="slider/AVISovacuna.png" style="width:100%">
#      </div>
#      -->
#
#
#
#
#
#
#  <div class="mySlides1">
#          <a href="avisos/registro-office.pdf">
#
#              <img src="slider/office.png" style="width:100%"/></a>
#      </div>
#      <div class="mySlides1">
#          <a href="https://www.tecnm.mx/menu/convocatorias_tecnm/01_InvCientifica_Academicos_Convocatoria_2021-2.pdf">
#
#              <img src="slider/convoinvest2.png" style="width:100%"/></a>
#      </div>
#
#  <div class="mySlides1">
#          <a href="avisos/solicitud protocolos  titulación_mayo 2021.pdf">
#
#              <img src="slider/solicitud protocolos  titulación_mayo 2021.png" style="width:100%"/></a>
#      </div>
#
#  <div class="mySlides1">
#          <a href="avisos/registro proyectos titulación_mayo 2021.pdf">
#
#              <img src="slider/registro proyectos titulación_mayo 2021.png" style="width:100%"/></a>
#      </div>
#
#
#  <div class="mySlides1">
#          <a href="https://escolares.itlalaguna.edu.mx/web/index.php/entrega-de-certificados/">
#
#              <img src="slider/certificados2.png" style="width:100%"/></a>
#      </div>
#
#
#  <div class="mySlides1">
#          <a href="ADMago.PHP">
#
#              <img src="slider/adm21ago2.png" style="width:100%"/></a>
#      </div>
#
#
#
#       <div class="mySlides1">
#
#         <img src="slider/puertas.jpg" style="width:100%"/>
#      </div>
#
#
#        <!-- <div class="mySlides1">
#          <a href="https://www.gob.mx/cms/uploads/attachment/file/617238/MANUTENCION_FEDERAL.pdf">
#
#              <img src="slider/becas.jpg" style="width:100%"></a>
#      </div>-->
#
#  <div class="mySlides1">
#          <a href="http://mooc.tecnm.mx/">
#
#              <img src="slider/mooc.jpg" style="width:100%"/></a>
#      </div>
#
#  <!--<div class="mySlides1">
#          <a href="https://docs.google.com/forms/d/e/1FAIpQLSeB0dMOHIapAMmylfW-sgKBPudl7-2krNWwB2Naud24UI0yaA/viewform?pli=1">
#
#              <img src="slider/ti2.jpg" style="width:100%"></a>
#      </div>
#
#  <div class="mySlides1">
#          <a href="https://forms.gle/JqEd4btNsP73eRvJ8">
#
#              <img src="slider/protocolos.png" style="width:100%"></a>
#      </div>-->
#  <div class="mySlides1">
#          <a href="avisos/convocatoria anfei.pdf">
#              <img src="slider/cienciasbasicas.png" style="width:100%"/></a>
#      </div>
#      <div class="mySlides1">
#          <a href="avisos/tripticoetica.pdf">
#              <img src="slider/tripticoetica.jpg" style="width:100%"/></a>
#      </div>
#
#
#
#
#
#
#  <!--<div class="mySlides1">
#          <a href="AVISOS/CALENDARIOEJ21.PDF">
#              <img src="slider/CALENDARIOEJ212.png" style="width:100%"></a>
#      </div>-->
#
#
#      <div class="mySlides1">
#          <a href="https://docs.google.com/forms/d/e/1FAIpQLSeco-OxDhHp_81y0fcDNBKu0dPQakLceC1tHWM49gjPnJdurQ/viewform">
#              <img src="slider/bioetica.jpg" style="width:100%"/></a>
#      </div>
#  <div class="mySlides1">
#          <a href="http://forms.gle/skuGWT2vabzxyDVp9">
#              <img src="slider/evalingles2.png" style="width:100%"/></a>
#      </div>
#
#
#
#      <div class="mySlides1">
#          <a href="avisos/ci2021.pdf">
#              <img src="slider/ci20212.png" style="width:100%"/></a>
#      </div>
#
#
#
#
#
#
#
#
#  <div class="mySlides1">
#          <a href="AVISOS/anfei20.PDF">
#              <img src="slider/anfei202.png" style="width:100%"/></a>
#      </div>
#
#
#
#
#
#  <div class="mySlides1">
#
#              <img src="slider/ingles203.jpg" style="width:100%"/>
#      </div>
#      <div class="mySlides1">
#          <a href="calidad/mejoracontinua.pdf">
#              <img src="slider/cero tolerancia2.jpg" style="width:100%"/></a>
#      </div>
#
#
#
#
#
#
#  <div class="mySlides1">
#          <a href="../avisos/elibro.pdf">
#              <img src="slider/elibro2.png" style="width:100%"/></a>
#      </div>
#
#
#
#
#
#      <div class="mySlides1">
#          <a href="directorio.php">
#              <img src="slider/directorio212.png" style="width:100%"/></a>
#      </div>
#
#
#
#
#
#      <div class="mySlides1">
#
#          <img src="slider/redesof.png" style="width:100%"/>
#      </div>
#
#
#
#
#      <div class="mySlides1">
#          <a href="https://www.tecnm.mx/?vista=TecNM_Virtual"><img src="slider/tecnmvirtual2.jpg" style="width:100%"/></a>
#      </div>
#
#
#      <div class="mySlides1">
#          <a href="avisos/gradua202.pdf">
#
#              <img src="slider/gradua204.jpg" style="width:100%"/></a>
#      </div>
#
#      <div class="mySlides1">
#          <a href="https://bit.ly/2VGuGuK">
#              <img src="slider/protocolo202.jpg" style="width:100%"/></a>
#      </div>
#
#      <div class="mySlides1">
#          <a href="https://bit.ly/2Toczbt">
#              <img src="slider/cerotolerancia202.jpg" style="width:100%"/></a>
#      </div>
#
#
#
#
#
#
#      </div>,
#  <div class="mySlides1">
#          <a href="avisos/registro-office.pdf">
#
#              <img src="slider/office.png" style="width:100%"/></a>
#      </div>,
#  <div class="mySlides1">
#          <a href="https://www.tecnm.mx/menu/convocatorias_tecnm/01_InvCientifica_Academicos_Convocatoria_2021-2.pdf">
#
#              <img src="slider/convoinvest2.png" style="width:100%"/></a>
#      </div>,
#  <div class="mySlides1">
#          <a href="avisos/solicitud protocolos  titulación_mayo 2021.pdf">
#
#              <img src="slider/solicitud protocolos  titulación_mayo 2021.png" style="width:100%"/></a>
#      </div>,
#  <div class="mySlides1">
#          <a href="avisos/registro proyectos titulación_mayo 2021.pdf">
#
#              <img src="slider/registro proyectos titulación_mayo 2021.png" style="width:100%"/></a>
#      </div>,
#  <div class="mySlides1">
#          <a href="https://escolares.itlalaguna.edu.mx/web/index.php/entrega-de-certificados/">
#
#              <img src="slider/certificados2.png" style="width:100%"/></a>
#      </div>,
#  <div class="mySlides1">
#          <a href="ADMago.PHP">
#
#              <img src="slider/adm21ago2.png" style="width:100%"/></a>
#      </div>,
#  <div class="mySlides1">
#
#         <img src="slider/puertas.jpg" style="width:100%"/>
#      </div>,
#  <div class="mySlides1">
#          <a href="http://mooc.tecnm.mx/">
#
#              <img src="slider/mooc.jpg" style="width:100%"/></a>
#      </div>,
#  <div class="mySlides1">
#          <a href="avisos/convocatoria anfei.pdf">
#              <img src="slider/cienciasbasicas.png" style="width:100%"/></a>
#      </div>,
#  <div class="mySlides1">
#          <a href="avisos/tripticoetica.pdf">
#              <img src="slider/tripticoetica.jpg" style="width:100%"/></a>
#      </div>,
#  <div class="mySlides1">
#          <a href="https://docs.google.com/forms/d/e/1FAIpQLSeco-OxDhHp_81y0fcDNBKu0dPQakLceC1tHWM49gjPnJdurQ/viewform">
#              <img src="slider/bioetica.jpg" style="width:100%"/></a>
#      </div>,
#  <div class="mySlides1">
#          <a href="http://forms.gle/skuGWT2vabzxyDVp9">
#              <img src="slider/evalingles2.png" style="width:100%"/></a>
#      </div>,
#  <div class="mySlides1">
#          <a href="avisos/ci2021.pdf">
#              <img src="slider/ci20212.png" style="width:100%"/></a>
#      </div>,
#  <div class="mySlides1">
#          <a href="AVISOS/anfei20.PDF">
#              <img src="slider/anfei202.png" style="width:100%"/></a>
#      </div>,
#  <div class="mySlides1">
#
#              <img src="slider/ingles203.jpg" style="width:100%"/>
#      </div>,
#  <div class="mySlides1">
#          <a href="calidad/mejoracontinua.pdf">
#              <img src="slider/cero tolerancia2.jpg" style="width:100%"/></a>
#      </div>,
#  <div class="mySlides1">
#          <a href="../avisos/elibro.pdf">
#              <img src="slider/elibro2.png" style="width:100%"/></a>
#      </div>,
#  <div class="mySlides1">
#          <a href="directorio.php">
#              <img src="slider/directorio212.png" style="width:100%"/></a>
#      </div>,
#  <div class="mySlides1">
#
#          <img src="slider/redesof.png" style="width:100%"/>
#      </div>,
#  <div class="mySlides1">
#          <a href="https://www.tecnm.mx/?vista=TecNM_Virtual"><img src="slider/tecnmvirtual2.jpg" style="width:100%"/></a>
#      </div>,
#  <div class="mySlides1">
#          <a href="avisos/gradua202.pdf">
#
#              <img src="slider/gradua204.jpg" style="width:100%"/></a>
#      </div>,
#  <div class="mySlides1">
#          <a href="https://bit.ly/2VGuGuK">
#              <img src="slider/protocolo202.jpg" style="width:100%"/></a>
#      </div>,
#  <div class="mySlides1">
#          <a href="https://bit.ly/2Toczbt">
#              <img src="slider/cerotolerancia202.jpg" style="width:100%"/></a>
#      </div>,
#  <div id="bolitas">
#              <span class="bolita" onclick="foto(1)"></span>
#              <span class="bolita" onclick="foto(2)"></span>
#              <span class="bolita" onclick="foto(3)"></span>
#              <span class="bolita" onclick="foto(4)"></span>
#              <span class="bolita" onclick="foto(5)"></span>
#              <span class="bolita" onclick="foto(6)"></span>
#              <span class="bolita" onclick="foto(7)"></span>
# ...
#                                  de Obligaciones de Transparencia</a></li>
#                          <li><a href="http://inicio.ifai.org.mx/SitePages/ifai.aspx" id="pie" style="color:#fff">INAI</a>
#                          </li>
#                          <li><a data-target="#modalQuejas" data-toggle="modal" href="#" id="pie" style="color:#fff">Buzón
#                                  de Sugerencias</a></li>
#                          <li><span data-target="#modalQuejas" data-toggle="modal" href="#" id="pie" style="color:#fff">Visitas</span>
#
#
#
#  <!-- Histats.com  START  (standard)-->
#  <script type="text/javascript">document.write(unescape("%3Cscript src=%27http://s10.histats.com/js15.js%27 type=%27text/javascript%27%3E%3C/script%3E"));</script>
#  <a href="http://www.histats.com" target="_blank" title="contadores web free"><script type="text/javascript">
#  try {Histats.start(1,1838853,4,4003,112,61,"00011011");
#  Histats.track_hits();} catch(err){};
#  </script></a>
#  <noscript></noscript>
#  <!-- Histats.com  END  -->
#
#
#
#  <!-- Start of StatCounter Code -->
#
#  <script type="text/javascript">
#  var sc_project=7949821;
#  var sc_invisible=1;
#  var sc_partition=59;
#  var sc_click_stat=1;
#  var sc_security="8c4af0fe";
#  </script>
#
#  <script src="http://www.statcounter.com/counter/counter.js" type="text/javascript"></script>
#  <!-- End of StatCounter Code --><br/>
#  <a href="http://my.statcounter.com/project/standard/stats.php?project_id=7949821&amp;guest=1" onclick="_gaq.push(['_trackEvent','links menu', 'abandono', 'estadisticas']);" target="_blank">Estadísticas</a>
#
#
#     <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#    (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#    m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#    })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#    ga('create', 'UA-54252992-1', 'auto');
#    ga('send', 'pageview');
#
#  </script>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                              </li>
#
#
#
#
#
#
#
#
#                      </ul>
#                  </div>,
#  <div class="col-lg-3">
#                      <h3 id="pie"> Ubicación </h3>
#                      <img height="70%" src="img/ubicacionITL.jpeg" width="100%"/>
#                      <a href="infra.php" id="pie"> Ver Ubicación </a>
#                  </div>,
#  <div id="sep">
#          <br/>
#      </div>,
#  <div class="list-info">
#              <div class="container">
#                  <div class="row">
#                      <div class="col-md-3" style="margin-top: 15%;">
#                          <img alt="logo gobierno de méxico" class="logo_footer" data-v-9e928f9a="" href="/" src="https://framework-gb.cdn.gob.mx/landing/img/logoheader.svg" style="margin-top: 5%;"/>
#                      </div>
#
#                      <div class="col-sm-3">
#                          <h4 id="pie">Enlaces</h4>
#                          <ul>
#                              <li><a href="https://participa.gob.mx" rel="noopener" target="_blank" title="Enlace abre en ventana nueva">Participa</a></li>
#                              <li><a href="https://www.gob.mx/publicaciones" rel="noopener" target="_blank" title="Enlace abre en ventana nueva">Publicaciones Oficiales</a></li>
#                              <li><a href="http://www.ordenjuridico.gob.mx" rel="noopener" target="_blank" title="Enlace abre en ventana nueva">Marco Jurídico</a></li>
#                              <li><a href="https://consultapublicamx.inai.org.mx/vut-web/" rel="noopener" target="_blank" title="Enlace abre en ventana nueva">Plataforma Nacional de Transparencia</a></li>
#                          </ul>
#                      </div>
#
#                      <div class="col-sm-3">
#                          <h4 id="pie">¿Qué es gob.mx?</h4>
#                          <p id="pie">Es el portal único de trámites, información y participación ciudadana. <a href="https://www.gob.mx/que-es-gobmx">Leer más</a></p>
#                          <ul>
#                              <li><a href="https://datos.gob.mx">Portal de datos abiertos</a></li>
#                              <li><a href="https://www.gob.mx/accesibilidad">Declaración de accesibilidad</a></li>
#                              <li><a href="https://www.gob.mx/privacidadintegral">Aviso de privacidad integral</a></li>
#                              <li><a href="https://www.gob.mx/privacidadsimplificado">Aviso de privacidad simplificado</a>
#                              </li>
#                              <li><a href="https://www.gob.mx/terminos">Términos y Condiciones</a></li>
#                              <li><a href="https://www.gob.mx/terminos#medidas-seguridad-informacion">Política de
#                                      seguridad</a></li>
#                              <li><a href="https://www.gob.mx/sitemap">Mapa de sitio</a></li>
#                          </ul>
#                      </div>
#
#                       <div class="col-sm-3">
#                          <h4 id="pie"><a href="https://www.gob.mx/tramites/ficha/presentacion-de-quejas-y-denuncias-en-la-sfp/SFP54">Denuncia
#                                  contra servidores públicos</a></h4> <br/><br/>
#                          <h4 id="pie">Síguenos en</h4>
#                          <h4><a aria-label="Facebook de presidencia" class="social-icon facebook" href="https://www.facebook.com/gobmexico" rel="noopener" target="_blank" title="Enlace abre en ventana nueva"><img alt="facebook" src="img/redes_sociales/faceb.png" width="10%"/></a><a aria-label="Twitter de presidencia" class="social-icon twitter" href="https://twitter.com/GobiernoMX" rel="noopener" target="_blank" title="Enlace abre en ventana nueva"><img alt="facebook" src="img/redes_sociales/twitt.png" width="10%"/></a></h4>
#                      </div>
#                  </div>
#              </div>
#          </div>,
#  <div class="container">
#                  <div class="row">
#                      <div class="col-md-3" style="margin-top: 15%;">
#                          <img alt="logo gobierno de méxico" class="logo_footer" data-v-9e928f9a="" href="/" src="https://framework-gb.cdn.gob.mx/landing/img/logoheader.svg" style="margin-top: 5%;"/>
#                      </div>
#
#                      <div class="col-sm-3">
#                          <h4 id="pie">Enlaces</h4>
#                          <ul>
#                              <li><a href="https://participa.gob.mx" rel="noopener" target="_blank" title="Enlace abre en ventana nueva">Participa</a></li>
#                              <li><a href="https://www.gob.mx/publicaciones" rel="noopener" target="_blank" title="Enlace abre en ventana nueva">Publicaciones Oficiales</a></li>
#                              <li><a href="http://www.ordenjuridico.gob.mx" rel="noopener" target="_blank" title="Enlace abre en ventana nueva">Marco Jurídico</a></li>
#                              <li><a href="https://consultapublicamx.inai.org.mx/vut-web/" rel="noopener" target="_blank" title="Enlace abre en ventana nueva">Plataforma Nacional de Transparencia</a></li>
#                          </ul>
#                      </div>
#
#                      <div class="col-sm-3">
#                          <h4 id="pie">¿Qué es gob.mx?</h4>
#                          <p id="pie">Es el portal único de trámites, información y participación ciudadana. <a href="https://www.gob.mx/que-es-gobmx">Leer más</a></p>
#                          <ul>
#                              <li><a href="https://datos.gob.mx">Portal de datos abiertos</a></li>
#                              <li><a href="https://www.gob.mx/accesibilidad">Declaración de accesibilidad</a></li>
#                              <li><a href="https://www.gob.mx/privacidadintegral">Aviso de privacidad integral</a></li>
#                              <li><a href="https://www.gob.mx/privacidadsimplificado">Aviso de privacidad simplificado</a>
#                              </li>
#                              <li><a href="https://www.gob.mx/terminos">Términos y Condiciones</a></li>
#                              <li><a href="https://www.gob.mx/terminos#medidas-seguridad-informacion">Política de
#                                      seguridad</a></li>
#                              <li><a href="https://www.gob.mx/sitemap">Mapa de sitio</a></li>
#                          </ul>
#                      </div>
#
#                       <div class="col-sm-3">
#                          <h4 id="pie"><a href="https://www.gob.mx/tramites/ficha/presentacion-de-quejas-y-denuncias-en-la-sfp/SFP54">Denuncia
#                                  contra servidores públicos</a></h4> <br/><br/>
#                          <h4 id="pie">Síguenos en</h4>
#                          <h4><a aria-label="Facebook de presidencia" class="social-icon facebook" href="https://www.facebook.com/gobmexico" rel="noopener" target="_blank" title="Enlace abre en ventana nueva"><img alt="facebook" src="img/redes_sociales/faceb.png" width="10%"/></a><a aria-label="Twitter de presidencia" class="social-icon twitter" href="https://twitter.com/GobiernoMX" rel="noopener" target="_blank" title="Enlace abre en ventana nueva"><img alt="facebook" src="img/redes_sociales/twitt.png" width="10%"/></a></h4>
#                      </div>
#                  </div>
#              </div>,
#  <div class="row">
#                      <div class="col-md-3" style="margin-top: 15%;">
#                          <img alt="logo gobierno de méxico" class="logo_footer" data-v-9e928f9a="" href="/" src="https://framework-gb.cdn.gob.mx/landing/img/logoheader.svg" style="margin-top: 5%;"/>
#                      </div>
#
#                      <div class="col-sm-3">
#                          <h4 id="pie">Enlaces</h4>
#                          <ul>
#                              <li><a href="https://participa.gob.mx" rel="noopener" target="_blank" title="Enlace abre en ventana nueva">Participa</a></li>
#                              <li><a href="https://www.gob.mx/publicaciones" rel="noopener" target="_blank" title="Enlace abre en ventana nueva">Publicaciones Oficiales</a></li>
#                              <li><a href="http://www.ordenjuridico.gob.mx" rel="noopener" target="_blank" title="Enlace abre en ventana nueva">Marco Jurídico</a></li>
#                              <li><a href="https://consultapublicamx.inai.org.mx/vut-web/" rel="noopener" target="_blank" title="Enlace abre en ventana nueva">Plataforma Nacional de Transparencia</a></li>
#                          </ul>
#                      </div>
#
#                      <div class="col-sm-3">
#                          <h4 id="pie">¿Qué es gob.mx?</h4>
#                          <p id="pie">Es el portal único de trámites, información y participación ciudadana. <a href="https://www.gob.mx/que-es-gobmx">Leer más</a></p>
#                          <ul>
#                              <li><a href="https://datos.gob.mx">Portal de datos abiertos</a></li>
#                              <li><a href="https://www.gob.mx/accesibilidad">Declaración de accesibilidad</a></li>
#                              <li><a href="https://www.gob.mx/privacidadintegral">Aviso de privacidad integral</a></li>
#                              <li><a href="https://www.gob.mx/privacidadsimplificado">Aviso de privacidad simplificado</a>
#                              </li>
#                              <li><a href="https://www.gob.mx/terminos">Términos y Condiciones</a></li>
#                              <li><a href="https://www.gob.mx/terminos#medidas-seguridad-informacion">Política de
#                                      seguridad</a></li>
#                              <li><a href="https://www.gob.mx/sitemap">Mapa de sitio</a></li>
#                          </ul>
#                      </div>
#
#                       <div class="col-sm-3">
#                          <h4 id="pie"><a href="https://www.gob.mx/tramites/ficha/presentacion-de-quejas-y-denuncias-en-la-sfp/SFP54">Denuncia
#                                  contra servidores públicos</a></h4> <br/><br/>
#                          <h4 id="pie">Síguenos en</h4>
#                          <h4><a aria-label="Facebook de presidencia" class="social-icon facebook" href="https://www.facebook.com/gobmexico" rel="noopener" target="_blank" title="Enlace abre en ventana nueva"><img alt="facebook" src="img/redes_sociales/faceb.png" width="10%"/></a><a aria-label="Twitter de presidencia" class="social-icon twitter" href="https://twitter.com/GobiernoMX" rel="noopener" target="_blank" title="Enlace abre en ventana nueva"><img alt="facebook" src="img/redes_sociales/twitt.png" width="10%"/></a></h4>
#                      </div>
#                  </div>,
#  <div class="col-md-3" style="margin-top: 15%;">
#                          <img alt="logo gobierno de méxico" class="logo_footer" data-v-9e928f9a="" href="/" src="https://framework-gb.cdn.gob.mx/landing/img/logoheader.svg" style="margin-top: 5%;"/>
#                      </div>,
#  <div class="col-sm-3">
#                          <h4 id="pie">Enlaces</h4>
#                          <ul>
#                              <li><a href="https://participa.gob.mx" rel="noopener" target="_blank" title="Enlace abre en ventana nueva">Participa</a></li>
#                              <li><a href="https://www.gob.mx/publicaciones" rel="noopener" target="_blank" title="Enlace abre en ventana nueva">Publicaciones Oficiales</a></li>
#                              <li><a href="http://www.ordenjuridico.gob.mx" rel="noopener" target="_blank" title="Enlace abre en ventana nueva">Marco Jurídico</a></li>
#                              <li><a href="https://consultapublicamx.inai.org.mx/vut-web/" rel="noopener" target="_blank" title="Enlace abre en ventana nueva">Plataforma Nacional de Transparencia</a></li>
#                          </ul>
#                      </div>,
#  <div class="col-sm-3">
#                          <h4 id="pie">¿Qué es gob.mx?</h4>
#                          <p id="pie">Es el portal único de trámites, información y participación ciudadana. <a href="https://www.gob.mx/que-es-gobmx">Leer más</a></p>
#                          <ul>
#                              <li><a href="https://datos.gob.mx">Portal de datos abiertos</a></li>
#                              <li><a href="https://www.gob.mx/accesibilidad">Declaración de accesibilidad</a></li>
#                              <li><a href="https://www.gob.mx/privacidadintegral">Aviso de privacidad integral</a></li>
#                              <li><a href="https://www.gob.mx/privacidadsimplificado">Aviso de privacidad simplificado</a>
#                              </li>
#                              <li><a href="https://www.gob.mx/terminos">Términos y Condiciones</a></li>
#                              <li><a href="https://www.gob.mx/terminos#medidas-seguridad-informacion">Política de
#                                      seguridad</a></li>
#                              <li><a href="https://www.gob.mx/sitemap">Mapa de sitio</a></li>
#                          </ul>
#                      </div>,
#  <div class="col-sm-3">
#                          <h4 id="pie"><a href="https://www.gob.mx/tramites/ficha/presentacion-de-quejas-y-denuncias-en-la-sfp/SFP54">Denuncia
#                                  contra servidores públicos</a></h4> <br/><br/>
#                          <h4 id="pie">Síguenos en</h4>
#                          <h4><a aria-label="Facebook de presidencia" class="social-icon facebook" href="https://www.facebook.com/gobmexico" rel="noopener" target="_blank" title="Enlace abre en ventana nueva"><img alt="facebook" src="img/redes_sociales/faceb.png" width="10%"/></a><a aria-label="Twitter de presidencia" class="social-icon twitter" href="https://twitter.com/GobiernoMX" rel="noopener" target="_blank" title="Enlace abre en ventana nueva"><img alt="facebook" src="img/redes_sociales/twitt.png" width="10%"/></a></h4>
#                      </div>,
#  <div id="sep">
#          <br/>
#      </div>]

# %%
sopa.find("body")
# Out:
# <body>
#     <!-- SCRIPT SUBMENUS -->
# <script>
# /*     $('.dropdown-menu a.dropdown-toggle').on('click', function(e) {
#         if (!$(this).next().hasClass('show')) {
#             $(this).parents('.dropdown-menu').first().find('.show').removeClass('show');
#         }
#         var $subMenu = $(this).next('.dropdown-menu');
#         $subMenu.toggleClass('show');
#
#
#         $(this).parents('li.nav-item.dropdown.show').on('hidden.bs.dropdown', function(e) {
#             $('.dropdown-submenu .show').removeClass('show');
#         });
#
#
#         return false;
#     }); */
# </script>
#
# <!--arreglos navbar verde-->
# <style>
#     a {
#         color: white !important;
#         font-size: large;
#     }
#
#     @media (min-width: 960px) {
#         .dropdown:hover>.dropdown-menu {
#             display: block;
#         }
#
#
#     }
#
#     .dropdown-submenu {
#         position: relative;
#     }
#
#     .dropdown-submenu a::after {
#         transform: rotate(-90deg);
#         position: absolute;
#         right: 6px;
#         top: .8em;
#     }
#
#     .dropdown-submenu {
#         position: relative;
#     }
#
#     .dropdown-submenu .dropdown-menu {
#         top: 0;
#         left: 100%;
#         margin-top: -1px;
#     }
#
#     .dropdown-submenu .dropdown-menu {
#         top: 0;
#         left: 100%;
#         margin-left: .1rem;
#         margin-right: .1rem;
#
#     }
#
#     #navbarDropdown {
#         cursor: pointer;
#     }
#
#     /*
#   nav>a:hover {
#     display:block;
#     cursor: pointer;
#     color: tomato;
#     background-color:white;
#     transition: background-color .5s;
#     opacity: 0.05;*/
#
#     div.dropdown-menu a:hover {
#         background-color: #363636;
#         align-content: center;
#     }
#
#     .navbar-nav li:hover>ul.dropdown-menu {
#         display: block;
#     }
#
#     .dropdown-submenu {
#         position: relative;
#     }
#
#     .dropdown-submenu>.dropdown-menu {
#         top: 0;
#         left: 100%;
#         margin-top: -6px;
#     }
#
#     /* rotate caret on hover */
#     .dropdown-menu>li>a:hover:after {
#         text-decoration: underline;
#         transform: rotate(-90deg);
#     }
#
#     div.dropdown-menu a:hover {
#       background-color: #363636;
#       align-content: center;
#     }
#
#     /*Fix imagen inicio del header*/
#     @media (max-width: 960px) {
#         .img-inicio-fix{
#             width: 30px !important;
#         }
#     }
#     .img-inicio-fix{
#         width: 50px;
#     }
# </style>
#
# <!--NavBar Menu Verde-->
#
# <nav class="navbar navbar-expand-md navbar-dark bg-dark" style="width: 100%; background-color: #0b231e  !important;">
#     <a class="navbar-brand" href="#">
#         <img alt="Página de inicio, Gobierno de México" height="33" src="https://framework-gb.cdn.gob.mx/landing/img/logoheader.svg" style=" margin-left: 80%;"/>
#     </a>
#
#     <button class="navbar-toggler" data-target="#navbarNav" data-toggle="collapse" type="button">
#         <span class="navbar-toggler-icon"></span>
#     </button>
#     <div class="collapse navbar-collapse" id="navbarNav">
#         <ul class="navbar-nav mr-auto">
#             <li class="nav-item active">
#                 <a class="nav-link" href="#"> <span class="sr-only">(current)</span></a>
#             </li>
#
#         </ul>
#         <ul class="navbar-nav" style="margin-right: 10%;">
#             <li class="nav-item">
#                 <a class="nav-link" href="https://www.gob.mx/gobierno" style="color: white;"> Gobierno</a>
#             </li>
#
#             <li class="nav-item">
#                 <a class="nav-link" href="https://www.gob.mx/participa" style="color: white;">Participa</a>
#             </li>
#
#             <li class="nav-item">
#                 <a class="nav-link" href="https://datos.gob.mx " style="color: white;">Datos</a>
#             </li>
#
#             <li class="nav-item">
#                 <a class="nav-item nav-link active" href="https://www.gob.mx/busqueda" style="color: white;">
#                     <span class="sr-only">Búsqueda</span>
#                     <svg aria-hidden="true" class="svg-inline--fa fa-search fa-w-16" data-fa-i2svg="" data-icon="search" data-prefix="fas" focusable="false" height="18" role="img" viewBox="0 0 512 512" width="18" xmlns="http://www.w3.org/2000/svg">
#                         <path d="M505 442.7L405.3 343c-4.5-4.5-10.6-7-17-7H372c27.6-35.3 44-79.7 44-128C416 93.1 322.9 0 208 0S0 93.1 0 208s93.1 208 208 208c48.3 0 92.7-16.4 128-44v16.3c0 6.4 2.5 12.5 7 17l99.7 99.7c9.4 9.4 24.6 9.4 33.9 0l28.3-28.3c9.4-9.4 9.4-24.6.1-34zM208 336c-70.7 0-128-57.2-128-128 0-70.7 57.2-128 128-128 70.7 0 128 57.2 128 128 0 70.7-57.2 128-128 128z" fill="currentColor"></path>
#                     </svg><!-- <i class="fas fa-search"></i> -->
#                 </a>
#             </li>
#
#         </ul>
#     </div>
# </nav>
# <!--Fin NavBar Menu Verde-->
#
#
#
# <!-- Menu logos instituciones -->
# <div style="background-color: fff; width: 90%;
#            margin-left: 5%; margin-right:5%; margin-top:2%; margin-bottom:2%;">
#
#     <a href="https://www.gob.mx/">
#         <img alt="Gobierno de México" src="img/logotipos/pleca-gob1.png" style="width:30%;height:auto"/>
#     </a>
#     <a href="https://www.gob.mx/sep">
#         <img alt="Educación" src="img/logotipos/pleca-gob2.png" style="width:30%;height:auto; min-width:auto;"/>
#     </a>
#     <a href="https://www.tecnm.mx/">
#         <img alt="TecNM" src="img/logotipos/pleca_tecnm.jpg" style="width:18%;height:auto; "/>
#     </a>
#     <a href="https:/www.itlalaguna.edu.mx/">
#         <img alt="ITL" src="img/logotipos/itl2.jpeg" style="width:7%; height:auto;"/>
#     </a>
# </div>
# <!--Fin Menu logos instituciones-->
#
#
# <!-- Menu Gris -->
# <nav class="navbar navbar-expand-lg navbar-dark bg-dark sticky-top" style="background:#363637 !important; z-index: 2;">
#
#     <!--  Collapse-->
#     <button aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-target="#navbarSupportedContent" data-toggle="collapse" type="button">
#         <span class="navbar-toggler-icon"></span>
#     </button>
#
#
#     <!-- Normal Menu-->
#     <div class="collapse navbar-collapse" id="navbarSupportedContent">
#         <ul class="navbar-nav mr-auto" style="margin: auto;">
#
#             <li class="nav-item img-inicio-fix" id="dmenu">
#                 <a aria-expanded="false" aria-haspopup="true" class="nav-link" href="index.php" role="button">
#                 <img class="img-fluid" src="img/icono-home.png"/>
#                 </a>
#             </li>
#             <li class="nav-item" id="dmenu">
#                 <a aria-expanded="false" aria-haspopup="true" class="nav-link" href="directorio.php" role="button">
#                     Directorio
#                 </a>
#             </li>
#             <!--   1-->
#             <li class="nav-item dropdown" id="dmenu">
#
#                 <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" id="navbarDropdown" role="button">
#                     ¿Quiénes Somos?
#                 </a>
#                 <div class="dropdown-menu" style="background:#454547;">
#
#                     <a class="text-black dropdown-item" href="historia.php">HISTORIA</a>
#                     <a class="text-black dropdown-item" href="mision.php">MISIÓN Y VISIÓN</a>
#                     <a class="text-black dropdown-item" href="infra.php">UBICACIÓN E INFRAESCTRUCTURA</a>
#                     <a class="text-black dropdown-item" href="cuidadoMa.php">CUIDADO DEL MEDIO AMBIENTE</a>
#                     <a class="text-black dropdown-item" href="logos.php">MASCOTA Y LOGOS</a>
#                     <!--<a class="text-black dropdown-item" href="contacto.php">CONTACTO</a>-->
#
#                     <!--<a class="text-black dropdown-item" href="https://docs.google.com/forms/d/e/1FAIpQLSeE8OPXE5YSXIcA0zLvfCnaHtY0NQrbtSEr9VVMn8ZavzT_iA/viewform#response=ACYDBNiyCA6p87VDbN4lu-wVyLdVOv5qkOKwqxQXMwKijoJdEsQXK53UB9bS5t4">BUZÓN DE QUEJAS Y SUGERENCIAS</a>-->
#                     <a class="text-black dropdown-item" href="https://docs.google.com/forms/d/e/1FAIpQLSddMvuMgSe8qJ63G7op3Pcr5-VEuV2_UPElM977PS9lm8faug/viewform">BUZÓN DE QUEJAS Y SUGERENCIAS</a>
#
#                     <a class="text-black dropdown-item" href="https://docs.google.com/forms/d/e/1FAIpQLSckSqRPLi4GVYVthg5wP034P8tiEgBhyLnNcd6JCc7ZkE1KGg/viewform?entry.1159593137=nombre&amp;entry.1809109965&amp;entry.1214002645&amp;entry.1344596603&amp;entry.1727722980&amp;entry.1573787809=nombre+completo&amp;entry.471819699=puesto&amp;entry.285911030=ITL&amp;entry.134294733=2018-03-03&amp;entry.1785309787=20:00&amp;entry.1084813065=ITL&amp;entry.1814560733=hechos&amp;entry.1641027819=Nombre+testigo&amp;entry.1484745992=Domicilio+testigo&amp;entry.769034671=S%C3%AD&amp;entry.1684521492=si1&amp;entry.1680632340=si2">
#                         FORMATO DE DENUNCIAS DEL SG DE
#                         <br/>IGUALDAD DE GÉNERO Y NO DISCRIMINACIÓN</a>
#
#                     <a class="text-black dropdown-item" href="http://www.itlalaguna.edu.mx/etica/codigoetica.pdf">CÓDIGO DE ÉTICA Y CONDUCTA</a>
#                     <a class="text-black dropdown-item" href="https://www.tecnm.mx/?vista=Normateca">NORMATECA  DEL TECNM</a>
#
#
#                 </div>
#             </li>
#             <!-- PRUEBA -->
#    <!--2-->
#                <!--2-->
#
#
#
#                <li class="nav-item dropdown" id="dmenu">
#                 <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" id="navbarDropdown" role="button">
#                     Oferta Educativa
#                 </a>
#
#                 <div class="dropdown-menu" style="background:#454547;">
#                     <ul class="navbar-nav nav-dropdown dropdown-item" data-app-modern-menu="true" style="background:#454547;">
#                         <li class="nav-item dropdown dropdown-submenu" style="background:#454547;">
#                             <a aria-expanded="false" class="dropdown-toggle dropdown-item dropdown-submenu" data-toggle="dropdown-submenu" href="#" style="background:#454547;">NIVEL LICENCIATURA</a>
#                             <div class="dropdown-menu" style="background:#454547;">
#                                 <a class="text-black dropdown-item" href="sistemas.php">ING. SISTEMAS
#                                     COMPUTACIONALES</a>
#                                 <a class="text-black dropdown-item" href="electrica.php">ING. ELÉCTRICA</a>
#                                 <a class="text-black dropdown-item" href="electronica.php">ING. ELECTRÓNICA</a>
#                                 <a class="text-black dropdown-item" href="er.php">ING. EN ENERGÍAS
#                                     RENOVABLES</a>
#                                 <a class="text-black dropdown-item" href="industrial.php">ING.
#                                     INDUSTRIAL</a>
#                                 <a class="text-black dropdown-item" href="mecanica.php">ING. MECÁNICA</a>
#                                 <a class="text-black dropdown-item" href="mecatronica.php">ING.
#                                     MECATRÓNICA</a>
#                                 <a class="text-black dropdown-item" href="quimica.php">ING. QUÍMICA</a>
#                                 <a class="text-black dropdown-item" href="admin.php">LIC.
#                                     ADMINISTRACION</a>
#                                 <a class="text-black dropdown-item" href="gestionEmp.php">ING. GESTIÓN
#                                     EMPRESARIAL</a>
#
#                             </div>
#                         </li>
#                     </ul>
#                        <!-- <a class="link text-black dropdown-item" style="background:#454547;" href="http://www.itlalaguna.edu.mx/posgrado/indexposgrado.html" data-toggle="dropdown-submenu" aria-expanded="false">NIVEL POSGRADO</a>-->
#
#
#
#
#                     <ul class="navbar-nav nav-dropdown dropdown-item" data-app-modern-menu="true" style="background:#454547;">
#                         <li class="nav-item dropdown dropdown-submenu" style="background:#454547;">
#                             <a aria-expanded="false" class="dropdown-toggle dropdown-item dropdown-submenu" data-toggle="dropdown-submenu" href="#" style="background:#454547;">NIVEL POSGRADO</a>
#                             <div class="dropdown-menu" style="background:#454547;">
#
#                                 <a class="text-black dropdown-item" href="MAESTRIAE.php">MAESTRÍA EN CIENCIAS EN INGENIERÍA ELÉCTRICA (PNPC)</a>
#
#                                 <a class="text-black dropdown-item" href="MAESTRIAI.php">MAESTRÍA EN INGENIERÍA INDUSTRIAL</a>
#                                 <a class="text-black dropdown-item" href="MAESTRIAS.php">MAESTRÍA EN SISTEMAS COMPUTACIONALES</a>
#                                 <a class="text-black dropdown-item" href="DOCTORADOE.php">DOCTORADO EN CIENCIAS EN INGENIERÍA ELÉCTRICA (PNPC)</a>
#
#                             </div>
#                         </li>
#                     </ul>
#
#
#                      <!-- <ul class="navbar-nav nav-dropdown dropdown-item " style="background:#454547;" data-app-modern-menu="true">
#                         <li class="nav-item dropdown dropdown-submenu" style="background:#454547;">
#                             <a class="dropdown-toggle dropdown-item dropdown-submenu" style="background:#454547;" href="#" data-toggle="dropdown-submenu" aria-expanded="false">NIVEL LICENCIATURA A DISTANCIA</a>
#                             <div class=" dropdown-menu" style="background:#454547;">
#
#                                 <a class="text-black dropdown-item" href="industrial.php">ING.
#                                     INDUSTRIAL</a>
#
#                                 <a class="text-black dropdown-item" href="gestionEmp.php">ING. GESTIÓN
#                                     EMPRESARIAL</a>
#
#                             </div>
#                         </li>
#                     </ul>-->
#                     </div>
#
#             </li>
#             <!-- NEW 4 -->
#
#
#
#
#
#
#
#  <!-- 3-->
#
#  <!-- ALUMNADO2   ERA 4
#  <li class="nav-item dropdown" id='dmenu'>
#                 <a class="nav-link dropdown-toggle" id="navbarDropdown" role="button" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
#                     Aspirantes
#                 </a>
#                 <div class="dropdown-menu" style="background:#454547;">
#                     <a class="text-black dropdown-item" href="nivelacion.php">SEMESTRE DE NIVELACIÓN</a>
#                     <a class="text-black dropdown-item" href="http://apps2.itlalaguna.edu.mx:8081/">INGRESO LICENCIATURA</a>
#                     <a class="text-black dropdown-item" href="posgrado/indexposgrado.html">INGRESO POSGRADO</a>
#
#                 </div>
#             </li>
#
#             <li class="nav-item dropdown" id='dmenu'>
#                 <a class="nav-link dropdown-toggle" id="navbarDropdown" role="button" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
#                     Alumnado2
#                 </a>
#                 <div class="dropdown-menu" style="background:#454547; ">
#                     <ul class="navbar-nav nav-dropdown dropdown-item" style="background:#454547;" data-app-modern-menu="true">
#                         <li class="nav-item dropdown dropdown-submenu" style="background:#454547;">
#                             <a class="dropdown-toggle dropdown-item dropdown-submenu" id="smn3" style="background:#454547;" href="#" data-toggle="dropdown-submenu" aria-expanded="false">DIV. DE ESTUDIOS PROFESIONALES</a>
#                             <div class="dropdown-menu" style="background:#454547;">
#                                 <a class="dropdown-item" href="#">COORDINACIÓN DE TITULACIÓN</a>
#                                 <a class="dropdown-item" href="#">HORARIO MATERIAS</a>
#                                 <a class="dropdown-item" href="#">REINGRESO LICENCIATURA</a>
#                                 <a class="dropdown-item" href="#">VERANOS LICENCIATURA</a>
#                                 <a class="dropdown-item" href="#">REINGRESO POSGRADO</a>
#                                 <a class="dropdown-item" href="#">REINGRESO A DISTANCIA</a>
#                             </div>
#                         </li>
#                     </ul>
#                     <ul class="navbar-nav nav-dropdown dropdown-item" style="background:#454547;" data-app-modern-menu="true">
#                         <li class="nav-item dropdown" style="background:#454547;">
#                             <a class=" dropdown-toggle dropdown-item dropdown-submenu" href="http://escolares.itlalaguna.edu.mx" id="smn4" style="background:#454547;" href="#" data-toggle="dropdown-submenu" aria-expanded="false">SERVICIOS ESCOLARES</a>
#
#                         </li>
#                     </ul>
#                 </div>
#             </li>
#
# -->
#
#
#    <!--2-->
#    <li class="nav-item dropdown" id="dmenu">
#                 <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" id="navbarDropdown" role="button">
#                     Alumnado
#                 </a>
#                 <div class="dropdown-menu" style="background:#454547;">
#                 <ul class="navbar-nav nav-dropdown dropdown-item" data-app-modern-menu="true" style="background:#454547;">
#                         <li class="nav-item dropdown dropdown-submenu" style="background:#454547;">
#                             <a aria-expanded="false" class="link text-black dropdown-toggle dropdown-item" data-toggle="dropdown-submenu" href="#" style="background:#454547;">DESARROLLO ACADÉMICO</a>
#                              <div class="dropdown-menu" style="background:#454547;">
#                             <a class="text-black dropdown-item" href="http://sed.itlalaguna.edu.mx/sed/">EVALUACIÓN AL PROFESORADO</a>
#
#                             <a class="dropdown-item" href="AVISOS/CALENDARIO.PDF">CALENDARIO ESCOLAR</a>
#                             </div>
#                         </li>
#                     </ul>
#                     <ul class="navbar-nav nav-dropdown dropdown-item" data-app-modern-menu="true" style="background:#454547;">
#                         <li class="nav-item dropdown dropdown-submenu" style="background:#454547;">
#                             <a aria-expanded="false" class="link text-black dropdown-toggle dropdown-item" data-toggle="dropdown-submenu" href="#" style="background:#454547;">DIVISIÓN DE ESTUDIOS PROFESIONALES</a>
#                              <div class="dropdown-menu" style="background:#454547;">
#
#                              <a class="dropdown-item" href="http://apps2.itlalaguna.edu.mx/inscripcion/login.aspx">CARGA DE MATERIAS</a>
#                              <!--<a class="dropdown-item" href="soporte@correo.itlalaguna.edu.mx">Si tienes algún problema escribe a <br>
#                              soporte@correo.itlalaguna.edu.mx <br> incluye número de control y <br>comprobante de pago
#                             </a>-->
#                              <a class="dropdown-item" href="http://apps.itlalaguna.edu.mx/servicios/academicos/horario_materias_2020/index.htm">HORARIO MATERIAS</a>
#                               <a class="text-black dropdown-item" href="titulacion.php">COORDINACIÓN DE TITULACIÓN</a>
#
#                             <a class="dropdown-item" href="http://apps2.itlalaguna.edu.mx:8082/">FICHAS DE PAGO REINGRESO</a>
#                             <a class="dropdown-item" href="COMITE/COMITE.PDF">COMITÉ ACADÉMICO</a>
#                             <a class="dropdown-item" href="ESPECIALES/ESPECIALES.PDF">EXÁMENES ESPECIALES</a>
#                             </div>
#                         </li>
#                     </ul>
#                     <a aria-expanded="false" class="link text-black dropdown-item" data-toggle="dropdown-submenu" href="REGLAMENTO/Manual_de_Lineamientos_TecNM.pdf" style="background:#454547;">MANUAL DE LINEAMIENTOS</a>
#                     <a aria-expanded="false" class="link text-black dropdown-item" data-toggle="dropdown-submenu" href="REGLAMENTO/REGLAMENTO2019.PDF" style="background:#454547;">REGLAMENTO ESTUDIANTIL</a>
#
#
#
#                     <a aria-expanded="false" class="link text-black dropdown-item" data-toggle="dropdown-submenu" href="http://escolares.itlalaguna.edu.mx" style="background:#454547;">SERVICIOS ESCOLARES</a>
#                     <a aria-expanded="false" class="link text-black dropdown-item" data-toggle="dropdown-submenu" href="extraescolares/extraescolares20.pdf" style="background:#454547;">ACTIVIDADES EXTRAESCOLARES</a>
#                 </div>
#             </li>
#
#
#
#
#             <!-- 3-->
#
#
#             <!-- 3-->
#             <li class="nav-item dropdown" id="dmenu">
#                 <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" id="navbarDropdown" role="button">
#                    Nuevo Ingreso
#                 </a>
#                 <div class="dropdown-menu" style="background:#454547;">
#
#                    <!-- <a class="text-black dropdown-item" href="http://apps2.itlalaguna.edu.mx:8081/">LICENCIATURA</a>-->
#                    <a class="text-black dropdown-item" href="ADMago.PHP">LICENCIATURA AGOSTO - DICIEMBRE</a>
#                    <a class="text-black dropdown-item" href="ADMcpago.PHP">POSGRADO AGOSTO - DICIEMBRE</a>
#                    <a class="text-black dropdown-item" href="nivelacion.php">NIVELACIÓN AGOSTO - DICIEMBRE</a>
#                    <a class="text-black dropdown-item" href="ADM.PHP">LICENCIATURA ENERO - JUNIO</a>
#                     <a class="text-black dropdown-item" href="ADMcp.PHP">POSGRADO ENERO - JUNIO</a>
#
#
#
#                     <!--<a class="text-black dropdown-item" href="ADMdis.PHP">LICENCIATURA MODALIDAD A DISTANCIA</a>-->
#
#                   <!--  <a class="text-black dropdown-item" href="distancia.php">INGRESO A DISTANCIA</a>-->
#                 </div>
#             </li>
#
#
#
#              <!-- 5-->
#              <li class="nav-item dropdown" id="dmenu">
#                 <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" id="navbarDropdown" role="button">
#                     Vinculación
#                 </a>
#                 <div class="dropdown-menu" style="background:#454547;">
#                     <a class="dropdown-item" href="http://www.itlalaguna.edu.mx/vinculacion/servsocial21.pdf">SERVICIO SOCIAL</a>
#                     <a class="dropdown-item" href="http://www.itlalaguna.edu.mx/vinculacion/bolsa_trabajo_2.pdf">BOLSA DE TRABAJO</a>
#                     <a class="dropdown-item" href="http://www.itlalaguna.edu.mx/vinculacion/servicios_externos.pdf">SERVICIO EXTERNOS</a>
#                     <a class="dropdown-item" href="http://www.itlalaguna.edu.mx/vinculacion/idiomas.pdf">IDIOMAS</a>
#                     <a class="dropdown-item" href="vinculacion/residencia/residencia-platica.pdf">SOLICITUD DE CARTA DE PRESENTACIÓN<br/> DE RESIDENCIA PROFESIONAL</a>
#
#                 </div>
#             </li>
#              <!-- 6-->
#              <li class="nav-item dropdown" id="dmenu">
#                 <a aria-expanded="false" aria-haspopup="true" class="nav-link dropdown-toggle" data-toggle="dropdown" id="navbarDropdown" role="button">
#                     Personal
#                 </a>
#                 <div class="dropdown-menu" style="background:#454547;">
#                     <a class="dropdown-item" href="http://apps.itlalaguna.edu.mx/servicios/personal/catedraticos/index18.html">DOCENTES CARGA DE TRABAJO</a>
#                     <!--<a class=" dropdown-item" href="http://apps2.itlalaguna.edu.mx/SGESCL/login.aspx">DOCENTES CALIFICACIONES</a>-->
#                     <a class="dropdown-item" href="becasint/becasint.html">CONVOCATORIAS</a>
#                     <a class="dropdown-item" href="REGLAMENTOS.PHP">REGLAMENTOS</a>
#                     <a class="dropdown-item" href="CONTRALORIA.PHP">PRODEP</a>
#                 </div>
#             </li>
#             <!-- 7-->
#             <!--  <li class="nav-item dropdown" id='dmenu'>
#                 <a class="nav-link dropdown-toggle" id="navbarDropdown" data-toggle="dropdown" role="button" data-toggle="dropdown" aria-haspopup="true" aria-expanded="false">
#                     Mejora Continua
#                 </a>
#                 <div class="dropdown-menu" style="background:#454547;">
#                     <a class=" dropdown-item" href="#">CONTROL DE DOCUMENTOS</a>
#                     <a class=" dropdown-item" href="#">SISTEMA DE GESTIÓN INTEGRAL</a>
#                     <a class=" dropdown-item" href="#">SISTEMA DE G.DE IGUALDAD DE GÉNERO</a>
#                     <a class=" dropdown-item" href="#">BUZÓN DE QUEJAS Y SUGERENCIAS</a>
#                     <a class=" dropdown-item" href="#">INNOVACIÓN Y DESARROLLO (PIID ITLaguna)</a>
#
#                 </div>
#             </li>-->
#         </ul>
#     </div>
# </nav>
# <!-- Fin Menu Gris -->
#
# <!-- boostrap
# <script src="https://code.jquery.com/jquery-3.5.1.min.js" integrity="sha256-9/aliU8dGd2tb6OSsuzixeV4y/faTqgFtohetphbbj0=" crossorigin="anonymous"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.14.3/umd/popper.min.js" integrity="sha384-ZMP7rVo3mIykV+2+9J3UJ46jBk0WLaUAdn689aCwoqbBJiSnjAK/l8WvCWPIPm49" crossorigin="anonymous">
# </script>
# <script src="https://stackpath.bootstrapcdn.com/bootstrap/4.1.1/js/bootstrap.min.js" integrity="sha384-smHYKdLADwkXOn1EmN1qk/HfnUcbVRZyYmZ4qpPea6sjB/pTJ0euyQp0Mk8ck+5T" crossorigin="anonymous">
# </script>-->
#
#
#
#
#
#
#      <br/>
#
# <!-- Carousel Banners -->
#
# <div class="slideshow-container">
#
# <!--<div class="mySlides1">
#
#
#             <img src="slider/AVISovacuna.png" style="width:100%">
#     </div>
#     -->
#
#
#
#
#
#
# <div class="mySlides1">
#         <a href="avisos/registro-office.pdf">
#
#             <img src="slider/office.png" style="width:100%"/></a>
#     </div>
#     <div class="mySlides1">
#         <a href="https://www.tecnm.mx/menu/convocatorias_tecnm/01_InvCientifica_Academicos_Convocatoria_2021-2.pdf">
#
#             <img src="slider/convoinvest2.png" style="width:100%"/></a>
#     </div>
#
# <div class="mySlides1">
#         <a href="avisos/solicitud protocolos  titulación_mayo 2021.pdf">
#
#             <img src="slider/solicitud protocolos  titulación_mayo 2021.png" style="width:100%"/></a>
#     </div>
#
# <div class="mySlides1">
#         <a href="avisos/registro proyectos titulación_mayo 2021.pdf">
#
#             <img src="slider/registro proyectos titulación_mayo 2021.png" style="width:100%"/></a>
#     </div>
#
#
# <div class="mySlides1">
#         <a href="https://escolares.itlalaguna.edu.mx/web/index.php/entrega-de-certificados/">
#
#             <img src="slider/certificados2.png" style="width:100%"/></a>
#     </div>
#
#
# <div class="mySlides1">
#         <a href="ADMago.PHP">
#
#             <img src="slider/adm21ago2.png" style="width:100%"/></a>
#     </div>
#
#
#
#      <div class="mySlides1">
#
#        <img src="slider/puertas.jpg" style="width:100%"/>
#     </div>
#
#
#       <!-- <div class="mySlides1">
#         <a href="https://www.gob.mx/cms/uploads/attachment/file/617238/MANUTENCION_FEDERAL.pdf">
#
#             <img src="slider/becas.jpg" style="width:100%"></a>
#     </div>-->
#
# <div class="mySlides1">
#         <a href="http://mooc.tecnm.mx/">
#
#             <img src="slider/mooc.jpg" style="width:100%"/></a>
#     </div>
#
# <!--<div class="mySlides1">
#         <a href="https://docs.google.com/forms/d/e/1FAIpQLSeB0dMOHIapAMmylfW-sgKBPudl7-2krNWwB2Naud24UI0yaA/viewform?pli=1">
#
#             <img src="slider/ti2.jpg" style="width:100%"></a>
#     </div>
#
# <div class="mySlides1">
#         <a href="https://forms.gle/JqEd4btNsP73eRvJ8">
#
#             <img src="slider/protocolos.png" style="width:100%"></a>
#     </div>-->
# <div class="mySlides1">
#         <a href="avisos/convocatoria anfei.pdf">
#             <img src="slider/cienciasbasicas.png" style="width:100%"/></a>
#     </div>
#     <div class="mySlides1">
#         <a href="avisos/tripticoetica.pdf">
#             <img src="slider/tripticoetica.jpg" style="width:100%"/></a>
#     </div>
#
#
#
#
#
#
# <!--<div class="mySlides1">
#         <a href="AVISOS/CALENDARIOEJ21.PDF">
#             <img src="slider/CALENDARIOEJ212.png" style="width:100%"></a>
#     </div>-->
#
#
#     <div class="mySlides1">
#         <a href="https://docs.google.com/forms/d/e/1FAIpQLSeco-OxDhHp_81y0fcDNBKu0dPQakLceC1tHWM49gjPnJdurQ/viewform">
#             <img src="slider/bioetica.jpg" style="width:100%"/></a>
#     </div>
# <div class="mySlides1">
#         <a href="http://forms.gle/skuGWT2vabzxyDVp9">
#             <img src="slider/evalingles2.png" style="width:100%"/></a>
#     </div>
#
#
#
#     <div class="mySlides1">
#         <a href="avisos/ci2021.pdf">
#             <img src="slider/ci20212.png" style="width:100%"/></a>
#     </div>
#
#
#
#
#
#
#
#
# <div class="mySlides1">
#         <a href="AVISOS/anfei20.PDF">
#             <img src="slider/anfei202.png" style="width:100%"/></a>
#     </div>
#
#
#
#
#
# <div class="mySlides1">
#
#             <img src="slider/ingles203.jpg" style="width:100%"/>
#     </div>
#     <div class="mySlides1">
#         <a href="calidad/mejoracontinua.pdf">
#             <img src="slider/cero tolerancia2.jpg" style="width:100%"/></a>
#     </div>
#
#
#
#
#
#
# <div class="mySlides1">
#         <a href="../avisos/elibro.pdf">
#             <img src="slider/elibro2.png" style="width:100%"/></a>
#     </div>
#
#
#
#
#
#     <div class="mySlides1">
#         <a href="directorio.php">
#             <img src="slider/directorio212.png" style="width:100%"/></a>
#     </div>
#
#
#
#
#
#     <div class="mySlides1">
#
#         <img src="slider/redesof.png" style="width:100%"/>
#     </div>
#
#
#
#
#     <div class="mySlides1">
#         <a href="https://www.tecnm.mx/?vista=TecNM_Virtual"><img src="slider/tecnmvirtual2.jpg" style="width:100%"/></a>
#     </div>
#
#
#     <div class="mySlides1">
#         <a href="avisos/gradua202.pdf">
#
#             <img src="slider/gradua204.jpg" style="width:100%"/></a>
#     </div>
#
#     <div class="mySlides1">
#         <a href="https://bit.ly/2VGuGuK">
#             <img src="slider/protocolo202.jpg" style="width:100%"/></a>
#     </div>
#
#     <div class="mySlides1">
#         <a href="https://bit.ly/2Toczbt">
#             <img src="slider/cerotolerancia202.jpg" style="width:100%"/></a>
#     </div>
#
#
#
#
#
#
#     </div>
#
#
#
#
#
#     <a class="prev" onclick="plusSlides(-1, 0)">❮</a>
#     <a class="next" onclick="plusSlides(1, 0)">❯</a>
#
#         <div id="bolitas">
#             <span class="bolita" onclick="foto(1)"></span>
#             <span class="bolita" onclick="foto(2)"></span>
#             <span class="bolita" onclick="foto(3)"></span>
#             <span class="bolita" onclick="foto(4)"></span>
#             <span class="bolita" onclick="foto(5)"></span>
#             <span class="bolita" onclick="foto(6)"></span>
#             <span class="bolita" onclick="foto(7)"></span>
#             <span class="bolita" onclick="foto(8)"></span>
#             <span class="bolita" onclick="foto(9)"></span>
#             <span class="bolita" onclick="foto(10)"></span>
#             <span class="bolita" onclick="foto(11)"></span>
#             <span class="bolita" onclick="foto(12)"></span>
#             <span class="bolita" onclick="foto(13)"></span>
#             <span class="bolita" onclick="foto(14)"></span>
#             <span class="bolita" onclick="foto(15)"></span>
#             <span class="bolita" onclick="foto(16)"></span>
#             <span class="bolita" onclick="foto(17)"></span>
#             <span class="bolita" onclick="foto(18)"></span>
#             <!-- <span class="bolita" onclick="foto(19)">
#             </span>
#            <span class="bolita" onclick="foto(20)"></span>-->
#
#
#
#
#
#
#
#
#         </div>
#
#
#
#
#
#
#
#
#     <br/>
#     <br/>
#
#
#
#
#
# 	<!-- Dinamic Carousel  -->
#
#
# 		<div class="top-content" style="background:#19396a;">
# 			<div class="text-center text-white">
# 			<a href="new.php/?id=1326"><h1 class="align-center display-4">NOTICIAS</h1>	</a>
# 			</div>
# 			<div class="container-fluid">
# 				<div class="carousel slide" data-ride="carousel" id="carousel-example">
# 					<div class="carousel-inner row w-100 mx-auto" role="listbox">
# 						<div class="text-white carousel-item col-12 col-sm-6 col-md-4 col-lg-3 active">
# 							<h2> Noticias Recientes ITL </h2>
#   						</div>
# 			<div class="carousel-item col-12 col-sm-6 col-md-4 col-lg-3">
#
#
# 			<a href="new.php/?id=1345" id="carousel">
# 			<img alt="img" class="img-fluid mx-auto d-block" src="../../tec_noticias/imagenes_noticias/8778.jpg"/>
# 			</a>
#
# 				<a href="new.php/?id=1345" id="carousel">
# 				<h5>NUEVA JEFA DEL DEPARTAMENTO DE ING. QUÍMICA BIOQUÍMICA</h5>
# 				</a>
# 				<h6></h6>
#
#
# 				<a href="new.php/?id=1345" id="carousel" style="color: #dark blue !important;">
# 						LEER MAS
# 				</a>
#
#
# 			</div>
#
# 			<div class="carousel-item col-12 col-sm-6 col-md-4 col-lg-3">
#
#
# 			<a href="new.php/?id=1343" id="carousel">
# 			<img alt="img" class="img-fluid mx-auto d-block" src="../../tec_noticias/imagenes_noticias/8760.jpg"/>
# 			</a>
#
# 				<a href="new.php/?id=1343" id="carousel">
# 				<h5>PRIMERA SESIÓN DEL CONSEJO DE VINCULACIÓN 2021 DEL TECNM CAMPUS LA LAGUNA</h5>
# 				</a>
# 				<h6></h6>
#
#
# 				<a href="new.php/?id=1343" id="carousel" style="color: #dark blue !important;">
# 						LEER MAS
# 				</a>
#
#
# 			</div>
#
# 			<div class="carousel-item col-12 col-sm-6 col-md-4 col-lg-3">
#
#
# 			<a href="new.php/?id=1344" id="carousel">
# 			<img alt="img" class="img-fluid mx-auto d-block" src="../../tec_noticias/imagenes_noticias/8768.jpg"/>
# 			</a>
#
# 				<a href="new.php/?id=1344" id="carousel">
# 				<h5>RECONOCEN TRAYECTORIA LABORAL</h5>
# 				</a>
# 				<h6></h6>
#
#
# 				<a href="new.php/?id=1344" id="carousel" style="color: #dark blue !important;">
# 						LEER MAS
# 				</a>
#
#
# 			</div>
#
# 			<div class="carousel-item col-12 col-sm-6 col-md-4 col-lg-3">
#
#
# 			<a href="new.php/?id=1342" id="carousel">
# 			<img alt="img" class="img-fluid mx-auto d-block" src="../../tec_noticias/imagenes_noticias/8753.jpg"/>
# 			</a>
#
# 				<a href="new.php/?id=1342" id="carousel">
# 				<h5>   TECNM CAMPUS LA LAGUNA, EN LA LUCHA CONTRA EL CÁNCER DE MAMA.   </h5>
# 				</a>
# 				<h6></h6>
#
#
# 				<a href="new.php/?id=1342" id="carousel" style="color: #dark blue !important;">
# 						LEER MAS
# 				</a>
#
#
# 			</div>
#
# 			<div class="carousel-item col-12 col-sm-6 col-md-4 col-lg-3">
#
#
# 			<a href="new.php/?id=1341" id="carousel">
# 			<img alt="img" class="img-fluid mx-auto d-block" src="../../tec_noticias/imagenes_noticias/8746.jpg"/>
# 			</a>
#
# 				<a href="new.php/?id=1341" id="carousel">
# 				<h5>TOMA DE PROTESTA DEL CAPÍTULO ESTUDIANTIL DE ING. MECATRÓNICA</h5>
# 				</a>
# 				<h6></h6>
#
#
# 				<a href="new.php/?id=1341" id="carousel" style="color: #dark blue !important;">
# 						LEER MAS
# 				</a>
#
#
# 			</div>
#
# 			<div class="carousel-item col-12 col-sm-6 col-md-4 col-lg-3">
#
#
# 			<a href="new.php/?id=1340" id="carousel">
# 			<img alt="img" class="img-fluid mx-auto d-block" src="../../tec_noticias/imagenes_noticias/8740.jpg"/>
# 			</a>
#
# 				<a href="new.php/?id=1340" id="carousel">
# 				<h5>SE CERTIFICAN EN ESTANDAR DE COMPETENCIA LABORAL EC0264 -SEIS SIGMA- A ESTUDIANTES DEL TECNM </h5>
# 				</a>
# 				<h6></h6>
#
#
# 				<a href="new.php/?id=1340" id="carousel" style="color: #dark blue !important;">
# 						LEER MAS
# 				</a>
#
#
# 			</div>
#
# 			<div class="carousel-item col-12 col-sm-6 col-md-4 col-lg-3">
#
#
# 			<a href="new.php/?id=1339" id="carousel">
# 			<img alt="img" class="img-fluid mx-auto d-block" src="../../tec_noticias/imagenes_noticias/8736.jpg"/>
# 			</a>
#
# 				<a href="new.php/?id=1339" id="carousel">
# 				<h5>CAMPUS LA  LAGUNA Y CAMPUS TORREÓN DEL TECNM PACTAN CONVENIO DE COLABORACIÓN</h5>
# 				</a>
# 				<h6></h6>
#
#
# 				<a href="new.php/?id=1339" id="carousel" style="color: #dark blue !important;">
# 						LEER MAS
# 				</a>
#
#
# 			</div>
#
# 			<div class="carousel-item col-12 col-sm-6 col-md-4 col-lg-3">
#
#
# 			<a href="new.php/?id=1338" id="carousel">
# 			<img alt="img" class="img-fluid mx-auto d-block" src="../../tec_noticias/imagenes_noticias/8722.jpg"/>
# 			</a>
#
# 				<a href="new.php/?id=1338" id="carousel">
# 				<h5>CEREMONIA DE INVESTIDURA MESA DIRECTIVA FUNDADORA IISE MÉXICO</h5>
# 				</a>
# 				<h6></h6>
#
#
# 				<a href="new.php/?id=1338" id="carousel" style="color: #dark blue !important;">
# 						LEER MAS
# 				</a>
#
#
# 			</div>
#
# 			<div class="carousel-item col-12 col-sm-6 col-md-4 col-lg-3">
#
#
# 			<a href="new.php/?id=1336" id="carousel">
# 			<img alt="img" class="img-fluid mx-auto d-block" src="../../tec_noticias/imagenes_noticias/8705.jpg"/>
# 			</a>
#
# 				<a href="new.php/?id=1336" id="carousel">
# 				<h5>MILWAUKEE TOOLS COMPANY: EN VISIÓN DE COLABORACIÓN CON EL TECNM CAMPUS LA LAGUNA</h5>
# 				</a>
# 				<h6></h6>
#
#
# 				<a href="new.php/?id=1336" id="carousel" style="color: #dark blue !important;">
# 						LEER MAS
# 				</a>
#
#
# 			</div>
#
# 			<div class="carousel-item col-12 col-sm-6 col-md-4 col-lg-3">
#
#
# 			<a href="new.php/?id=1337" id="carousel">
# 			<img alt="img" class="img-fluid mx-auto d-block" src="../../tec_noticias/imagenes_noticias/8714.jpg"/>
# 			</a>
#
# 				<a href="new.php/?id=1337" id="carousel">
# 				<h5>CAPITULO ESTUDIANTIL SALSS.DEL TECNM CAMPUS LA LAGUNA RENUEVA SU MESA DIRECTIVA</h5>
# 				</a>
# 				<h6></h6>
#
#
# 				<a href="new.php/?id=1337" id="carousel" style="color: #dark blue !important;">
# 						LEER MAS
# 				</a>
#
#
# 			</div>
#
#
# 		</div>
# 			<a class="carousel-control-prev" data-slide="prev" href="#carousel-example" role="button">
# 				<span aria-hidden="true" class="carousel-control-prev-icon"></span>
# 				<span class="sr-only">Previous</span>
# 			</a>
#
# 			<a class="carousel-control-next" data-slide="next" href="#carousel-example" role="button">
# 				<span aria-hidden="true" class="carousel-control-next-icon"></span>
# 				<span class="sr-only">Next</span>
# 			</a>
#
#
# 			</div>
# 		</div>
# 		<br/><br/>
# 	</div>
# 	<br/><br/><br/>
#
#
#
#         <!-- Javascript -->
# 		<!--<script src="js/jquery-3.3.1.min.js"></script>
# 		<script src="js/jquery-migrate-3.0.0.min.js"></script>
# 		<script src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.14.6/umd/popper.min.js" integrity="sha384-wHAiFfRlMFy6i5SRaxvfOCifBUQy1xHdJ/yoi7FRNXMRBu5WHdZYu1hA6ZOblgut" crossorigin="anonymous"></script>
# 		<script src="https://stackpath.bootstrapcdn.com/bootstrap/4.2.1/js/bootstrap.min.js" integrity="sha384-B0UglyR+jN6CkvvICOB2joaf5I4l3gm9GU6Hc1og6Ls7i6U/mkkaduKaBhlAXv9k" crossorigin="anonymous"></script>
#         <script src="js/jquery.backstretch.min.js"></script>
#         <script src="js/wow.min.js"></script>
#         <script src="js/scripts.js"></script>-->
#
#
#
#
#
#
#
#
#
#
#     <section id="Section1" style="background-color: #efefef; width:85%; margin:auto; padding-bottom:15px;">
#
#         <center>
#             <h2 class="mbr-section-title pb-3 align-center mbr-fonts-style display-4" style="margin-bottom: 15px; margin: auto;">
#                 Síguenos
#             </h2>
#         </center>
#
#         <div class="media-container-row" style="text-align:center">
#
#             <!--Twitter-->
#             <span style="margin-top:15px;">
#                 <a class="twitter-timeline" data-dnt="true" data-height="525" data-lang="es" data-theme="light" data-width="330" href="https://twitter.com/itlalaguna?ref_src=twsrc%5Etfw">Tweets by
#                     itlalaguna</a>
#                 <script async="" charset="utf-8" src="https://platform.twitter.com/widgets.js"></script>
#             </span>
#
#             <!--Youtube-->
#             <iframe allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" frameborder="0" height="525" src="https://www.youtube.com/embed/swACDm94S5g" style="margin-top:15px;" width="280"></iframe>
#
#             <!--Facebook-->
#             <iframe allow="encrypted-media" allowtransparency="true" frameborder="0" height="525" scrolling="no" src="https://www.facebook.com/plugins/page.php?href=https%3A%2F%2Fwww.facebook.com%2FtecLaguna%2F&amp;tabs=timeline&amp;width=340&amp;height=500&amp;small_header=false&amp;adapt_container_width=true&amp;hide_cover=false&amp;show_facepile=false&amp;appId" style="margin-top:15px;" width="280"></iframe>
#
#
#                 <div style="width: 100%; align-items:center;">
#                         <div class="tecCar">
#
#                         <div><a href="CALIDAD.PHP"><img alt="" class="center" src="img/anexos/SG.png"/></a></div>
#                         <div><a href="https://www.tecnm.mx/?vista=Protocolo_Actuacion"><img alt="" class="center" src="img/anexos/Boton_Actuacion.png"/></a></div>
#                         <div><a href="https://www.tecnm.mx/archivos/anexos/M00-CC-01_Codigo_de_Conducta_del_TecNM.pdf"><img alt="" class="center" src="img/anexos/codigo conducta btn.png"/></a></div>
#                         <div><a href="https://www.tecnm.mx/archivos/anexos/SFP-CE-2019_C%C3%B3digo_de_%C3%89tica.pdf"><img alt="" class="center" src="img/anexos/codigo etica btn.png"/></a></div>
#                         <div><a href="https://www.tecnm.mx/?vista=Comite_Etica_CEPCI"><img alt="" class="center" src="img/anexos/logoetica.png"/></a></div>
#                         <!--<div><a href=""><img class="center" src="img/anexos/convocatoria_seguro_btn.png" alt=""></a></div>-->
#                         <div><a href="piid.php"><img alt="" class="center" src="img/anexos/logopiid.png"/></a></div>
#                         <div><a href="https://www.tecnm.mx/archivos/anexos/PRONTUARIO%20-%20Difusion%20Digital.pdf"><img alt="" class="center" src="img/anexos/prontuario.png"/></a></div>
#                         <div><a href="https://www.tecnm.mx/archivos/anexos/Pronunciamiento%20Cero%20Tolerancia%20al%20Hostigamiento%20y%20Acoso%20Sexual%20en%20el%20TecNM.pdf"><img alt="" class="center" src="img/anexos/pronunciamiento.png"/></a></div>
#                         <div><a href="https://www.tecnm.mx/archivos/anexos/ANEXO%201%20Protocolo%20HSyAS.pdf"><img alt="" class="center" src="img/anexos/protocolo prevencion btn.png"/></a></div>
#
#                         <div><a href="transp.php"><img alt="" class="center" src="img/anexos/transparencia.png"/></a></div>
#                         <div><a href="proveedores.php"><img alt="" class="center" src="img/anexos/proveedoresgris.png"/></a></div>
#                         <div><a href="historial.php"><img alt="" class="center" src="img/anexos/historialgris.png"/></a></div>
#                         </div>
#                 </div>
#
#         </div>
#     </section>
#
#     <!------------------------------------------BOT-------------------------------------------------------- -->
# <div class="tecbot-container" id="contenedorBot">
#     <div class="tecbot-titleChatBar">
#         <div class="tecbot-Dot"></div>
#         <div class="tecbot-titleBarText">Hable con nosotros</div>
#         <div class="tecbot-icon">
#             <i aria-hidden="true" class="fa fa-window-minimize mr-1 bot-click" id="icon-bar"></i>
#             <i aria-hidden="true" class="fa fa-window-close bot-click" id="icon-bar-close"></i>
#         </div>
#     </div>
#     <div class="tecbot-maximize" id="chat-body" style="display: block;">
#         <div class="tecbot-chatContainer" id="chatContainer">
#             <div class="tecbot-chatBox" id="chat">
#                 <div class="tecbot-chatWelcome">
#                     <div>En línea</div>
#                 </div>
#                 <div class="tecbot-msgBot tecbot-msgBotText" style="display: inline-block;">Hola, bienvenido (a) al
#                     TecNM campus La Laguna, ¿en que puedo ayudarte?
#                 </div>
#                 <div class="tecbot-msgBot tecbot-msgBotText" style="display: inline-block;">
#                     Selecciona alguna de nuestras opciones:
#                     <button class="menu-option" id="ac" onclick="pregunta('actividades-complementarias')">Actividades
#                         extraescolares</button>
#                     <button class="menu-option" id="ca" onclick="agregarMenu(['Actualizar: teléfono, correo, dirección', 'Errores en nombre o apellido en el sistema', 'Errores en promedio'],['actualizar-datos', 'errores-nombre', 'errores-promedio'], 'Actualización de datos:')">Actualización de datos del alumno</button>
#                     <button class="menu-option" id="ca" onclick="pregunta('baja-semestre')">Baja de semestre</button>
#                     <button class="menu-option" id="ca" onclick="pregunta('becas')">Becas</button>
#                     <button class="menu-option" id="ca" onclick="pregunta('calendario-actividades')">Calendario
#                         de actividades</button>
#                     <button class="menu-option" id="tu" onclick="pregunta('correos')">Contactos y correos de
#                         coordinadores (as)</button>
#                     <button class="menu-option" id="convocatorias" onclick="pregunta('convocatorias')">Convocatorias</button>
#                     <button class="menu-option" id="costos" onclick="agregarMenu(['Cambio de carrera','Certificados','Constancias', 'Credenciales','Exámenes','Inscripciones licenciatura', 'Inscripciones posgrado', 'Titulación'],['cambio-carrera', 'certificado','constancias', 'credenciales','examenes', 'inscripciones-licenciatura', 'inscripciones-posgrado', 'costo-titulacion'], 'Los costos de los cuales se tiene información son los siguientes:')">Costos</button>
#                     <button class="menu-option" id="ingreso" onclick="agregarMenu(['Nueva credencial','Reposición de credencial','Resello de credencial'],['nueva-credencial', 'reposicion-credencial', 'resello-credencial'], 'Opciones sobre credenciales:')">Credenciales</button>
#                     <button class="menu-option" id="ca" onclick="pregunta('creditos-complementarios')">Créditos complementarios</button>
#                     <button class="menu-option" id="cursos" onclick="pregunta('cursos')">Cursos</button>
#                     <button class="menu-option" id="ca" onclick="agregarMenu(['Horarios nuevo ingreso', 'Horarios reingreso'],['horario-nuevo-ingreso', 'horario-clase'], 'Horarios:')">Horarios de clases</button>
#                     <button class="menu-option" id="idiomas" onclick="pregunta('idiomas')">Idiomas</button>
#                     <button class="menu-option" id="ingreso" onclick="agregarMenu(['Ingreso licenciatura ENE-JUN', 'Ingreso posgrado ENE-JUN', 'Ingreso licenciatura AGO-DIC', 'Ingreso posgrado AGO-DIC','Semestre de nivelación AGO-DIC'],['enejun-ingreso-a-licenciatura', 'enejun-ingreso-a-posgrado', 'agodic-ingreso-a-licenciatura', 'agodic-ingreso-a-posgrado', 'agodic-nivelacion'], '¿Acerca de qué tipo de información deseas conocer?')">Ingreso</button>
#                     <button class="menu-option" id="planesEstudio" onclick="pregunta('informacion-estudios')">Planes de
#                         estudio</button>
#                     <button class="menu-option" id="ingreso" onclick="agregarMenu(['Recuperar contraseña de correo institucional', 'Recuperar contraseña de ficha/estatus'],['recuperar-contrasena', 'contrasena-ficha'], 'Opciones sobre recuperación de contraseñas:')">Recuperación de contraseña</button>
#                     <button class="menu-option" id="ca" onclick="pregunta('seguro-facultativo')">Seguro facultativo</button>
#                     <button class="menu-option" id="ca" onclick="pregunta('titulacion')">Titulación</button>
# ...
#                     $("#chatContainer").animate({
#                         scrollTop: $('#chatContainer').prop("scrollHeight")
#                     }, 500);
#                 } catch (error) {
#                     var botHtml =
#                         '<div class="tecbot-msgBot" style="display: inline-block;"><p class=" tecbot-msgBotText">' +
#                         data + '</p></div>';
#                     chat.append(botHtml);
#                     var menuReturn =
#                         '<div class="tecbot-msgBot" style="display: inline-block;"><p class=" tecbot-msgBotText"><button class="menu-option" onclick="menuInicial()">Volver a menú</button></p></div>';
#                     chat.append(menuReturn);
#                     $("#chatContainer").animate({
#                         scrollTop: $('#chatContainer').prop("scrollHeight")
#                     }, 500);
#                 }
#             });
#         }
#
#     </script>
#     <!------------------------------------------BOT--------------------------------------------------------->
#
#
#     <!-- Otras Páginas -->
#
# <section class="" id="features3-2" style="width:100%; margin: auto; margin-bottom: 2%; margin-top:2%; background-color: #efefef;">
#     <center>
#         <h2 class="mbr-section-title pb-3 align-center mbr-fonts-style display-2">
#             Sitios de Interés
#         </h2>
#     </center>
#
#     <div align="center">
#
# <a href="https://www.conacyt.gob.mx/" target="_blank">
#     <img alt="concyt" src="img/interes/CONACYT.png" style="width:16%;" title="CONACYT"/>
# </a>
#
# <a href="https://www.conricyt.mx/" target="_blank">
#      <img alt="conricyt" src="img/interes/CONRICYT.png" style="width:16%;" title="CONRICYT"/>
# </a>
#
# <a href="http://www.ifai.org.mx/" target="_blank">
#     <img alt="inai" src="img/interes/INAI.png" style="width:16%;" title="INAI"/>
# </a>
#
# <a href="prodep/docu.htmL" target="_blank">
#     <img alt="contraloria" src="img/interes/CONtraloria.png" style="width:16%;" title="CONACYT"/></a>
#
# <a href="http://consultapublicamx.inai.org.mx:8080/vut-web/?idSujetoObigadoParametro=10009&amp;idEntidadParametro=33&amp;idSectorParametro=21" target="_blank">
#     <img alt="pnt" src="img/interes/PNT.png" style="width:16%;" title=""/>
# </a>
#
#
#
#     <br/>
#     <a href="becasint/becasint.html" target="_blank">
#     <img alt="convocatorias" src="img/interes/convocatorias.png" style="width:11%;" title=""/></a>
#
# <a href="pulsotec/pulsotecdigital.html" target="_blank"><img alt="pulsotec" src="img/interes/revista.png" style="width:11%;" title=""/></a><a href="bolsadetrabajo.html" target="_blank"><img alt="bolsa" src="img/interes/bolsa.png" style="width:11%;" title=""/></a>
#     <a href="seguimientoegresados.html" target="_blank"><img alt="egresados" src="img/interes/egresados.png" style="width:11%;" title=""/></a>
#
#     <a href="AVISOS/CALENDARIO.PDF" target="_blank"><img alt="egresados" src="img/interes/calendario.png" style="width:11%;" title=""/></a>
#
#     <a href="recbiblio.php"><img alt="egresados" src="img/interes/recursosbiblio.png" style="width:11%;" title=""/></a>
#     <a href="https://docs.google.com/forms/d/e/1FAIpQLSckSqRPLi4GVYVthg5wP034P8tiEgBhyLnNcd6JCc7ZkE1KGg/viewform?entry.1159593137=nombre&amp;entry.1809109965&amp;entry.1214002645&amp;entry.1344596603&amp;entry.1727722980&amp;entry.1573787809=nombre+completo&amp;entry.471819699=puesto&amp;entry.285911030=ITL&amp;entry.134294733=2018-03-03&amp;entry.1785309787=20:00&amp;entry.1084813065=ITL&amp;entry.1814560733=hechos&amp;entry.1641027819=Nombre+testigo&amp;entry.1484745992=Domicilio+testigo&amp;entry.769034671=S%C3%AD&amp;entry.1684521492=si1&amp;entry.1680632340=si2"><img alt="egresados" src="img/interes/buzond.png" style="width:11%;" title=""/></a>
#     <a href="https://docs.google.com/forms/d/e/1FAIpQLSddMvuMgSe8qJ63G7op3Pcr5-VEuV2_UPElM977PS9lm8faug/viewform"><img alt="egresados" src="img/interes/buzonq.png" style="width:11%;" title=""/></a>
#     </div>
#
# </section>
#
# <!--footer gris-->
#
# <!--ajustes fooder-->
# <style>
#     p#pie {
#         color: white;
#         font-family: century gothic;
#     }
#
#     h3#pie {
#         color: yellow;
#         margin-top: 10%;
#         font-family: century gothic;
#     }
#
#     h4#pie {
#         color: white;
#         margin-top: 10%;
#         font-family: century gothic;
#     }
#
#     a#pie {
#         font-family: century gothic;
#     }
#
#     div#sep {
#         height: 5%;
#         background: #0b231e;
#         width: 100%;
#     }
# </style>
#
# <!-- fooder gris-->
# <footer>
#     <div class="bg-secondary" style="background: #454547 !important;">
#         <div class="container">
#             <div class="row">
#
#                 <div class="col-lg-3">
#                     <h3 id="pie"> Dirección</h3>
#                     <p id="pie">Blvd. Revolución y Av. Instituto Tecnológico de La Laguna, Torreón, Coahuila, C.P. 27000
#                        <br/>  <a href="https://www.netacad.com/es">  <img alt="cisco" src="cisco.png" width="103"/></a>
#                         <br/><br/><a href="CALIDAD.PHP">  <img alt="iso" src="isogde.png" width="203"/></a>
#
#
#
#                    </p>
#
#                 </div>
#
#                 <div class="col-lg-3">
#                     <h3 id="pie"> Contacto</h3>
#                     <p id="pie" style="color: white;">Email: webmaster@correo.itlalaguna.edu.mx
#                         Teléfono: 52 (871) 705-13-13 </p>
#                 </div>
#
#                 <div class="col-lg-3">
#                     <h3 id="pie"> Enlaces </h3>
#                     <ul class="list-unsyled">
#                         <li><a href="http://portaltransparencia.gob.mx/buscador/search/search.do?method=begin" id="pie" style="color:#fff">Portal
#                                 de Obligaciones de Transparencia</a></li>
#                         <li><a href="http://inicio.ifai.org.mx/SitePages/ifai.aspx" id="pie" style="color:#fff">INAI</a>
#                         </li>
#                         <li><a data-target="#modalQuejas" data-toggle="modal" href="#" id="pie" style="color:#fff">Buzón
#                                 de Sugerencias</a></li>
#                         <li><span data-target="#modalQuejas" data-toggle="modal" href="#" id="pie" style="color:#fff">Visitas</span>
#
#
#
# <!-- Histats.com  START  (standard)-->
# <script type="text/javascript">document.write(unescape("%3Cscript src=%27http://s10.histats.com/js15.js%27 type=%27text/javascript%27%3E%3C/script%3E"));</script>
# <a href="http://www.histats.com" target="_blank" title="contadores web free"><script type="text/javascript">
# try {Histats.start(1,1838853,4,4003,112,61,"00011011");
# Histats.track_hits();} catch(err){};
# </script></a>
# <noscript></noscript>
# <!-- Histats.com  END  -->
#
#
#
# <!-- Start of StatCounter Code -->
#
# <script type="text/javascript">
# var sc_project=7949821;
# var sc_invisible=1;
# var sc_partition=59;
# var sc_click_stat=1;
# var sc_security="8c4af0fe";
# </script>
#
# <script src="http://www.statcounter.com/counter/counter.js" type="text/javascript"></script>
# <!-- End of StatCounter Code --><br/>
# <a href="http://my.statcounter.com/project/standard/stats.php?project_id=7949821&amp;guest=1" onclick="_gaq.push(['_trackEvent','links menu', 'abandono', 'estadisticas']);" target="_blank">Estadísticas</a>
#
#
#    <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-54252992-1', 'auto');
#   ga('send', 'pageview');
#
# </script>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                             </li>
#
#
#
#
#
#
#
#
#                     </ul>
#                 </div>
#
#                 <div class="col-lg-3">
#                     <h3 id="pie"> Ubicación </h3>
#                     <img height="70%" src="img/ubicacionITL.jpeg" width="100%"/>
#                     <a href="infra.php" id="pie"> Ver Ubicación </a>
#                 </div>
#
#             </div>
#         </div>
#         <br/>
#     </div>
#     <!--Fin fooder gris-->
#
#     <div id="sep">
#         <br/>
#     </div>
#     <!-- fooder verde-->
#     <footer class="main-footer" style="background: url(img/banners/fondofooter.jpg)">
#         <div class="list-info">
#             <div class="container">
#                 <div class="row">
#                     <div class="col-md-3" style="margin-top: 15%;">
#                         <img alt="logo gobierno de méxico" class="logo_footer" data-v-9e928f9a="" href="/" src="https://framework-gb.cdn.gob.mx/landing/img/logoheader.svg" style="margin-top: 5%;"/>
#                     </div>
#
#                     <div class="col-sm-3">
#                         <h4 id="pie">Enlaces</h4>
#                         <ul>
#                             <li><a href="https://participa.gob.mx" rel="noopener" target="_blank" title="Enlace abre en ventana nueva">Participa</a></li>
#                             <li><a href="https://www.gob.mx/publicaciones" rel="noopener" target="_blank" title="Enlace abre en ventana nueva">Publicaciones Oficiales</a></li>
#                             <li><a href="http://www.ordenjuridico.gob.mx" rel="noopener" target="_blank" title="Enlace abre en ventana nueva">Marco Jurídico</a></li>
#                             <li><a href="https://consultapublicamx.inai.org.mx/vut-web/" rel="noopener" target="_blank" title="Enlace abre en ventana nueva">Plataforma Nacional de Transparencia</a></li>
#                         </ul>
#                     </div>
#
#                     <div class="col-sm-3">
#                         <h4 id="pie">¿Qué es gob.mx?</h4>
#                         <p id="pie">Es el portal único de trámites, información y participación ciudadana. <a href="https://www.gob.mx/que-es-gobmx">Leer más</a></p>
#                         <ul>
#                             <li><a href="https://datos.gob.mx">Portal de datos abiertos</a></li>
#                             <li><a href="https://www.gob.mx/accesibilidad">Declaración de accesibilidad</a></li>
#                             <li><a href="https://www.gob.mx/privacidadintegral">Aviso de privacidad integral</a></li>
#                             <li><a href="https://www.gob.mx/privacidadsimplificado">Aviso de privacidad simplificado</a>
#                             </li>
#                             <li><a href="https://www.gob.mx/terminos">Términos y Condiciones</a></li>
#                             <li><a href="https://www.gob.mx/terminos#medidas-seguridad-informacion">Política de
#                                     seguridad</a></li>
#                             <li><a href="https://www.gob.mx/sitemap">Mapa de sitio</a></li>
#                         </ul>
#                     </div>
#
#                      <div class="col-sm-3">
#                         <h4 id="pie"><a href="https://www.gob.mx/tramites/ficha/presentacion-de-quejas-y-denuncias-en-la-sfp/SFP54">Denuncia
#                                 contra servidores públicos</a></h4> <br/><br/>
#                         <h4 id="pie">Síguenos en</h4>
#                         <h4><a aria-label="Facebook de presidencia" class="social-icon facebook" href="https://www.facebook.com/gobmexico" rel="noopener" target="_blank" title="Enlace abre en ventana nueva"><img alt="facebook" src="img/redes_sociales/faceb.png" width="10%"/></a><a aria-label="Twitter de presidencia" class="social-icon twitter" href="https://twitter.com/GobiernoMX" rel="noopener" target="_blank" title="Enlace abre en ventana nueva"><img alt="facebook" src="img/redes_sociales/twitt.png" width="10%"/></a></h4>
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </footer>
#     <!-- fin fooder verde-->
#
#     <div id="sep">
#         <br/>
#     </div>
#
#     <!-- boostrap -->
#     <script crossorigin="anonymous" integrity="sha256-9/aliU8dGd2tb6OSsuzixeV4y/faTqgFtohetphbbj0=" src="https://code.jquery.com/jquery-3.5.1.min.js"></script>
#     <script crossorigin="anonymous" integrity="sha384-ZMP7rVo3mIykV+2+9J3UJ46jBk0WLaUAdn689aCwoqbBJiSnjAK/l8WvCWPIPm49" src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.14.3/umd/popper.min.js">
#     </script>
#     <script crossorigin="anonymous" integrity="sha384-smHYKdLADwkXOn1EmN1qk/HfnUcbVRZyYmZ4qpPea6sjB/pTJ0euyQp0Mk8ck+5T" src="https://stackpath.bootstrapcdn.com/bootstrap/4.1.1/js/bootstrap.min.js">
#     </script>
#     <script src="js/jquery.backstretch.min.js"></script>
#     <script src="js/wow.min.js"></script>
#     <script src="js/scripts.js"></script>
#     <script src="js/slick.min.js" type="text/javascript"></script>
#
#     <script>
#     console.log("Footer cargado");
#         //Navbar
#         $('.dropdown-menu a.dropdown-toggle').on('click', function (e) {
#             if (!$(this).next().hasClass('show')) {
#                 $(this).parents('.dropdown-menu').first().find('.show').removeClass('show');
#             }
#             var $subMenu = $(this).next('.dropdown-menu');
#             $subMenu.toggleClass('show');
#
#
#             $(this).parents('li.nav-item.dropdown.show').on('hidden.bs.dropdown', function (e) {
#                 $('.dropdown-submenu .show').removeClass('show');
#             });
#
#
#             return false;
#         });
#
#         //Si existe el elemento con id tecCar, quiere decir que es el index y a continuacion se ejecuta el codigo del index
#         if ($('.tecCar').length) {
#
#             //Script works to Carousel
#             var slideIndex = [1, 1];
#             var slideId = ["mySlides1", "mySlides2"];
#             var bolitas = document.getElementsByClassName("bolita");
#             var i = 1;
#
#             showSlides(1, 0);
#             //showSlides(1, 1);
#
#             function plusSlides(n, no) {
#                 showSlides(slideIndex[no] += n, no);
#             }
#
#             function foto(n, interval = true) {
#                 if (interval)
#                     i = n;
#                 showSlides(slideIndex[0] = n, 0);
#             }
#
#             function showSlides(n = 1, no = 0) {
#                 var i;
#                 var x = document.getElementsByClassName(slideId[no]);
#                 if (n > x.length) {
#                     slideIndex[no] = 1
#                 }
#                 if (n < 1) {
#                     slideIndex[no] = x.length
#                 }
#                 for (i = 0; i < x.length; i++) {
#                     x[i].style.display = "none";
#                 }
#                 for (var i = 0; i < bolitas.length; i++) {
#                     bolitas[i].className = bolitas[i].className.replace("activo", "");
#                 }
#                 x[slideIndex[no] - 1].style.display = "block";
#                 bolitas[slideIndex[no] - 1].className += " activo";
#             }
#
#             //Transcición automatica para el banner
#             $(document).ready(function () {
#                 setInterval(function () {
#                     if (i == 36) {
#                         i = 1;
#                     }
#                     foto(i++, false);
#                 }, 3000);
#             });
#
#
#             //Carusel gris
#             if (screen.width < 1024) {
#                 $('.tecCar').slick({
#                     infinite: true,
#                     slidesToShow: 2,
#                     slidesToScroll: 1,
#                     nextArrow: '<button type="button" class="slick-next"><i class="next fas fa-arrow-circle-right"></i></button>',
#                     prevArrow: '<button type="button" class="slick-prev"><i class="prev fas fa-arrow-circle-left"></i></button>'
#                 });
#             } else {
#                 $('.tecCar').slick({
#                     infinite: true,
#                     slidesToShow: 4,
#                     slidesToScroll: 1,
#                     nextArrow: '<button type="button" class="slick-next"><i class="next fas fa-arrow-circle-right"></i></button>',
#                     prevArrow: '<button type="button" class="slick-prev"><i class="prev fas fa-arrow-circle-left"></i></button>'
#                 });
#             }
#         }
#     </script>
#
#
#
#     </footer></body>

# %%
sopa.find_all("img")
# Out:
# [<img alt="Página de inicio, Gobierno de México" height="33" src="https://framework-gb.cdn.gob.mx/landing/img/logoheader.svg" style=" margin-left: 80%;"/>,
#  <img alt="Gobierno de México" src="img/logotipos/pleca-gob1.png" style="width:30%;height:auto"/>,
#  <img alt="Educación" src="img/logotipos/pleca-gob2.png" style="width:30%;height:auto; min-width:auto;"/>,
#  <img alt="TecNM" src="img/logotipos/pleca_tecnm.jpg" style="width:18%;height:auto; "/>,
#  <img alt="ITL" src="img/logotipos/itl2.jpeg" style="width:7%; height:auto;"/>,
#  <img class="img-fluid" src="img/icono-home.png"/>,
#  <img src="slider/office.png" style="width:100%"/>,
#  <img src="slider/convoinvest2.png" style="width:100%"/>,
#  <img src="slider/solicitud protocolos  titulación_mayo 2021.png" style="width:100%"/>,
#  <img src="slider/registro proyectos titulación_mayo 2021.png" style="width:100%"/>,
#  <img src="slider/certificados2.png" style="width:100%"/>,
#  <img src="slider/adm21ago2.png" style="width:100%"/>,
#  <img src="slider/puertas.jpg" style="width:100%"/>,
#  <img src="slider/mooc.jpg" style="width:100%"/>,
#  <img src="slider/cienciasbasicas.png" style="width:100%"/>,
#  <img src="slider/tripticoetica.jpg" style="width:100%"/>,
#  <img src="slider/bioetica.jpg" style="width:100%"/>,
#  <img src="slider/evalingles2.png" style="width:100%"/>,
#  <img src="slider/ci20212.png" style="width:100%"/>,
#  <img src="slider/anfei202.png" style="width:100%"/>,
#  <img src="slider/ingles203.jpg" style="width:100%"/>,
#  <img src="slider/cero tolerancia2.jpg" style="width:100%"/>,
#  <img src="slider/elibro2.png" style="width:100%"/>,
#  <img src="slider/directorio212.png" style="width:100%"/>,
#  <img src="slider/redesof.png" style="width:100%"/>,
#  <img src="slider/tecnmvirtual2.jpg" style="width:100%"/>,
#  <img src="slider/gradua204.jpg" style="width:100%"/>,
#  <img src="slider/protocolo202.jpg" style="width:100%"/>,
#  <img src="slider/cerotolerancia202.jpg" style="width:100%"/>,
#  <img alt="img" class="img-fluid mx-auto d-block" src="../../tec_noticias/imagenes_noticias/8778.jpg"/>,
#  <img alt="img" class="img-fluid mx-auto d-block" src="../../tec_noticias/imagenes_noticias/8760.jpg"/>,
#  <img alt="img" class="img-fluid mx-auto d-block" src="../../tec_noticias/imagenes_noticias/8768.jpg"/>,
#  <img alt="img" class="img-fluid mx-auto d-block" src="../../tec_noticias/imagenes_noticias/8753.jpg"/>,
#  <img alt="img" class="img-fluid mx-auto d-block" src="../../tec_noticias/imagenes_noticias/8746.jpg"/>,
#  <img alt="img" class="img-fluid mx-auto d-block" src="../../tec_noticias/imagenes_noticias/8740.jpg"/>,
#  <img alt="img" class="img-fluid mx-auto d-block" src="../../tec_noticias/imagenes_noticias/8736.jpg"/>,
#  <img alt="img" class="img-fluid mx-auto d-block" src="../../tec_noticias/imagenes_noticias/8722.jpg"/>,
#  <img alt="img" class="img-fluid mx-auto d-block" src="../../tec_noticias/imagenes_noticias/8705.jpg"/>,
#  <img alt="img" class="img-fluid mx-auto d-block" src="../../tec_noticias/imagenes_noticias/8714.jpg"/>,
#  <img alt="" class="center" src="img/anexos/SG.png"/>,
#  <img alt="" class="center" src="img/anexos/Boton_Actuacion.png"/>,
#  <img alt="" class="center" src="img/anexos/codigo conducta btn.png"/>,
#  <img alt="" class="center" src="img/anexos/codigo etica btn.png"/>,
#  <img alt="" class="center" src="img/anexos/logoetica.png"/>,
#  <img alt="" class="center" src="img/anexos/logopiid.png"/>,
#  <img alt="" class="center" src="img/anexos/prontuario.png"/>,
#  <img alt="" class="center" src="img/anexos/pronunciamiento.png"/>,
#  <img alt="" class="center" src="img/anexos/protocolo prevencion btn.png"/>,
#  <img alt="" class="center" src="img/anexos/transparencia.png"/>,
#  <img alt="" class="center" src="img/anexos/proveedoresgris.png"/>,
#  <img alt="" class="center" src="img/anexos/historialgris.png"/>,
#  <img alt="" src="./img/loadig.gif" style="width: 30px; height: 30px;"/>,
#  <img alt="concyt" src="img/interes/CONACYT.png" style="width:16%;" title="CONACYT"/>,
#  <img alt="conricyt" src="img/interes/CONRICYT.png" style="width:16%;" title="CONRICYT"/>,
#  <img alt="inai" src="img/interes/INAI.png" style="width:16%;" title="INAI"/>,
#  <img alt="contraloria" src="img/interes/CONtraloria.png" style="width:16%;" title="CONACYT"/>,
#  <img alt="pnt" src="img/interes/PNT.png" style="width:16%;" title=""/>,
#  <img alt="convocatorias" src="img/interes/convocatorias.png" style="width:11%;" title=""/>,
#  <img alt="pulsotec" src="img/interes/revista.png" style="width:11%;" title=""/>,
#  <img alt="bolsa" src="img/interes/bolsa.png" style="width:11%;" title=""/>,
#  <img alt="egresados" src="img/interes/egresados.png" style="width:11%;" title=""/>,
#  <img alt="egresados" src="img/interes/calendario.png" style="width:11%;" title=""/>,
#  <img alt="egresados" src="img/interes/recursosbiblio.png" style="width:11%;" title=""/>,
#  <img alt="egresados" src="img/interes/buzond.png" style="width:11%;" title=""/>,
#  <img alt="egresados" src="img/interes/buzonq.png" style="width:11%;" title=""/>,
#  <img alt="cisco" src="cisco.png" width="103"/>,
#  <img alt="iso" src="isogde.png" width="203"/>,
#  <img height="70%" src="img/ubicacionITL.jpeg" width="100%"/>,
#  <img alt="logo gobierno de méxico" class="logo_footer" data-v-9e928f9a="" href="/" src="https://framework-gb.cdn.gob.mx/landing/img/logoheader.svg" style="margin-top: 5%;"/>,
#  <img alt="facebook" src="img/redes_sociales/faceb.png" width="10%"/>,
#  <img alt="facebook" src="img/redes_sociales/twitt.png" width="10%"/>]

# %%
#Pagina de clima
import requests
from bs4 import BeautifulSoup
pagina = requests.get("https://forecast.weather.gov/MapClick.php?lat=29.633&lon=-95.6007#.YJPuBsDisdW")
soup = BeautifulSoup(pagina.content, "html.parser")
dias = soup.find(id="seven-day-forecast")
forecast_items = dias.find_all(class_="tombstone-container")
actual = forecast_items[0]
print(actual.prettify())
# Out:
# <div class="tombstone-container">
#  <p class="period-name">
#   Today
#   <br/>
#   <br/>
#  </p>
#  <p>
#   <img alt="Today: Sunny, with a high near 86. Northeast wind 5 to 10 mph. " class="forecast-icon" src="newimages/medium/skc.png" title="Today: Sunny, with a high near 86. Northeast wind 5 to 10 mph. "/>
#  </p>
#  <p class="short-desc">
#   Sunny
#  </p>
#  <p class="temp temp-high">
#   High: 86 °F
#  </p>
# </div>

# %%
forecast_items
#nombre del item :HOY
#descripción
#Condiciones
#temperatura
# Out:
# [<div class="tombstone-container">
#  <p class="period-name">Today<br/><br/></p>
#  <p><img alt="Today: Sunny, with a high near 86. Northeast wind 5 to 10 mph. " class="forecast-icon" src="newimages/medium/skc.png" title="Today: Sunny, with a high near 86. Northeast wind 5 to 10 mph. "/></p><p class="short-desc">Sunny</p><p class="temp temp-high">High: 86 °F</p></div>,
#  <div class="tombstone-container">
#  <p class="period-name">Tonight<br/><br/></p>
#  <p><img alt="Tonight: Clear, with a low around 64. Northeast wind around 5 mph. " class="forecast-icon" src="newimages/medium/nskc.png" title="Tonight: Clear, with a low around 64. Northeast wind around 5 mph. "/></p><p class="short-desc">Clear</p><p class="temp temp-low">Low: 64 °F</p></div>,
#  <div class="tombstone-container">
#  <p class="period-name">Friday<br/><br/></p>
#  <p><img alt="Friday: Sunny, with a high near 86. Northeast wind 5 to 10 mph becoming southeast in the afternoon. " class="forecast-icon" src="newimages/medium/few.png" title="Friday: Sunny, with a high near 86. Northeast wind 5 to 10 mph becoming southeast in the afternoon. "/></p><p class="short-desc">Sunny</p><p class="temp temp-high">High: 86 °F</p></div>,
#  <div class="tombstone-container">
#  <p class="period-name">Friday<br/>Night</p>
#  <p><img alt="Friday Night: Mostly clear, with a low around 65. Southeast wind 5 to 10 mph. " class="forecast-icon" src="newimages/medium/nfew.png" title="Friday Night: Mostly clear, with a low around 65. Southeast wind 5 to 10 mph. "/></p><p class="short-desc">Mostly Clear</p><p class="temp temp-low">Low: 65 °F</p></div>,
#  <div class="tombstone-container">
#  <p class="period-name">Saturday<br/><br/></p>
#  <p><img alt="Saturday: Mostly sunny, with a high near 86. South wind 5 to 15 mph, with gusts as high as 25 mph. " class="forecast-icon" src="newimages/medium/sct.png" title="Saturday: Mostly sunny, with a high near 86. South wind 5 to 15 mph, with gusts as high as 25 mph. "/></p><p class="short-desc">Mostly Sunny</p><p class="temp temp-high">High: 86 °F</p></div>,
#  <div class="tombstone-container">
#  <p class="period-name">Saturday<br/>Night</p>
#  <p><img alt="Saturday Night: Mostly cloudy, with a low around 74." class="forecast-icon" src="newimages/medium/nbkn.png" title="Saturday Night: Mostly cloudy, with a low around 74."/></p><p class="short-desc">Mostly Cloudy</p><p class="temp temp-low">Low: 74 °F</p></div>,
#  <div class="tombstone-container">
#  <p class="period-name">Sunday<br/><br/></p>
#  <p><img alt="Sunday: A 20 percent chance of showers and thunderstorms after 1pm.  Partly sunny, with a high near 87." class="forecast-icon" src="DualImage.php?i=bkn&amp;j=scttsra&amp;jp=20" title="Sunday: A 20 percent chance of showers and thunderstorms after 1pm.  Partly sunny, with a high near 87."/></p><p class="short-desc">Mostly Cloudy<br/>then Slight<br/>Chance<br/>T-storms</p><p class="temp temp-high">High: 87 °F</p></div>,
#  <div class="tombstone-container">
#  <p class="period-name">Sunday<br/>Night</p>
#  <p><img alt="Sunday Night: A 30 percent chance of showers and thunderstorms.  Mostly cloudy, with a low around 74." class="forecast-icon" src="newimages/medium/nscttsra30.png" title="Sunday Night: A 30 percent chance of showers and thunderstorms.  Mostly cloudy, with a low around 74."/></p><p class="short-desc">Chance<br/>T-storms</p><p class="temp temp-low">Low: 74 °F</p></div>,
#  <div class="tombstone-container">
#  <p class="period-name">Monday<br/><br/></p>
#  <p><img alt="Monday: A 20 percent chance of showers and thunderstorms.  Partly sunny, with a high near 88." class="forecast-icon" src="newimages/medium/scttsra20.png" title="Monday: A 20 percent chance of showers and thunderstorms.  Partly sunny, with a high near 88."/></p><p class="short-desc">Slight Chance<br/>T-storms</p><p class="temp temp-high">High: 88 °F</p></div>]

# %%
#extracción de la información
hoy = actual.find(class_ = "period-name").get_text()
descripcion = actual.find(class_ = "short-desc").get_text()
temp = actual.find(class_ = "temp").get_text()
print(hoy)
print(descripcion)
print(temp)
# Out:
# Today
# Sunny
# High: 86 °F

# %%
#Podemos traernos la descripcion de la imagen
imagenHOY = actual.find("img")
describe = imagenHOY["title"]
print(describe)
# Out:
# Today: Sunny, with a high near 86. Northeast wind 5 to 10 mph.

# %%
tags = dias.select(".tombstone-container .period-name")
semana = [i.get_text() for i in tags]
semana
# Out:
# ['Today',
#  'Tonight',
#  'Friday',
#  'FridayNight',
#  'Saturday',
#  'SaturdayNight',
#  'Sunday',
#  'SundayNight',
#  'Monday']

# %%
tags
# Out:
# [<p class="period-name">Today<br/><br/></p>,
#  <p class="period-name">Tonight<br/><br/></p>,
#  <p class="period-name">Friday<br/><br/></p>,
#  <p class="period-name">Friday<br/>Night</p>,
#  <p class="period-name">Saturday<br/><br/></p>,
#  <p class="period-name">Saturday<br/>Night</p>,
#  <p class="period-name">Sunday<br/><br/></p>,
#  <p class="period-name">Sunday<br/>Night</p>,
#  <p class="period-name">Monday<br/><br/></p>]
