# %% [markdown]
# Desastre de titanic survival - Survival (0 = No; 1 = Yes) class - Passenger Class (1 = 1st, 2 = 2nd; 3 = 3rd) name - Name sex - Sex age - Age sibsp - Number of Siblings/Spouses Aboard parch - Number of Parentes/Children Aboard ticket - Ticket Number fare - Passenger Fare cabin - Cabin embarked - Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton) boat  - Lifeboat (if survived) body - Body number (if did not survive and body was recovered)

# %%
import pandas as pd
arch = "C:\\Users\\jmas_\\Jupyter\\Datasets\\titanic.csv"

# %%
arch
# Out:
# 'C:\\Users\\jmas_\\Jupyter\\Datasets\\titanic.csv'

# %%
data = pd.read_csv(arch, delimiter=',', encoding='latin1')

# %%
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
data.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked   class  \
# 886         0       2    male  27.0      0      0  13.00        S  Second
# 887         1       1  female  19.0      0      0  30.00        S   First
# 888         0       3  female   NaN      1      2  23.45        S   Third
# 889         1       1    male  26.0      0      0  30.00        C   First
# 890         0       3    male  32.0      0      0   7.75        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
len(data)
# Out:
# 891

# %%
data.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
data.count()
# Out:
# survived       891
# pclass         891
# sex            891
# age            714
# sibsp          891
# parch          891
# fare           891
# embarked       889
# class          891
# who            891
# adult_male     891
# deck           203
# embark_town    889
# alive          891
# alone          891
# dtype: int64

# %%
data.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
data['age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
data[data.age == 30]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 79          1       3  female  30.0      0      0   12.4750        S   Third
# 157         0       3    male  30.0      0      0    8.0500        S   Third
# 178         0       2    male  30.0      0      0   13.0000        S  Second
# 213         0       2    male  30.0      0      0   13.0000        S  Second
# 219         0       2    male  30.0      0      0   10.5000        S  Second
# 244         0       3    male  30.0      0      0    7.2250        C   Third
# 253         0       3    male  30.0      1      0   16.1000        S   Third
# 257         1       1  female  30.0      0      0   86.5000        S   First
# 286         1       3    male  30.0      0      0    9.5000        S   Third
# 308         0       2    male  30.0      1      0   24.0000        C  Second
# 309         1       1  female  30.0      0      0   56.9292        C   First
# ...

# %%
pd.crosstab(data.survived, data.sex)
# Out:
# sex       female  male
# survived
# 0             81   468
# 1            233   109

# %%
sobreviviente_clase_HM = data.groupby(['pclass', 'sex'])['survived'].sum()
#sobreviviente_clase_HM.to_frame()
#print(sobreviviente_clase_HM)
#df = pd.DataFrame(sobreviviente_clase_HM)
s = pd.DataFrame(sobreviviente_clase_HM, index=["1st", "2nd", "3rd"], columns = ["Clase", "Genero", "sobre"])
print(s)
#ren = {1: "Primera", 2: "Segunda", 3: "Tercera"}
#sobreviviente_clase_HM.rename(index=ren, inplace=True)
#sobreviviente_clase_HM
#col = {"pclass": "Close", "sex": "Genero"}
#sobreviviente_clase_HM.rename(columns = ["Clase", "Genero"], inplace=True)
#print(sobreviviente_clase_HM)
#sobreviviente_clase_HM
# Out:
#     Clase Genero sobre
# 1st   NaN    NaN   NaN
# 2nd   NaN    NaN   NaN
# 3rd   NaN    NaN   NaN

# %%
sobreviviente_clase_HM[2]
# Out:
# sex
# female    70
# male      17
# Name: survived, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
#para ver plots juntos en la misma linea
plt.subplot2grid((3,3),(0,0))

data.survived.value_counts().plot(kind='bar')

plt.title('Los que sobrevivieron')
#manera más amable %
plt.subplot2grid((3,3),(0,1))
data.survived.value_counts(normalize=True).plot(kind='bar')
plt.title('Los que sobrevivieron en %')
plt.subplot2grid((3,3),(1,0))

data.survived.value_counts().plot(kind='bar')
plt.subplot2grid((3,3),(0,1))

data.survived.value_counts().plot(kind='bar')
plt.subplot2grid((3,3),(2,0))

data.survived.value_counts().plot(kind='bar')

#plt.show
# Out:
# <AxesSubplot:>

# %%
figura = plt.figure(figsize=(30,10)) #crea el canvas 30x10 pix
#para ver plots juntos en la misma linea

data.sex[data.survived==1].value_counts(normalize=True).plot(kind='bar')

plt.title('Los que sobrevivieron mujeres y hombres')
#plt.show()
# Out:
# Text(0.5, 1.0, 'Los que sobrevivieron mujeres y hombres')

# %%
figura = plt.figure(figsize=(10, 5)) #crea el canvas 10x5 pix
#para ver plots juntos en la misma linea
data.pclass[data.survived == 1].value_counts(normalize = True).plot(kind='bar')
plt.title('Los que sobrevivieron por clase')
#plt.show()
# Out:
# Text(0.5, 1.0, 'Los que sobrevivieron por clase')

# %%
#relacion de la case con la edad
figura = plt.figure(figsize=(20,10))
for tipoBoleto in [1, 2, 3]:
    data.age[data.pclass == tipoBoleto].plot(kind='kde')
    
plt.legend(('1ra clase', '2da clase', '3ra clase'))
