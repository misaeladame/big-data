# %% [markdown]
# # U2_Procesamiento con Pandas
#
# TECNM Campus La Laguna
#
# Big Data
#
# **Alumno: 18131209 - ADAME SANDOVAL JOSE MISAEL**

# %% [markdown]
# ## Dataset 1: Seguridad en las aerolíneas

# %%
#importar la libreria de Pandas
import pandas as pd

# %%
#Lectura desde un dataset CSV - airline-safety.csv
ruta = "C:\\"
df_as = pd.read_csv(ruta+"airline-safety.csv")

# %%
type(df_as)
# Out:
# pandas.core.frame.DataFrame

# %%
#Todo el archivo con to_string()
print(df_as.to_string())
# Out:
#                        airline  avail_seat_km_per_week  incidents_85_99  fatal_accidents_85_99  fatalities_85_99  incidents_00_14  fatal_accidents_00_14  fatalities_00_14
# 0                   Aer Lingus               320906734                2                      0                 0                0                      0                 0
# 1                    Aeroflot*              1197672318               76                     14               128                6                      1                88
# 2        Aerolineas Argentinas               385803648                6                      0                 0                1                      0                 0
# 3                  Aeromexico*               596871813                3                      1                64                5                      0                 0
# ...

# %%
# Observar los registros del dataset con print
print (df_as)
# Out:
#                        airline  avail_seat_km_per_week  incidents_85_99  \
# 0                   Aer Lingus               320906734                2
# 1                    Aeroflot*              1197672318               76
# 2        Aerolineas Argentinas               385803648                6
# 3                  Aeromexico*               596871813                3
# 4                   Air Canada              1865253802                2
# 5                   Air France              3004002661               14
# 6                   Air India*               869253552                2
# 7             Air New Zealand*               710174817                3
# 8             Alaska Airlines*               965346773                5
# 9                     Alitalia               698012498                7
# 10          All Nippon Airways              1841234177                3
# 11                   American*              5228357340               21
# ...

# %%
# Observar los registros del dataset
df_as
# Out:
#                        airline  avail_seat_km_per_week  incidents_85_99  \
# 0                   Aer Lingus               320906734                2
# 1                    Aeroflot*              1197672318               76
# 2        Aerolineas Argentinas               385803648                6
# 3                  Aeromexico*               596871813                3
# 4                   Air Canada              1865253802                2
# 5                   Air France              3004002661               14
# 6                   Air India*               869253552                2
# 7             Air New Zealand*               710174817                3
# 8             Alaska Airlines*               965346773                5
# 9                     Alitalia               698012498                7
# 10          All Nippon Airways              1841234177                3
# 11                   American*              5228357340               21
# ...

# %% [markdown]
# En este Dataset son de distintas aerolíneas de todo el mundo en donde están registrados los número de asientos que una compañía aérea pone a disposición por cada kilómetro que un avión de esta recorre, los incidentes, los accidentes mortales y las victimas fatales de esos accidentes, y están dividos en dos periodos, el primero es de los años **1985-1999** y de **2000-2014**.

# %%
df_as.describe()
# Out:
#        avail_seat_km_per_week  incidents_85_99  fatal_accidents_85_99  \
# count            5.600000e+01        56.000000              56.000000
# mean             1.384621e+09         7.178571               2.178571
# std              1.465317e+09        11.035656               2.861069
# min              2.593733e+08         0.000000               0.000000
# 25%              4.740362e+08         2.000000               0.000000
# 50%              8.029089e+08         4.000000               1.000000
# 75%              1.847239e+09         8.000000               3.000000
# max              7.139291e+09        76.000000              14.000000
#
#        fatalities_85_99  incidents_00_14  fatal_accidents_00_14  \
# count         56.000000        56.000000              56.000000
# mean         112.410714         4.125000               0.660714
# std          146.691114         4.544977               0.858684
# min            0.000000         0.000000               0.000000
# ...

# %% [markdown]
# Genera estadísticas descriptivas.
#
# Las estadísticas descriptivas incluyen las que resumen la tendencia central, la dispersión y la forma de la distribución de un conjunto de datos, excluyendo los valores NaN.

# %%
df_as.count()
# Out:
# airline                   56
# avail_seat_km_per_week    56
# incidents_85_99           56
# fatal_accidents_85_99     56
# fatalities_85_99          56
# incidents_00_14           56
# fatal_accidents_00_14     56
# fatalities_00_14          56
# dtype: int64

# %% [markdown]
# Contar las celdas non-NA para cada columna o fila.

# %%
#Analizando la información
#Permite ver los primeros 10 registros
df_as.head(10)
# Out:
#                  airline  avail_seat_km_per_week  incidents_85_99  \
# 0             Aer Lingus               320906734                2
# 1              Aeroflot*              1197672318               76
# 2  Aerolineas Argentinas               385803648                6
# 3            Aeromexico*               596871813                3
# 4             Air Canada              1865253802                2
# 5             Air France              3004002661               14
# 6             Air India*               869253552                2
# 7       Air New Zealand*               710174817                3
# 8       Alaska Airlines*               965346773                5
# 9               Alitalia               698012498                7
#
#    fatal_accidents_85_99  fatalities_85_99  incidents_00_14  \
# 0                      0                 0                0
# 1                     14               128                6
# ...

# %%
#El tipo de dato de las columnas
print(df_as.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   airline                 56 non-null     object
#  1   avail_seat_km_per_week  56 non-null     int64
#  2   incidents_85_99         56 non-null     int64
#  3   fatal_accidents_85_99   56 non-null     int64
#  4   fatalities_85_99        56 non-null     int64
#  5   incidents_00_14         56 non-null     int64
#  6   fatal_accidents_00_14   56 non-null     int64
#  7   fatalities_00_14        56 non-null     int64
# dtypes: int64(7), object(1)
# memory usage: 3.6+ KB
# None

# %%
#Permite ver los ultimos 5 registros
df_as.tail()
# Out:
#                        airline  avail_seat_km_per_week  incidents_85_99  \
# 51       United / Continental*              7139291291               19
# 52  US Airways / America West*              2455687887               16
# 53            Vietnam Airlines               625084918                7
# 54             Virgin Atlantic              1005248585                1
# 55             Xiamen Airlines               430462962                9
#
#     fatal_accidents_85_99  fatalities_85_99  incidents_00_14  \
# 51                      8               319               14
# 52                      7               224               11
# 53                      3               171                1
# 54                      0                 0                0
# 55                      1                82                2
#
#     fatal_accidents_00_14  fatalities_00_14
# 51                      2               109
# 52                      2                23
# ...

# %% [markdown]
# ### Procesamiento de la información
#
# #### Fase 1:
#
# Limpieza de datos: datos vacíos, duplicados, datos y formato equivocado
# revisar la información df

# %%
#Datos vacíos - eliminar renglón
df_notNan = df_as.dropna()
df_notNan
# Out:
#                        airline  avail_seat_km_per_week  incidents_85_99  \
# 0                   Aer Lingus               320906734                2
# 1                    Aeroflot*              1197672318               76
# 2        Aerolineas Argentinas               385803648                6
# 3                  Aeromexico*               596871813                3
# 4                   Air Canada              1865253802                2
# 5                   Air France              3004002661               14
# 6                   Air India*               869253552                2
# 7             Air New Zealand*               710174817                3
# 8             Alaska Airlines*               965346773                5
# 9                     Alitalia               698012498                7
# 10          All Nippon Airways              1841234177                3
# 11                   American*              5228357340               21
# ...

# %% [markdown]
# No hay renglones con datos vacios

# %%
# Observar los registros del dataset 
df_as
# Out:
#                        airline  avail_seat_km_per_week  incidents_85_99  \
# 0                   Aer Lingus               320906734                2
# 1                    Aeroflot*              1197672318               76
# 2        Aerolineas Argentinas               385803648                6
# 3                  Aeromexico*               596871813                3
# 4                   Air Canada              1865253802                2
# 5                   Air France              3004002661               14
# 6                   Air India*               869253552                2
# 7             Air New Zealand*               710174817                3
# 8             Alaska Airlines*               965346773                5
# 9                     Alitalia               698012498                7
# 10          All Nippon Airways              1841234177                3
# 11                   American*              5228357340               21
# ...

# %%
#Para ver si hay renglones duplicados
print(df_as.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# 55    False
# dtype: bool

# %% [markdown]
# No hay ningún renglón duplicado.

# %% [markdown]
# #### Fase 2.
#
# Encontrar relaciones en la información (correlacionar)

# %%
# Metodo corr() : calcula la relacion entre columnas.
# Valores -1.0 a 1.0
# Relacion perfecta : 1.0000, Buena relacion : 0.90000
# Mala relacion : 0.000291 <- significa
df_as.corr()
# Out:
#                         avail_seat_km_per_week  incidents_85_99  \
# avail_seat_km_per_week                1.000000         0.279538
# incidents_85_99                       0.279538         1.000000
# fatal_accidents_85_99                 0.468300         0.856991
# fatalities_85_99                      0.209835         0.274394
# incidents_00_14                       0.725917         0.403009
# fatal_accidents_00_14                 0.375673         0.390249
# fatalities_00_14                      0.228484         0.195337
#
#                         fatal_accidents_85_99  fatalities_85_99  \
# avail_seat_km_per_week               0.468300          0.209835
# incidents_85_99                      0.856991          0.274394
# fatal_accidents_85_99                1.000000          0.540866
# fatalities_85_99                     0.540866          1.000000
# incidents_00_14                      0.572923          0.273696
# fatal_accidents_00_14                0.498758          0.228180
# ...

# %% [markdown]
# #### Fase 3
#
# Graficar

# %%
#Matplotlib, pyplot
import matplotlib.pyplot as plt

# %%
df_as.plot()
plt.show()

# %%
#Grafica de dispersión
df_as.plot.scatter(x = "incidents_85_99", y = "fatal_accidents_85_99")
plt.show()

# %% [markdown]
# Al observar la gráfica de dispersión, se concluye que hay una buena correlación entre los incidentes y accidentes mortales en el periodo de 1985 a 1999.

# %%
#Histograma
df_as.fatalities_00_14.plot.hist()
plt.show()

# %% [markdown]
# En el Histograma se ve la frecuencia de victimas mortales hay en los accidentes aéreos entre los años 2000 a 2014 por aerolínea.

# %%
# Histograma
df_as.incidents_00_14.plot.hist()
plt.show()

# %% [markdown]
# La frecuencia de los incidentes entre los años 2000 a 2014, por lo tanto, los incidentes aéreos son muy raros.

# %% [markdown]
# ## Dataset 2: Netflix

# %%
#Lectura desde un dataset CSV - netflix_titles.csv
df_netflix = pd.read_csv(ruta+"netflix_titles.csv")

# %%
type(df_netflix)
# Out:
# pandas.core.frame.DataFrame

# %%
# Observar los registros del dataset con print
print (df_netflix)
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
# Observar los registros del dataset
df_netflix
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# En este Dataset son de distintas producciones de Netflix en todo el mundo donde están registrados el tipo de producción, el nombre de la producción, el director, el cast, país en donde se realizó, la fecha en que se añadió, el año de lanzamiento, a que público va enfocada la producción, la duración, en que categorías se encuenta y una descripción de la producción.

# %%
df_netflix.describe()
# Out:
#        release_year
# count   7787.000000
# mean    2013.932580
# std        8.757395
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2018.000000
# max     2021.000000

# %% [markdown]
# Genera estadísticas descriptivas.
#
# Las estadísticas descriptivas incluyen las que resumen la tendencia central, la dispersión y la forma de la distribución de un conjunto de datos, excluyendo los valores NaN.

# %%
df_netflix.count()
# Out:
# show_id         7787
# type            7787
# title           7787
# director        5398
# cast            7069
# country         7280
# date_added      7777
# release_year    7787
# rating          7780
# duration        7787
# listed_in       7787
# description     7787
# dtype: int64

# %% [markdown]
# Contar las celdas non-NA para cada columna o fila.

# %%
#Analizando la información
#Permite ver los primeros 10 registros
df_netflix.head(10)
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
# 6      s7    Movie    122    Yasir Al Yasiri
# 7      s8    Movie    187     Kevin Reynolds
# 8      s9    Movie    706      Shravan Kumar
# 9     s10    Movie   1920       Vikram Bhatt
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# ...

# %%
#El tipo de dato de las columnas
print(df_netflix.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   object
#  10  listed_in     7787 non-null   object
#  11  description   7787 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 730.2+ KB
# None

# %%
#Permite ver los ultimos 15 registros
df_netflix.tail(15)
# Out:
#      show_id     type                                    title  \
# 7772   s7773    Movie        Zipi & Zape y la Isla del Capitan
# 7773   s7774    Movie                           Zoé: Panoramas
# 7774   s7775    Movie                                   Zodiac
# 7775   s7776  TV Show                               Zoids Wild
# 7776   s7777    Movie                                 Zokkomon
# 7777   s7778  TV Show                              Zombie Dumb
# 7778   s7779    Movie                               Zombieland
# 7779   s7780  TV Show                                Zona Rosa
# 7780   s7781    Movie                                      Zoo
# 7781   s7782    Movie                                     Zoom
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# ...

# %% [markdown]
# ### Procesamiento de la información
#
# #### Fase 1:
#
# Limpieza de datos: datos vacíos, duplicados, datos y formato equivocado
# revisar la información df

# %%
#Datos vacíos - eliminar renglón
df_netflix.dropna(inplace = True)
df_netflix
# Out:
#      show_id     type       title           director  \
# 1         s2    Movie        7:19  Jorge Michel Grau
# 2         s3    Movie       23:59       Gilbert Chan
# 3         s4    Movie           9        Shane Acker
# 4         s5    Movie          21     Robert Luketic
# 5         s6  TV Show          46        Serdar Akar
# ...      ...      ...         ...                ...
# 7778   s7779    Movie  Zombieland    Ruben Fleischer
# 7780   s7781    Movie         Zoo       Shlok Sharma
# 7781   s7782    Movie        Zoom       Peter Hewitt
# 7782   s7783    Movie        Zozo        Josef Fares
# 7783   s7784    Movie      Zubaan        Mozez Singh
#
#                                                    cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %% [markdown]
# Si se eliminaron varios renglones de datos que tenían datos vacios

# %%
df_netflix.count()
# Out:
# show_id         4808
# type            4808
# title           4808
# director        4808
# cast            4808
# country         4808
# date_added      4808
# release_year    4808
# rating          4808
# duration        4808
# listed_in       4808
# description     4808
# dtype: int64

# %%
registros_eliminados = 7787 - 4808
print(registros_eliminados)
# Out:
# 2979

# %% [markdown]
# Al realizar la operación, se encontró que se eliminaron 2979 registros, por lo tanto, ahorita solo son 4808 registros con los que se van a manipular.

# %%
#Para ver si hay renglones duplicados
print(df_netflix.duplicated())
# Out:
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
#         ...
# 7778    False
# 7780    False
# 7781    False
# 7782    False
# 7783    False
# Length: 4808, dtype: bool

# %%
#Para eliminar duplicados
df_netflix.drop_duplicates(inplace = True)

# %%
df_netflix.count()
# Out:
# show_id         4808
# type            4808
# title           4808
# director        4808
# cast            4808
# country         4808
# date_added      4808
# release_year    4808
# rating          4808
# duration        4808
# listed_in       4808
# description     4808
# dtype: int64

# %% [markdown]
# No había registros duplicados

# %%
df_netflix
# Out:
#      show_id     type       title           director  \
# 1         s2    Movie        7:19  Jorge Michel Grau
# 2         s3    Movie       23:59       Gilbert Chan
# 3         s4    Movie           9        Shane Acker
# 4         s5    Movie          21     Robert Luketic
# 5         s6  TV Show          46        Serdar Akar
# ...      ...      ...         ...                ...
# 7778   s7779    Movie  Zombieland    Ruben Fleischer
# 7780   s7781    Movie         Zoo       Shlok Sharma
# 7781   s7782    Movie        Zoom       Peter Hewitt
# 7782   s7783    Movie        Zozo        Josef Fares
# 7783   s7784    Movie      Zubaan        Mozez Singh
#
#                                                    cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %% [markdown]
# #### Fase 2.
#
# Encontrar relaciones en la información (correlacionar)

# %%
# Metodo corr() : calcula la relacion entre columnas.
# Valores -1.0 a 1.0
# Relacion perfecta : 1.0000, Buena relacion : 0.90000
# Mala relacion : 0.000291 <- significa
df_netflix.corr()
# Out:
#               release_year
# release_year           1.0

# %% [markdown]
# #### Fase 3
#
# Graficar

# %%
df_netflix.plot()
plt.show()

# %%
#Histograma
df_netflix.release_year.plot.hist()
plt.show()

# %% [markdown]
# Histograma de las frecuencias del año de lanzamiento de las producciones de Netflix, se concluye que la mayoría de las producciones son entre los años 2010-2020.

# %% [markdown]
# ## Dataset 3: Comentarios sobre DisneyLand

# %%
#Lectura desde un dataset CSV - DisneylandReviews.csv
arch = "C:\\DisneylandReviews.csv"
df_dlr = pd.read_csv(arch, delimiter=",", encoding='latin1')

# %%
type(df_dlr)
# Out:
# pandas.core.frame.DataFrame

# %%
# Observar los registros del dataset con print
print (df_dlr)
# Out:
#        Review_ID  Rating Year_Month     Reviewer_Location  \
# 0      670772142       4     2019-4             Australia
# 1      670682799       4     2019-5           Philippines
# 2      670623270       4     2019-4  United Arab Emirates
# 3      670607911       4     2019-4             Australia
# 4      670607296       4     2019-4        United Kingdom
# ...          ...     ...        ...                   ...
# 42651    1765031       5    missing        United Kingdom
# 42652    1659553       5    missing                Canada
# 42653    1645894       5    missing          South Africa
# 42654    1618637       4    missing         United States
# 42655    1536786       4    missing        United Kingdom
#
#                                              Review_Text               Branch
# 0      If you've ever been to Disneyland anywhere you...  Disneyland_HongKong
# 1      Its been a while since d last time we visit HK...  Disneyland_HongKong
# ...

# %%
# Observar los registros del dataset
df_dlr
# Out:
#        Review_ID  Rating Year_Month     Reviewer_Location  \
# 0      670772142       4     2019-4             Australia
# 1      670682799       4     2019-5           Philippines
# 2      670623270       4     2019-4  United Arab Emirates
# 3      670607911       4     2019-4             Australia
# 4      670607296       4     2019-4        United Kingdom
# ...          ...     ...        ...                   ...
# 42651    1765031       5    missing        United Kingdom
# 42652    1659553       5    missing                Canada
# 42653    1645894       5    missing          South Africa
# 42654    1618637       4    missing         United States
# 42655    1536786       4    missing        United Kingdom
#
#                                              Review_Text               Branch
# 0      If you've ever been to Disneyland anywhere you...  Disneyland_HongKong
# 1      Its been a while since d last time we visit HK...  Disneyland_HongKong
# ...

# %% [markdown]
# En este Dataset son de los Reviews de los parques de DisneyLand en distintas ubicaciones del mundo donde están registrados el ID del review, el rating, el año y mes, el lugar de origen de la persona que hizo el review, la descripción, y el parque al que visitó.

# %%
df_dlr.describe()
# Out:
#           Review_ID        Rating
# count  4.265600e+04  42656.000000
# mean   3.188553e+08      4.217695
# std    1.657092e+08      1.063371
# min    1.398724e+06      1.000000
# 25%    1.743274e+08      4.000000
# 50%    2.907583e+08      5.000000
# 75%    4.489579e+08      5.000000
# max    6.708014e+08      5.000000

# %% [markdown]
# Genera estadísticas descriptivas.
#
# Las estadísticas descriptivas incluyen las que resumen la tendencia central, la dispersión y la forma de la distribución de un conjunto de datos, excluyendo los valores NaN.

# %%
df_dlr.count()
# Out:
# Review_ID            42656
# Rating               42656
# Year_Month           42656
# Reviewer_Location    42656
# Review_Text          42656
# Branch               42656
# dtype: int64

# %% [markdown]
# Contar las celdas non-NA para cada columna o fila.

# %%
#Analizando la información
#Permite ver los primeros 15 registros
df_dlr.head(15)
# Out:
#     Review_ID  Rating Year_Month     Reviewer_Location  \
# 0   670772142       4     2019-4             Australia
# 1   670682799       4     2019-5           Philippines
# 2   670623270       4     2019-4  United Arab Emirates
# 3   670607911       4     2019-4             Australia
# 4   670607296       4     2019-4        United Kingdom
# 5   670591897       3     2019-4             Singapore
# 6   670585330       5     2019-4                 India
# 7   670574142       3     2019-3              Malaysia
# 8   670571027       2     2019-4             Australia
# 9   670570869       5     2019-3                 India
# 10  670443403       5     2019-4         United States
# 11  670435886       5     2019-4                Canada
# 12  670376905       4     2019-4             Australia
# 13  670324965       5     2019-4           Philippines
# 14  670274554       5     2018-9             Australia
#
#                                           Review_Text               Branch
# ...

# %%
#El tipo de dato de las columnas
print(df_dlr.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42656 entries, 0 to 42655
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Review_ID          42656 non-null  int64
#  1   Rating             42656 non-null  int64
#  2   Year_Month         42656 non-null  object
#  3   Reviewer_Location  42656 non-null  object
#  4   Review_Text        42656 non-null  object
#  5   Branch             42656 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 2.0+ MB
# None

# %%
#Permite ver los ultimos 10 registros
df_dlr.tail(10)
# Out:
#        Review_ID  Rating Year_Month Reviewer_Location  \
# 42646    2228738       3    missing             Spain
# 42647    2216235       2    missing     United States
# 42648    2192691       5    missing     United States
# 42649    2174555       5    missing    United Kingdom
# 42650    1879452       5    missing    United Kingdom
# 42651    1765031       5    missing    United Kingdom
# 42652    1659553       5    missing            Canada
# 42653    1645894       5    missing      South Africa
# 42654    1618637       4    missing     United States
# 42655    1536786       4    missing    United Kingdom
#
#                                              Review_Text            Branch
# 42646  It's my 4th. visit to disneyland paris and all...  Disneyland_Paris
# 42647  I would not recommend going if you have been t...  Disneyland_Paris
# 42648  I've been to Disney in California 5 times. I'v...  Disneyland_Paris
# ...

# %% [markdown]
# ### Procesamiento de la información
#
# #### Fase 1:
#
# Limpieza de datos: datos vacíos, duplicados, datos y formato equivocado
# revisar la información df

# %%
#Datos vacíos - eliminar renglón
df_dlr.dropna(inplace = True)
df_dlr
# Out:
#        Review_ID  Rating Year_Month     Reviewer_Location  \
# 0      670772142       4     2019-4             Australia
# 1      670682799       4     2019-5           Philippines
# 2      670623270       4     2019-4  United Arab Emirates
# 3      670607911       4     2019-4             Australia
# 4      670607296       4     2019-4        United Kingdom
# ...          ...     ...        ...                   ...
# 42651    1765031       5    missing        United Kingdom
# 42652    1659553       5    missing                Canada
# 42653    1645894       5    missing          South Africa
# 42654    1618637       4    missing         United States
# 42655    1536786       4    missing        United Kingdom
#
#                                              Review_Text               Branch
# 0      If you've ever been to Disneyland anywhere you...  Disneyland_HongKong
# 1      Its been a while since d last time we visit HK...  Disneyland_HongKong
# ...

# %% [markdown]
# No hay renglones con datos vacios

# %%
#Para ver si hay renglones duplicados
print(df_dlr.duplicated())
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 42651    False
# 42652    False
# 42653    False
# 42654    False
# 42655    False
# Length: 42656, dtype: bool

# %%
#Para eliminar duplicados
df_dlr.drop_duplicates(inplace = True)

# %%
df_dlr.count()
# Out:
# Review_ID            42644
# Rating               42644
# Year_Month           42644
# Reviewer_Location    42644
# Review_Text          42644
# Branch               42644
# dtype: int64

# %% [markdown]
# Se eliminaron algunos registros duplicados

# %%
df_dlr
# Out:
#        Review_ID  Rating Year_Month     Reviewer_Location  \
# 0      670772142       4     2019-4             Australia
# 1      670682799       4     2019-5           Philippines
# 2      670623270       4     2019-4  United Arab Emirates
# 3      670607911       4     2019-4             Australia
# 4      670607296       4     2019-4        United Kingdom
# ...          ...     ...        ...                   ...
# 42651    1765031       5    missing        United Kingdom
# 42652    1659553       5    missing                Canada
# 42653    1645894       5    missing          South Africa
# 42654    1618637       4    missing         United States
# 42655    1536786       4    missing        United Kingdom
#
#                                              Review_Text               Branch
# 0      If you've ever been to Disneyland anywhere you...  Disneyland_HongKong
# 1      Its been a while since d last time we visit HK...  Disneyland_HongKong
# ...

# %% [markdown]
# #### Fase 2.
#
# Encontrar relaciones en la información (correlacionar)

# %%
# Metodo corr() : calcula la relacion entre columnas.
# Valores -1.0 a 1.0
# Relacion perfecta : 1.0000, Buena relacion : 0.90000
# Mala relacion : 0.000291 <- significa
df_dlr.corr()
# Out:
#            Review_ID    Rating
# Review_ID   1.000000  0.006325
# Rating      0.006325  1.000000

# %% [markdown]
# #### Fase 3
#
# Graficar

# %%
df_dlr.plot()
plt.show()

# %%
#Grafica de dispersión
df_dlr.plot.scatter(x = "Review_ID", y = "Rating")
plt.show()

# %% [markdown]
# Al observar la gráfica de dispersión, se concluye que **NO** hay correlación entre los Review_ID y el Rating.

# %%
#Histograma
df_dlr.Rating.plot.hist()
plt.show()

# %% [markdown]
# Histograma de las frecuencias del Rating, es decir, la calificación en general de los usuarios sobre los parques, el cual es positivo en la mayoría de las calificaciones.

# %% [markdown]
# ## Dataset 4: Juego Skillcraft 1

# %%
#Lectura desde un dataset CSV - SkillCraft1_Dataset.csv
arch = "C:\\SkillCraft1_Dataset.csv"
df_sk = pd.read_csv(arch, delimiter=",", encoding='latin1')

# %%
type(df_sk)
# Out:
# pandas.core.frame.DataFrame

# %%
# Observar los registros del dataset con print
print (df_sk)
# Out:
#       GameID  LeagueIndex Age HoursPerWeek TotalHours       APM  \
# 0         52            5  27           10       3000  143.7180
# 1         55            5  23           10       5000  129.2322
# 2         56            4  30           10        200   69.9612
# 3         57            3  19           20        400  107.6016
# 4         58            3  32           10        500  122.8908
# ...      ...          ...  ..          ...        ...       ...
# 3390   10089            8   ?            ?          ?  259.6296
# 3391   10090            8   ?            ?          ?  314.6700
# 3392   10092            8   ?            ?          ?  299.4282
# 3393   10094            8   ?            ?          ?  375.8664
# 3394   10095            8   ?            ?          ?  348.3576
#
#       SelectByHotkeys  AssignToHotkeys  UniqueHotkeys  MinimapAttacks  \
# 0            0.003515         0.000220              7        0.000110
# ...

# %%
# Observar los registros del dataset
df_sk
# Out:
#       GameID  LeagueIndex Age HoursPerWeek TotalHours       APM  \
# 0         52            5  27           10       3000  143.7180
# 1         55            5  23           10       5000  129.2322
# 2         56            4  30           10        200   69.9612
# 3         57            3  19           20        400  107.6016
# 4         58            3  32           10        500  122.8908
# ...      ...          ...  ..          ...        ...       ...
# 3390   10089            8   ?            ?          ?  259.6296
# 3391   10090            8   ?            ?          ?  314.6700
# 3392   10092            8   ?            ?          ?  299.4282
# 3393   10094            8   ?            ?          ?  375.8664
# 3394   10095            8   ?            ?          ?  348.3576
#
#       SelectByHotkeys  AssignToHotkeys  UniqueHotkeys  MinimapAttacks  \
# 0            0.003515         0.000220              7        0.000110
# ...

# %% [markdown]
# En este Dataset contiene la información y detalles generales de lo que han hecho los jugadores en el SkillCraft 1

# %%
df_sk.describe()
# Out:
#              GameID  LeagueIndex          APM  SelectByHotkeys  \
# count   3395.000000  3395.000000  3395.000000      3395.000000
# mean    4805.012371     4.184094   117.046947         0.004299
# std     2719.944851     1.517327    51.945291         0.005284
# min       52.000000     1.000000    22.059600         0.000000
# 25%     2464.500000     3.000000    79.900200         0.001258
# 50%     4874.000000     4.000000   108.010200         0.002500
# 75%     7108.500000     5.000000   142.790400         0.005133
# max    10095.000000     8.000000   389.831400         0.043088
#
#        AssignToHotkeys  UniqueHotkeys  MinimapAttacks  MinimapRightClicks  \
# count      3395.000000    3395.000000     3395.000000         3395.000000
# mean          0.000374       4.364654        0.000098            0.000387
# std           0.000225       2.360333        0.000166            0.000377
# min           0.000000       0.000000        0.000000            0.000000
# ...

# %% [markdown]
# Genera estadísticas descriptivas.
#
# Las estadísticas descriptivas incluyen las que resumen la tendencia central, la dispersión y la forma de la distribución de un conjunto de datos, excluyendo los valores NaN.

# %%
df_sk.count()
# Out:
# GameID                  3395
# LeagueIndex             3395
# Age                     3395
# HoursPerWeek            3395
# TotalHours              3395
# APM                     3395
# SelectByHotkeys         3395
# AssignToHotkeys         3395
# UniqueHotkeys           3395
# MinimapAttacks          3395
# MinimapRightClicks      3395
# NumberOfPACs            3395
# GapBetweenPACs          3395
# ActionLatency           3395
# ActionsInPAC            3395
# TotalMapExplored        3395
# WorkersMade             3395
# UniqueUnitsMade         3395
# ComplexUnitsMade        3395
# ComplexAbilitiesUsed    3395
# dtype: int64

# %% [markdown]
# Contar las celdas non-NA para cada columna o fila.

# %%
#Analizando la información
#Permite ver los primeros 13 registros
df_sk.head(13)
# Out:
#     GameID  LeagueIndex Age HoursPerWeek TotalHours       APM  \
# 0       52            5  27           10       3000  143.7180
# 1       55            5  23           10       5000  129.2322
# 2       56            4  30           10        200   69.9612
# 3       57            3  19           20        400  107.6016
# 4       58            3  32           10        500  122.8908
# 5       60            2  27            6         70   44.4570
# 6       61            1  21            8        240   46.9962
# 7       72            7  17           42      10000  212.6022
# 8       77            4  20           14       2708  117.4884
# 9       81            4  18           24        800  155.9856
# 10      83            3  16           16       6000  153.8010
# 11      93            4  26            4        190   79.2948
# 12      97            3  18           12        350   67.4754
#
#     SelectByHotkeys  AssignToHotkeys  UniqueHotkeys  MinimapAttacks  \
# ...

# %%
#El tipo de dato de las columnas
print(df_sk.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3395 entries, 0 to 3394
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   GameID                3395 non-null   int64
#  1   LeagueIndex           3395 non-null   int64
#  2   Age                   3395 non-null   object
#  3   HoursPerWeek          3395 non-null   object
#  4   TotalHours            3395 non-null   object
#  5   APM                   3395 non-null   float64
#  6   SelectByHotkeys       3395 non-null   float64
#  7   AssignToHotkeys       3395 non-null   float64
#  8   UniqueHotkeys         3395 non-null   int64
#  9   MinimapAttacks        3395 non-null   float64
#  10  MinimapRightClicks    3395 non-null   float64
#  11  NumberOfPACs          3395 non-null   float64
#  12  GapBetweenPACs        3395 non-null   float64
#  13  ActionLatency         3395 non-null   float64
# ...

# %%
#Permite ver los ultimos 12 registros
df_sk.tail(12)
# Out:
#       GameID  LeagueIndex Age HoursPerWeek TotalHours       APM  \
# 3383   10075            8   ?            ?          ?  274.6194
# 3384   10076            8   ?            ?          ?  225.0678
# 3385   10079            8   ?            ?          ?  254.2188
# 3386   10081            8   ?            ?          ?  339.1524
# 3387   10082            8   ?            ?          ?  310.0416
# 3388   10083            8   ?            ?          ?  288.7608
# 3389   10084            8   ?            ?          ?  151.4046
# 3390   10089            8   ?            ?          ?  259.6296
# 3391   10090            8   ?            ?          ?  314.6700
# 3392   10092            8   ?            ?          ?  299.4282
# 3393   10094            8   ?            ?          ?  375.8664
# 3394   10095            8   ?            ?          ?  348.3576
#
#       SelectByHotkeys  AssignToHotkeys  UniqueHotkeys  MinimapAttacks  \
# ...

# %% [markdown]
# ### Procesamiento de la información
#
# #### Fase 1:
#
# Limpieza de datos: datos vacíos, duplicados, datos y formato equivocado
# revisar la información df

# %%
#Datos vacíos - eliminar renglón
df_sk.dropna(inplace = True)
df_sk
# Out:
#       GameID  LeagueIndex Age HoursPerWeek TotalHours       APM  \
# 0         52            5  27           10       3000  143.7180
# 1         55            5  23           10       5000  129.2322
# 2         56            4  30           10        200   69.9612
# 3         57            3  19           20        400  107.6016
# 4         58            3  32           10        500  122.8908
# ...      ...          ...  ..          ...        ...       ...
# 3390   10089            8   ?            ?          ?  259.6296
# 3391   10090            8   ?            ?          ?  314.6700
# 3392   10092            8   ?            ?          ?  299.4282
# 3393   10094            8   ?            ?          ?  375.8664
# 3394   10095            8   ?            ?          ?  348.3576
#
#       SelectByHotkeys  AssignToHotkeys  UniqueHotkeys  MinimapAttacks  \
# 0            0.003515         0.000220              7        0.000110
# ...

# %% [markdown]
# No hay registros con datos vacíos.

# %%
# Datos equivocados e incompletos:
# son los que tienen un signo de "?" en las columnas de Age, HoursPerWeek y TotalHours

#Para modificar toda la columna
for i in df_sk.index:
    if df_sk.loc[i, "Age"] == "?" or df_sk.loc[i, "HoursPerWeek"] == "?" or df_sk.loc[i, "TotalHours"] == "?":
        print(i)
        df_sk.drop(i, inplace = True)
# Out:
# 358
# 1841
# 3340
# 3341
# 3342
# 3343
# 3344
# 3345
# 3346
# 3347
# 3348
# 3349
# 3350
# 3351
# 3352
# 3353
# 3354
# 3355
# 3356
# 3357
# 3358
# 3359
# 3360
# 3361
# 3362
# 3363
# 3364
# 3365
# 3366
# 3367
# 3368
# 3369
# 3370
# 3371
# 3372
# 3373
# 3374
# 3375
# 3376
# 3377
# 3378
# 3379
# 3380
# 3381
# 3382
# 3383
# 3384
# 3385
# 3386
# 3387
# 3388
# 3389
# 3390
# 3391
# 3392
# 3393
# 3394

# %% [markdown]
# Se eliminan los registros (renglones) anteriores porque estan incompletos.

# %%
df_sk.count()
# Out:
# GameID                  3338
# LeagueIndex             3338
# Age                     3338
# HoursPerWeek            3338
# TotalHours              3338
# APM                     3338
# SelectByHotkeys         3338
# AssignToHotkeys         3338
# UniqueHotkeys           3338
# MinimapAttacks          3338
# MinimapRightClicks      3338
# NumberOfPACs            3338
# GapBetweenPACs          3338
# ActionLatency           3338
# ActionsInPAC            3338
# TotalMapExplored        3338
# WorkersMade             3338
# UniqueUnitsMade         3338
# ComplexUnitsMade        3338
# ComplexAbilitiesUsed    3338
# dtype: int64

# %%
# Observar los registros del dataset
df_sk
# Out:
#       GameID  LeagueIndex Age HoursPerWeek TotalHours       APM  \
# 0         52            5  27           10       3000  143.7180
# 1         55            5  23           10       5000  129.2322
# 2         56            4  30           10        200   69.9612
# 3         57            3  19           20        400  107.6016
# 4         58            3  32           10        500  122.8908
# ...      ...          ...  ..          ...        ...       ...
# 3335    9261            4  20            8        400  158.1390
# 3336    9264            5  16           56       1500  186.1320
# 3337    9265            4  21            8        100  121.6992
# 3338    9270            3  20           28        400  134.2848
# 3339    9271            4  22            6        400   88.8246
#
#       SelectByHotkeys  AssignToHotkeys  UniqueHotkeys  MinimapAttacks  \
# 0            0.003515         0.000220              7        0.000110
# ...

# %%
#Para ver si hay renglones duplicados
print(df_sk.duplicated())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3335    False
# 3336    False
# 3337    False
# 3338    False
# 3339    False
# Length: 3338, dtype: bool

# %%
#Para eliminar duplicados
df_sk.drop_duplicates(inplace = True)

# %%
df_sk.count()
# Out:
# GameID                  3338
# LeagueIndex             3338
# Age                     3338
# HoursPerWeek            3338
# TotalHours              3338
# APM                     3338
# SelectByHotkeys         3338
# AssignToHotkeys         3338
# UniqueHotkeys           3338
# MinimapAttacks          3338
# MinimapRightClicks      3338
# NumberOfPACs            3338
# GapBetweenPACs          3338
# ActionLatency           3338
# ActionsInPAC            3338
# TotalMapExplored        3338
# WorkersMade             3338
# UniqueUnitsMade         3338
# ComplexUnitsMade        3338
# ComplexAbilitiesUsed    3338
# dtype: int64

# %% [markdown]
# No había registros duplicados

# %%
# Observar los registros del dataset
df_sk
# Out:
#       GameID  LeagueIndex Age HoursPerWeek TotalHours       APM  \
# 0         52            5  27           10       3000  143.7180
# 1         55            5  23           10       5000  129.2322
# 2         56            4  30           10        200   69.9612
# 3         57            3  19           20        400  107.6016
# 4         58            3  32           10        500  122.8908
# ...      ...          ...  ..          ...        ...       ...
# 3335    9261            4  20            8        400  158.1390
# 3336    9264            5  16           56       1500  186.1320
# 3337    9265            4  21            8        100  121.6992
# 3338    9270            3  20           28        400  134.2848
# 3339    9271            4  22            6        400   88.8246
#
#       SelectByHotkeys  AssignToHotkeys  UniqueHotkeys  MinimapAttacks  \
# 0            0.003515         0.000220              7        0.000110
# ...

# %% [markdown]
# #### Fase 2.
#
# Encontrar relaciones en la información (correlacionar)

# %%
# Metodo corr() : calcula la relacion entre columnas.
# Valores -1.0 a 1.0
# Relacion perfecta : 1.0000, Buena relacion : 0.90000
# Mala relacion : 0.000291 <- significa
df_sk.corr()
# Out:
#                         GameID  LeagueIndex       APM  SelectByHotkeys  \
# GameID                1.000000     0.024974  0.075944         0.070298
# LeagueIndex           0.024974     1.000000  0.624171         0.428637
# APM                   0.075944     0.624171  1.000000         0.814624
# SelectByHotkeys       0.070298     0.428637  0.814624         1.000000
# AssignToHotkeys       0.063915     0.487280  0.534134         0.450342
# UniqueHotkeys         0.081176     0.322415  0.335986         0.274030
# MinimapAttacks        0.022422     0.270526  0.218562         0.132723
# MinimapRightClicks    0.009898     0.206380  0.306392         0.107615
# NumberOfPACs          0.035622     0.589193  0.635248         0.360057
# GapBetweenPACs       -0.065629    -0.537536 -0.567396        -0.273767
# ActionLatency        -0.042711    -0.659940 -0.722253        -0.390012
# ActionsInPAC          0.039482     0.140303  0.402928         0.166964
# ...

# %% [markdown]
# #### Fase 3
#
# Graficar

# %%
df_sk.plot()
plt.show()

# %%
#Grafica de dispersión
df_sk.plot.scatter(x = "APM", y = "SelectByHotkeys", alpha=0.1)
plt.show()

# %% [markdown]
# Al observar la gráfica de dispersión, se concluye que hay una buena correlación entre los APM y SelectByHotKeys

# %%
#Grafica de dispersión
df_sk.plot.scatter(x = "MinimapAttacks", y = "MinimapRightClicks", alpha=0.1)
plt.show()

# %% [markdown]
# Se concluye que NO hay una buena correlación entre los MinimapAttacks y MinimapRightClicks

# %%
#Histograma
df_sk.LeagueIndex.plot.hist()
plt.show()

# %% [markdown]
# Histograma de las frecuencias del indice de la liga, es decir, la liga en la que compiten los jugadores.

# %%
#Histograma
df_sk.TotalMapExplored.plot.hist()
plt.show()

# %% [markdown]
# Histograma de las frecuencias del mapa explorado, se concluye que gran parte de los jugadores exploran entre un 15 a 25
